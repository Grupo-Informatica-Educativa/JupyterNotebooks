# %% [markdown]
# # PC para Tod@s - Introducción a Python y Automatización

# %% [markdown]
# Estos Notebooks de Python fueron creados por el profesor Camilo Vieira (PhD), coordinador del grupo de *Informática Educativa* para el curso de Pensamiento Computacional para Tod@s de la Universidad del Norte, en Barranquilla - Colombia.
#
# Todos estos materiales cuentan con una licencia **Creative Commons** de libre uso con atribución.
#
# **Información de Contacto:**
# - cvieira@uninorte.edu.co
# - @cvieiram
# - https://cvieira77.wixsite.com/personal

# %% [markdown]
# ## Python y Jupyter
# *Python* es un lenguaje de programación muy usado en **ciencias humanas y exactas**. Python te permite crear programas que resuelvan problemas automatizando tareas repetitivas, procesando grandes cantidades de datos, resolviendo complejos cálculos matemáticos, o simplemente, creando visualizaciones de fenónenos complejos.
#
# *Jupyter* es un editor de texto y código que nos permite integrar éstos dos elementos en una página web que llamaremos NoteBook NB), para poder integrar explicaciones, ejecutar código, e incluir ejercicios prácticos. Cada que encuentres el texto **In [ ]** a la izquierda de una caja de texto, quiere decir que puedes ejecutar esta instrucción.
#
# Al finalizar esta actividad estarás en capacidad de:
# - Explicar pequeñas secuencias de pasos escritas en Python para hacer operaciones matemáticas
# - Modificar instrucciones en Python para resolver problemas específicos

# %% [markdown]
# ### Instrucciones, Variables, y Operaciones Matemáticas

# %% [markdown]
# Comencemos por lo más sencillo... Recuerda que programar significa darle instrucciones al computador para que haga lo que yo quiera. Podemos comenzar por pedirle que imprima algo para nosotros:

# %%
print('Mi primera instrucción al computador!')

# %% [markdown]
# ### Actividad
# Lo que hicimos fue simplemente decirle al computador que imprimiera (**print**) el texto que estaba entre las comillas. Ahora tu puedes hacer que imprima algo diferente. Escribe tu instrucción en el siguiente espacio y luego lo podrás ejecutar.

# %% [markdown]
# Vamos a hacer algo más interesante, vamos a crear una variable y hacer algunas operaciones con ésta.
#
# Una variable es *un espacio donde podemos guardar un valor*. A diferencia de otros lenguajes de programación, en Python no es necesario establecer un tipo de dato desde el inicio, sino que nuestra variable puede tomar cualquier valor. Por ejemplo, en la siguiente instrucción estamos asignando el valor de **5,** a la variable **y**.

# %%
y=5

# %% [markdown]
# Por ahora no vemos nada, pero ¿qué tal si imprimirmos la variable **y**?

# %%
print(y)

# %% [markdown]
# Nota que en este caso no pusimos las comillas. Esto es porque en la parte de arriba queríamos imprimir el texto entre comillas, mientras aquí queríamos imprimir el contenido de una variable **y**. Mira lo que ocurre si pones las comillas:

# %%
print('y')

# %% [markdown]
# Como el valor que asignamos a la variable **y** es un número, podemos hacer algunas operaciones matemáticas con esta variable. Por ejemplo, acá vamos a multiplicarla por 2, y almacenar el resultado en una nueva variable **x**.

# %%
x = y*2

# %% [markdown]
# ### Actividad
# Divide el valor de *x* entre 3, y verifica el resultado

# %% [markdown]
# Otros operadores matemáticos que podemos usar en Python son **+, -, /, y \****. Éste último ( \** ) corresponde a la potenciación. Por ejemplo: **x\*\*2,** significa *x al cuadrado*. **Pruébalo en el siguiente espacio**

# %% [markdown]
# Además de estas operaciones matemáticas básicas, también podemos importar otras operaciones o funciones desde una "**librería**" (aunque la traducción correcta de **library** es *biblioteca*, en español se ha vuelto más común hablar de librerías).
#
# Por ejemplo, podemos usar la función raíz cuadrada **sqrt** importando **math**.

# %%
import math
math.sqrt(x)

# %% [markdown]
# Puedes ver todas las funciones que tiene esta biblioteca y cómo se usan, con los siguientes comandos:

# %%
#dir(math)           # Lista de funciones
#help(math)          # Ayuda sobre la librería math
help(math.sqrt)     # Ayuda sobre la función sqrt

# %% [markdown]
# En realidad la instrucción anterior solo ejecutó **help(math.sqrt)** . Esto es porque las otras dos instruccinoes tenían el signo **#,** que indica que esa línea es un comentario. Si lo borras del inicio de la línea, podrás ver lo que hacen las funciones **dir(math)** y **help(math)**

# %% [markdown]
# Librerías como **math** pueden ayudarte a hacer cálculos complejos. Esta es una de las primeras razones por las cuales es muy importante que aprendamos a programar. Un lenguaje como Python te permite automatizar muchos cálculos en poco tiempo.

# %% [markdown]
# ### Actividad
#
# Asigna la raiz cuadrada de **x,** a una variable **b,** redondea este valor a cero decimales y luego calcula el **factorial** de este número

# %% [markdown]
# Aunque Python no exige declarar un tipo de variable y nunca cambiarlo (como si ocurre en otros lenguajes), cada variable si asume un tipo según el dato que tenga almacenado. Por ejemplo:

# %%
a = 5     # Esto es un Entero (No tiene decimales)
b = 5.3   # Esto es un flotante (Un número que puede tener comas decimals)
c = '5'   # Esto es un texto, y por ende, no podemos hacer operaciones matemáticas con c

# %% [markdown]
# Podemos ver el tipo de dato de cada variable con  la función **type**

# %%
type(a)

# %%
type(b)

# %%
type(c)

# %% [markdown]
# Puedes multiplicar un entero por un flotante:

# %%
a*b

# %% [markdown]
# Pero si multiplicas números con texto, puedes obtener algunos resultados inesperados:

# %%
a*c

# %%
b*c

# %% [markdown]
# **Pregunta:** ¿Por que crees que estás obteniendo estos resultados?

# %% [markdown]
# Tendríamos que hacer una conversión para poder hacer dicha multiplicación:

# %%
int(c)*b

# %% [markdown]
# Hay además otro tipo de variables. Por ejemplo, las variables **booleanas** solo pueden almacenar dos valores: *verdadero* o *falso* .  Esto sirve por ejemplo cuando quieres saber si una máquina está encendida o apagada, o si una compuerta está abierta o cerrada

# %%
encendido = True
print(encendido)
type(encendido)

# %% [markdown]
# ## Actividades

# %% [markdown]
# Vamos ahora a practicar un poco. Completa los siguientes retos de programación:
#
# **Promedio**
#
# - Calcula tu promedio del semestre pasado, y almacénalo en una variable **x**.
#
# **Considera las siguientes ecuaciones:**
#
# $$ 4x^2 -2x +30 $$
#
# $$ 3x^2 -(2/3)x +26 $$
#
# - Utiliza la fórmula general (formula del bachiller) para calcular los posibles valores que puede tomar X, e imprime éstos valores
#
# **Calcular la distancia en tres dimensions**
#
# - La distancia entre dos átomos en un espacio tridimensional como el de la figura está dado por la siguiente ecuación:
#
# $$ d = \sqrt{(x_2 -x_1)^2+(y_2 -y_1)^2+(z_2 -z_1)^2} $$
#
# Donde la posición del átomo 1 está dado por: $$ (x_1, y_1, z_1) $$
# y la posición del átomo 2 está dado por: $$ (x_2, y_2, z_2) $$
#
# <img src="https://i.imgur.com/aeu2ccp.gif" width="380">
#
# Calcula la distancia entre dos átomos ubicados en las siguientes posiciones:
# $$ Atomo_1= (0,1,0) $$ y  $$ Atomo_2= (1,2,-1) $$

# %% [markdown]
# ### Listas de Valores
# U
# na estructura de datos bastante útil en programación es una lista de valores, a menudo conocida como un arreglo (en inglés, Array ). **Nota:*** En Python hay algunas diferencias menores entre un arreglo y una lista, pero por ahora vamos a asumir que son lo mismo.
#
# Para crear una lista, utilizamos los corchetes y separamos los valores de nuestra estructura con una coma. Por ejemplo, en la siguiente instrucción estamos creando una lista llamada **a** con los valores 1, 3, 2, 5,

# %%
a = [1, 3, 2, 5, 2]
print(a)

# %% [markdown]
# Las listas no necesariamente tienen que ser de números, también pueden ser de texto:

# %%
nombres = ["María", "Juan","Andrés"]
print(nombres)

# %% [markdown]
# Cada valor en la lista puede ser accedida utilizando su posición, donde la primera posición de la lista es considerada la posición **cero.** Por ejemplo, para obtener el valor en la segunda posición de **a** y el tercer nombre en la lista de nombres, utilizamos las siguientes instrucciones:

# %%
print(a[1])
print(nombres[2])

# %% [markdown]
# ### Actividad
# Escribe un programa en Python que imprima uno a uno los tres primeros valores de la lista **a** junto a los tres primeros nombres de la lista

# %% [markdown]
# Una forma útil de recorrer una lista en Python es utilizando ciclos. Un ciclo es una estructura en la cual le decimos al computador ejecute unas tareas varias veces. El ciclo for es ideal para estas tareas ya que con tan solo la siguiente estructura, ya Python sabrá que necesitamos recorrer todos los elementos de la lista:

# %%
for i in a:
    print(i)

for y in nombres:
    print(y)

# %% [markdown]
# ### Actividad
# Modifica el código anterior para que imprima todas las combinaciones de números y nombres, así:
#
# 1 - María
#
# 1 - Juan
#
# 1 - Andrés
#
# 3 - María
#
# 3 - Juan
#
# 3 - Andrés
#
# 2 - María
#
# 2 - Juan
#
# 2 - Andrés
#
# ... y así sucesivamente

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# Ahora vamos a usar Python para automatizar algunas tareas. Específicamente, queremos usarlo para tomar datos desde algunas páginas web sin necesidad de ir a copiar y pegar manualmente.
#
# Aunque hoy en día muchos de los datos están disponibles en la Web para descargas, hay otros sitios web que no ofrecen este servicio. Por ejemplo, .... Para poder descargar esta información necesitamos hacer *Web Scraping*.
#
# Cuando accedemos a una página web a través de nuestro navegado (ejem. Chrome), lo que hacemos es hacer una **solicitud** (request) a un servidor a través de un protocolo (una forma predefinida de comunicarse entre computadores) llamado HTTP. Sin embargo, ésta no es la única forma de hacerlo, podemos también hacer dicha **solicitud** desde un programa que nosotros creemos.
#
# Cuando hacemos esta solicitud, el servidor nos devuelve la página web en formato *HTML*. Esto significa que tendremos que entender cómo está construida la página para poder sacar los datos de allí.

# %% [markdown]
# **Comencemos...**
#
# Lo primero que debemos hacer es llamar una *librería* llamada requests, que nos permitirá hacer la solicitud de una página.
#
# Vamos a traernos la página principal de El Heraldo, e imprimir su código html.

# %%
import requests

URL = "https://www.elheraldo.co/"

page = requests.get(URL)

print(page.content)
# Out:
# b'\t\t<!DOCTYPE html>\r\n\t\t<html lang="es-CO">\r\n\t\t\t<head>\r\n\t\t\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="shortcut icon" href="https://www.elheraldo.co/sites/default/files/favicon_1.png" type="image/png" />\n<meta name="generator" content="Drupal 7 (https://www.drupal.org)" />\n<link rel="canonical" href="https://www.elheraldo.co/" />\n<link rel="shortlink" href="https://www.elheraldo.co/" />\n\r\n\t\t\t\t<!-- Google Tag Manager -->\r\n\t\t\t\t<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\n\t\t\t\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\n\t\t\t\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\t\t\t\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n\t\t\t\t})(window,document,\'script\',\'dataLayer\',\'GTM-MGHCJ5L\');</script>\r\n\t\t\t\t<!-- End Google Tag Manager -->\r\n\r\n\t\t\t\t<!-- Chartbeat -->\r\n\t\t\t\t<script async type="text/javascript">\r\n\t\t\t\t\tvar _sf_async_config = window._sf_async_config = (window._sf_async_config || {});\r\n\t\t\t\t\t_sf_async_config.uid = 65677;\r\n\t\t\t\t\t_sf_async_config.domain = \'elheraldo.co\';\r\n\t\t\t\t\t_sf_async_config.useCanonical = true;\r\n\t\t\t\t\t_sf_async_config.useCanonicalDomain = true;\r\n\t\t\t\t\t//_sf_async_config.lazyLoadSrcsetAttribute = \'data-original\';\r\n\t\t\t\t\t_sf_async_config.flickerControl = false;\r\n\t\t\t\t</script>\r\n\t\t\t\t<script async src="//static.chartbeat.com/js/chartbeat_mab.js"></script>\r\n\r\n\t\t\t\t<!-- Start: Metadata -->\r\n\t\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t<title>Noticias de Barranquilla, la regi\xc3\xb3n Caribe, Colombia y el mundo - ELHERALDO.CO</title>\r\n\t\t\t\t\r\n\t\t\t\t<meta property="url" content="https://www.elheraldo.co/home">\r\n\t\t\t\t<meta property="og:site_name" content="EL HERALDO">\r\n\r\n\t\t\t\t\t\t\t\t\t<meta property="og:title" content="Noticias de Barranquilla, la regi\xc3\xb3n Caribe, Colombia y el mundo - ELHERALDO.CO">\r\n\t\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t<meta property="og:url" content="https://www.elheraldo.co/home">\r\n\t\t\t\t\t<meta property="og:description" content="Noticias de Barranquilla, la regi\xc3\xb3n Caribe, Colombia y el mundo: \xc3\x9altimas noticias en deportes, junior, f\xc3\xbatbol, econom\xc3\xada, pol\xc3\xadtica y tecnolog\xc3\xada. Mant\xc3\xa9ngase informado en ELHERALDO.CO">\r\n\t\t\t\t\r\n\t\t\t\t<meta property="og:locale:alternate" content="es_CO" />\r\n\t\t\t\t<meta property="og:locale" content="es_LA" />\r\n\t\t\t\t<meta property="og:country_name" content="Colombia" />\r\n\t\t\t\t<meta property="og:region" content="Barranquilla" />\r\n\r\n\t\t\t\t<meta name="url" content="https://www.elheraldo.co/home">\r\n\t\t\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n\r\n\t\t\t\t<meta property="fb:admins" content="100002164552872">\r\n\t\t\t\t<meta property="fb:app_id" content="137584700113014">\r\n\t\t\t\t<meta property="fb:pages" content="124906244202182">\r\n\t\t\t\t<meta property="genre" content="News">\r\n\r\n\t\t\t\t<meta property="geo.placename" content="Colombia">\r\n\t\t\t\t<meta property="geo.position" content="10.9897177,-74.791122">\r\n\t\t\t\t<meta property="geo.region" content="CO">\r\n\t\t\t\t<meta property="google" content="notranslate">\r\n\t\t\t\t<meta property="ICBM" content="10.9897177,-74.791122">\r\n\r\n\t\t\t\t<meta http-equiv=\'cache-control\' content=\'no-cache\' />\r\n\t\t\t\t<meta http-equiv=\'expires\' content=\'0\' />\r\n\t\t\t\t<meta http-equiv=\'pragma\' content=\'no-cache\' />\r\n\r\n\t\t\t\t<meta property="twitter:card" content="summary_large_image">\r\n\t\t\t\t<meta property="twitter:creator" content="@elheraldoco">\r\n\t\t\t\t\t\t\t\t\t\t<meta property="twitter:description" content="Noticias de Barranquilla, la regi\xc3\xb3n Caribe, Colombia y el mundo: \xc3\x9altimas noticias en deportes, junior, f\xc3\xbatbol, econom\xc3\ ...

# %% [markdown]
# Como habrás visto, esto trae un código que es difícil de leer para nosotros, pero que los navegadores (como Chrome o Firefox) comprenden y utilizan para pintar las páginas web tal y como las vemos.
#
# A nosotros no nos interesan todas las páginas, sino secciones específicas de noticias que podamos tomar. Para esto, debemos entender de manera general cómo está la página creada. Específicamente, vamos a buscar la sección horizontal de noticias en la parte superior, que tiene como id **widget_eh_horizontal_4_noticias**. Utilizamos otra librería, *BeautifulSoup* para acceder fácilmente a las secciones de la página.
#
# Pide ayuda a tu docente si aún tienes dudas sobre cómo encontramos esta palabra clave ( *widget_eh_horizontal_4_noticias* )

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, "html.parser")

results = soup.find(id="widget_eh_horizontal_4_noticias")

print(results)
# Out:
# <section class="widget-not" id="widget_eh_horizontal_4_noticias">
# <h1 class="titulo-bloque-seccion">
# <a href="/elecciones-2022">
# 				Lo que piden las regiones			</a>
# </h1>
# <div class="content-items">
# <article class="item foto-titulo">
# <div class="image">
# <a class="icon icon-articulo 892608-widget" data-id="892608" href="/cesar/mas-oportunidades-y-menos-promesas-lo-que-exigen-en-el-cesar-892608" id="192491-widget"><picture><source media="(min-width: 768px)" srcset="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/03/06/cesar_1_1.jpg?itok=VgpBgTcV"/><source media="(max-width: 767px)" srcset="https://www.elheraldo.co/sites/default/files/styles/380x214/public/articulo/2022/03/06/cesar_1_1.jpg?itok=c3ZlQXh2"/><img alt="“Más oportunidades y menos promesas”: lo que exigen en el Cesar" loading="lazy" src="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/03/06/cesar_1_1.jpg?itok=VgpBgTcV"/></picture>
# </a> </div>
# <div class="text">
# <div class="datos">
# <span class="tag">Elecciones 2022</span>
# <time datetime="2022-03-07 00:00:00">Mar 07, 2022</time>
# </div>
# <h1><a href="/cesar/mas-oportunidades-y-menos-promesas-lo-que-exigen-en-el-cesar-892608">“Más oportunidades y menos promesas”: lo que exigen en el Cesar</a></h1>
# </div>
# </article>
# <article class="item foto-titulo">
# <div class="image">
# <a class="icon icon-articulo 890994-widget" data-id="890994" href="/politica/lo-que-le-exigen-los-sucrenos-los-candidatos-politicos-890994" id="359136-widget"><picture><source media="(min-width: 768px)" srcset="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/02/27/4c_elecciones.jpg?itok=KNLAO8vd"/><source media="(max-width: 767px)" srcset="https://www.elheraldo.co/sites/default/files/styles/380x214/public/articulo/2022/02/27/4c_elecciones.jpg?itok=kK_YZnxo"/><img alt="Lo que le exigen los sucreños a los candidatos políticos" loading="lazy" src="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/02/27/4c_elecciones.jpg?itok=KNLAO8vd"/></picture>
# </a> </div>
# <div class="text">
# <div class="datos">
# <span class="tag">Sucre</span>
# <time datetime="2022-02-28 00:00:00">Feb 28, 2022</time>
# </div>
# <h1><a href="/politica/lo-que-le-exigen-los-sucrenos-los-candidatos-politicos-890994">Lo que le exigen los sucreños a los candidatos políticos</a></h1>
# </div>
# </article>
# <article class="item foto-titulo">
# <div class="image">
# <a class="icon icon-articulo 887316-widget" data-id="887316" href="/politica/la-guajira-el-crudo-escenario-social-que-rodea-las-elecciones-887316" id="271341-widget"><picture><source media="(min-width: 768px)" srcset="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/02/12/shutterstock_356863136.jpg?itok=IODK_3qB"/><source media="(max-width: 767px)" srcset="https://www.elheraldo.co/sites/default/files/styles/380x214/public/articulo/2022/02/12/shutterstock_356863136.jpg?itok=WIZNeH-T"/><img alt="La Guajira: el crudo escenario social que rodea a las elecciones" loading="lazy" src="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/02/12/shutterstock_356863136.jpg?itok=IODK_3qB"/></picture>
# </a> </div>
# <div class="text">
# <div class="datos">
# <span class="tag">La Guajira</span>
# <time datetime="2022-02-13 00:00:00">Feb 13, 2022</time>
# </div>
# <h1><a href="/politica/la-guajira-el-crudo-escenario-social-que-rodea-las-elecciones-887316">La Guajira: el crudo escenario social que rodea a las elecciones</a></h1>
# </div>
# </article>
# <article class="item foto-titulo">
# <div class="image">
# <a class="icon icon-articulo 885523-widget" data-id="885523" href="/politica/cordoba-lo-que-exigen-sus-habitantes-los-candidatos-885523" id="588711-widget"><picture><source media="(min-width: 768px)" srcset="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/02/05/elecciones_1.jpg?itok=X9aKBGld"/><source media="(max-width: 767px)" srcset="https://www.elheraldo.co/sites/default/files/styles/380x214/public/articulo/2022/02/05/elecciones_1.jpg?itok=E9URCJLz"/><img alt="Córdoba: lo que exigen sus habitantes a los candidatos" loading="lazy" src="https://www.elheraldo.co/sites/default/files/styles/384x216/public/articulo/2022/02/05/elecciones_1.jpg?itok=X9aKBGld"/></picture>
# </a> </div>
# <div class="text">
# <div class="datos">
# <span class="tag">El caribe decide</span>
# <time datetime="2022-02-06 00:00:00">Feb 06, 2022</time>
# </div>
# <h1><a href="/politica/cordoba-lo-que-exigen-sus-habitantes-los-candidatos-885523">Córdoba: lo que exigen sus habitantes a los candidatos</a></h1>
# </div>
# </article>
# </div>
# </section>

# %% [markdown]
# Esta nueva impresión nos muestra los datos muchos más organizados, y nos permite incluso ver ya algunas noticias que estaban en ésa sección.
#
# El tercer paso es sacar cada pedacito de información de cada noticia. Para esto, usamos la función **find_all** y buscamos todas las estructuras de tipo "div" que tengan la palabra clave "text". Luego, lo recorremos con un ciclo for para tomar cada pedacito.

# %%
noticias = results.find_all("div", class_="text")

for noticia in noticias:
    
    titulo = noticia.find("h1")
    etiqueta = noticia.find("span", class_="tag")
    fecha = noticia.find("time")
    print(titulo.text)
    print(etiqueta.text)
    print(fecha.text)
    print()
# Out:
# “Más oportunidades y menos promesas”: lo que exigen en el Cesar
# Elecciones 2022
# Mar 07, 2022
#
# Lo que le exigen los sucreños a los candidatos políticos
# Sucre
# Feb 28, 2022
#
# La Guajira: el crudo escenario social que rodea a las elecciones
# La Guajira
# Feb 13, 2022
#
# Córdoba: lo que exigen sus habitantes a los candidatos
# El caribe decide
# Feb 06, 2022

# %% [markdown]
# ## Actividades
# Extrae las noticias de una sección diferente en El Heraldo.

# %% [markdown]
# ### Otro Ejemplo...
# Un uso común que le dan al Web Scraping es buscar los precios de ciertos productos en páginas específicas.
#
# Por ejemplo, podemos usar la siguiente URL para traer los precios de diferentes audífonos en Mercado Libre.

# %%
URL = "https://listado.mercadolibre.com.co/audifonos#D[A:audifonos]"
page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="es-CO">
# <head><link rel="preconnect" href="https://www.google-analytics.com"/><link rel="preconnect" href="https://www.google.com"/><link rel="preconnect" href="https://data.mercadolibre.com"/><link rel="preconnect" href="https://http2.mlstatic.com"/><link rel="preconnect" href="https://stats.g.doubleclick.net"/><link rel="preconnect" href="https://analytics.mercadolibre.com.co"/><link rel="preconnect" href="https://analytics.mercadolibre.com"/><link rel="preconnect" href="https://www.google.com.co"/><script type='text/javascript' >window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"3009922991","applicationID":"408441092","applicationTime":1557.2441760000002,"transactionName":"YlZQYEVZC0QEV0BZV1scd0xHSgBEFl5HH39wZx0bHQ==","queueTime":0,"ttGuid":"2dec517cac74361a","agentToken":null}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"XQ4OVF5VGwcAXFVWBgEOVA==",licenseKey:"3009922991",applicationID:"408441092"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(32),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(33),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v ...
# <meta charSet="utf-8"/>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0"/>
# <meta name="HandheldFriendly" content="True"/>
# <meta http-equiv="cleartype" content="on"/>
# <meta name="browser-support" content="samesite=true"/>
# <meta name="csrf-token" content="i4HkEUZT-81T1quIFPHPgmLoqjF-jbJLQHfQ" />
# <link rel="preload" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2" as="font" type="font/woff2" crossorigin="anonymous" data-head-react="true"/><link rel="preload" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2" as="font" type="font/woff2" crossorigin="anonymous" data-head-react="true"/><link rel="preload" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2" as="font" type="font/woff2" crossorigin="anonymous" data-head-react="true"/><style data-head-react="true">@font-face{font-family:'Proxima Nova';font-weight:300;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:400;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:600;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.ttf) format("truetype")}</style><link href="https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/favicon.svg" rel="icon" data-head-react="true"/><link href="https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/180x180.png" rel="apple-touch-icon" data-head-react="true"/><script type="application/ld+json">{"@context":"https:\u002F\u002Fschema.org","@graph":[{"@type":"SearchResultsPage","id":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos","name":"Audifonos","about":"Envíos Gratis en el día ✓ Compre Audifonos en cuotas sin interés! Conozca nuestras increíbles ofertas y promociones en millones de productos."},{"@type":"ItemList","id":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos\u002F#itemList","numberOfItems":1,"itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Product","name":"Audífonos in-ear inalámbricos Xiaomi Redmi AirDots 2 negro","url":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos","aggregateRating":{"@type":"AggregateRating","ratingCount":539,"bestRating":5,"ratingValue":4.2,"worstRating":1},"offers":{"@type":"AggregateOffer","price":74000,"lowPrice":74000,"priceCurrency":"COP","offerCount":1,"availability":"https:\u002F\u002Fschema.org\u002FInStock","itemCondition":"https:\u002F\u002Fschema.org\u002FNewCondition"},"brand":{"@type":"Brand","name":"Xiaomi"}}}]}]}</script><link rel="preconnect" href="https://securepubads.g.doubleclick.net" data-head-react="true"/><link rel="preconnect" href="https://www.googletagservices.com" data-head-react="true"/><title>Audifonos | MercadoLibre 📦</title><meta name="description" content="Envíos Gratis en el día ✓ Compre Audifonos en cuotas sin interés! Conozca nuestras increíbles ofertas y promociones en millones de productos." data-head-react="true"/><link rel="canonical" href="https://listado.mercadolibre.com.co/audifonos" data-head-react="true"/><link rel="alternate" href="android-app://com.mercadolibre/meli/search?go=https://listado.mercadolibre.com.co/audifonos" data-head-react="true"/><link rel="alternate" href="ios-app://463624852/meli/search?go=https://listado.mercadolibre.com.co/audifonos" data-head-react= ...
# <style media="(min-width: 1024px)">@charset "UTF-8";/*!
#  * Navigation
#  * @platform "mercadolibre"
#  * @site "MCO"
#  * @version 5.18.9
#  * @author MercadoLibre.com
#  */[role=main],body,html{height:100%}.nav-footer-access-content [href*='twitter.com'],.nav-footer-access-content [href*='facebook.com'],.nav-footer-access-content [href*='plus.google.com'],.nav-footer-access-content [href*='youtube.com'],.nav-footer-access-content [href*='instagram.com'],[class*=' nav-icon-'],[class^=nav-icon-]{font-style:normal}@font-face{font-family:navigation;src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot);src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot#iefix) format("embedded-opentype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff2) format("woff2"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff) format("woff"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.ttf) format("truetype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.svg#navigation) format("svg");font-weight:400;font-style:normal}[class*=' nav-icon-']:before,[class^=nav-icon-]:before{font-variant:normal;margin:0;speak:none;text-align:center;width:1em;text-rendering:auto;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;font-family:navigation}.nav-header .nav-header-btn:before,.nav-icon-back-o:before{content:'\EA01'}#nav-header-menu a.option-bookmarks:after,.nav-icon-bookmarks-o:before{content:'\EA02'}.nav-icon-bookmarks:before{content:'\EA03'}.nav-icon-chevron-right-o:before{content:'\EA04'}.nav-icon-chevron-right:before{content:'\EA05'}.nav-icon-chevron-up-o:before{content:'\EA06'}.nav-icon-chevron-up:before{content:'\EA07'}.nav-icon-close:before{content:'\EA08'}.nav-icon-facebook:before{content:'\EA09'}.nav-icon-gplus:before{content:'\EA0A'}#nav-header-menu a.option-help:after,.nav-icon-help-o:before{content:'\EA0B'}.nav-icon-help:before{content:'\EA0C'}.nav-icon-instagram:before{content:'\EA0D'}#nav-header-menu a.option-login:after,.nav-icon-login-o:before{content:'\EA0E'}#nav-header-menu a.option-logout:after,.nav-icon-logout-o:before{content:'\EA0F'}.nav-icon-logout:before{content:'\EA10'}#nav-header-menu a.option-notifications:after,.nav-icon-notifications-o:before{content:'\EA11'}.nav-icon-notifications:before{content:'\EA12'}.nav-icon-official-store-o:before{content:'\EA13'}#nav-header-menu a.option-register:after,.nav-icon-register-o:before{content:'\EA14'}.nav-icon-search-o:before{content:'\EA15'}.nav-icon-search:before{content:'\EA16'}#nav-header-menu a.option-sell:after,.nav-icon-sell-o:before{content:'\EA17'}.nav-icon-time-o:before{content:'\EA18'}.nav-icon-twitter:before{content:'\EA19'}#nav-header-menu a.option-my-account:after,.nav-icon-user-o:before{content:'\EA1A'}.nav-icon-user:before{content:'\EA1B'}.nav-icon-youtube:before{content:'\EA1C'}.nav-icon-close-o:before{content:'\EA1D'}.nav-icon-bookmarks-medium:before{content:'\EA1E'}.nav-icon-cart-empty-medium:before{content:'\EA1F'}.nav-icon-phone:before{content:'\EA20'}.nav-cart.nav-cart-empty .nav-icon-cart:before,.nav-icon-cart-empty-small:before{content:'\EA21'}.nav-icon-cart-full-medium:before{content:'\EA22'}.nav-cart.nav-cart-full .nav-icon-cart:before,.nav-icon-cart-full-small:before{content:'\EA23'}.nav-icon-help-medium:before{content:'\EA24'}.nav-icon-notifications-medium:before{content:'\EA25'}.nav-icon-user-medium:before{content:'\EA26'}.nav-icon-search-ml:before{content:'\EA27'}.nav-icon-user-rounded:before{content:'\EA28'}.nav-icon-app:before{content:'\EA29'}.nav-icon-search-plus:before{content:'\EA2A'}.nav-icon-vender-mobile:before{content:'\EA2B'}.nav-icon-bookmarks-mobile:before{content:'\EA2C'}.nav-icon-categories-mobile:before{content:'\EA2D'}.nav-icon-create-account-mobile:before{content:'\EA2E'}.nav-icon-deals-mobile:before{content:'\EA2F'}.nav-icon-download-mobile:before{content:'\EA30'}.nav-icon-help-mobile:before{content:'\EA31'}.nav-icon-history-mobile:before{content:'\EA32'}.nav-icon-logout-mobile:before{content:'\EA33'}. ...
# <style media="(max-width: 1023px)">@charset "UTF-8";/*!
#  * Navigation
#  * @platform "mercadolibre"
#  * @site "MCO"
#  * @version 5.18.9
#  * @author MercadoLibre.com
#  */[role=main],body,html{height:100%}@font-face{font-family:navigation;src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot);src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot#iefix) format("embedded-opentype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff2) format("woff2"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff) format("woff"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.ttf) format("truetype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.svg#navigation) format("svg");font-weight:400;font-style:normal}[class*=' nav-icon-'],[class^=nav-icon-]{font-style:normal}[class*=' nav-icon-']:before,[class^=nav-icon-]:before{display:inline-block;font-variant:normal;margin:0;speak:none;text-align:center;width:1em;text-rendering:auto;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;font-family:navigation}.nav-header .nav-header-btn:before,.nav-icon-back-o:before{content:'\EA01'}#nav-header-menu a.option-bookmarks:after,.nav-icon-bookmarks-o:before{content:'\EA02'}.nav-icon-bookmarks:before{content:'\EA03'}.nav-icon-chevron-right-o:before{content:'\EA04'}.nav-icon-chevron-right:before{content:'\EA05'}.nav-icon-chevron-up-o:before{content:'\EA06'}.nav-icon-chevron-up:before{content:'\EA07'}.nav-icon-close:before{content:'\EA08'}.nav-icon-facebook:before{content:'\EA09'}.nav-icon-gplus:before{content:'\EA0A'}#nav-header-menu a.option-help:after,.nav-icon-help-o:before{content:'\EA0B'}.nav-icon-help:before{content:'\EA0C'}.nav-icon-instagram:before{content:'\EA0D'}#nav-header-menu a.option-login:after,.nav-icon-login-o:before{content:'\EA0E'}#nav-header-menu a.option-logout:after,.nav-icon-logout-o:before{content:'\EA0F'}.nav-icon-logout:before{content:'\EA10'}#nav-header-menu a.option-notifications:after,.nav-icon-notifications-o:before{content:'\EA11'}.nav-icon-notifications:before{content:'\EA12'}.nav-icon-official-store-o:before{content:'\EA13'}#nav-header-menu a.option-register:after,.nav-icon-register-o:before{content:'\EA14'}.nav-icon-search-o:before{content:'\EA15'}.nav-icon-search:before{content:'\EA16'}#nav-header-menu a.option-sell:after,.nav-icon-sell-o:before{content:'\EA17'}.nav-icon-time-o:before{content:'\EA18'}.nav-icon-twitter:before{content:'\EA19'}#nav-header-menu a.option-my-account:after,.nav-icon-user-o:before{content:'\EA1A'}.nav-icon-user:before{content:'\EA1B'}.nav-icon-youtube:before{content:'\EA1C'}.nav-icon-close-o:before{content:'\EA1D'}.nav-icon-bookmarks-medium:before{content:'\EA1E'}.nav-icon-cart-empty-medium:before{content:'\EA1F'}.nav-icon-phone:before{content:'\EA20'}.nav-cart.nav-cart-empty .nav-icon-cart:before,.nav-icon-cart-empty-small:before{content:'\EA21'}.nav-icon-cart-full-medium:before{content:'\EA22'}.nav-cart.nav-cart-full .nav-icon-cart:before,.nav-icon-cart-full-small:before{content:'\EA23'}.nav-icon-help-medium:before{content:'\EA24'}.nav-icon-notifications-medium:before{content:'\EA25'}.nav-icon-user-medium:before{content:'\EA26'}.nav-icon-search-ml:before{content:'\EA27'}.nav-icon-user-rounded:before{content:'\EA28'}.nav-icon-app:before{content:'\EA29'}.nav-icon-search-plus:before{content:'\EA2A'}.nav-icon-vender-mobile:before{content:'\EA2B'}.nav-icon-bookmarks-mobile:before{content:'\EA2C'}.nav-icon-categories-mobile:before{content:'\EA2D'}.nav-icon-create-account-mobile:before{content:'\EA2E'}.nav-icon-deals-mobile:before{content:'\EA2F'}.nav-icon-download-mobile:before{content:'\EA30'}.nav-icon-help-mobile:before{content:'\EA31'}.nav-icon-history-mobile:before{content:'\EA32'}.nav-icon-logout-mobile:before{content:'\EA33'}.nav-icon-my-account-mobile:before{content:'\EA34'}.nav-icon-navigation-mobile:before{content:'\EA35'}.nav-icon-notifications-mobile:before{content:'\EA36'}.nav-icon-points-mobile:before{content:'\EA37'}.nav-icon-purchases-mobile:be ...
# <style>a.nav-skip-to-main-content{border:0;border-bottom-left-radius:4px;border-bottom-right-radius:4px;position:absolute;color:#fff;font-weight:100;text-decoration:none;text-align:center;background:#3484fa;top:0;left:0;z-index:999;cursor:pointer;height:0;padding:0;line-height:normal}a.nav-skip-to-main-content:focus{border:1px solid #3484fa;height:54px;padding:8px 8px}.nav-skip-to-main-content>.nav-skip-to-main-content__content{display:none}.nav-skip-to-main-content:focus>.nav-skip-to-main-content__content{display:block;padding:8px;border:1px solid #fff;border-radius:4px}</style>
# <link href="https://http2.mlstatic.com/frontend-assets/search-nordic/search.desktop.c22a72d7.css" rel="stylesheet" type="text/css" onerror="(window['_pfl'] = window['_pfl'] || []).push(['css', this.href])" />
#
# <script>
# (function(win, doc) {
#
# function preloadCriticalPath() {
#   var head = doc.getElementsByTagName('head')[0],
#       assets = ["https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/navigation-desktop-MCO.css","https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/navigation-mobile-MCO.css"],
#       link,
#       i;
#   for(i = 0; i < assets.length; i++) {
#     link = doc.createElement('link');
#     link.rel = 'prefetch';
#     link.href = assets[i];
#     link.onerror = function(e) {
#       (window['_pfl'] = window['_pfl'] || []).push(['css', e.target.href]);
#     }
#     head.appendChild(link);
#   }
# }
#   if (doc.readyState === 'complete') {
#     setTimeout(preloadCriticalPath, 0);
#   } else {
#     win.addEventListener('load', function() {
#       preloadCriticalPath();
#     });
#   }
# })(window, document);
# </script>
# <script>
# (function(a,b){a.GoogleAnalyticsObject=b;a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};a[b].l=1*new Date})(window,"meli_ga");
# meli_ga("set", "title", "app-search-nordic-nodejs-3.1.1");
# meli_ga("set", "page", "/SEARCH/LISTING/?q=audifonos");
# meli_ga("set", "dimension49", "MCO812367769,MCO618049088,MCO618542478,MCO613267539,MCO652324942,MCO613173279,MCO657809856,MCO618060363,MCO621222310,MCO643708663,MCO658984720,MCO860197401,MCO867220824,MCO866606051,MCO618050413,MCO640578413,MCO843371332,MCO618050281,MCO832876490,MCO862601588,MCO860956693,MCO613258796,MCO855935558,MCO865030065,MCO805848514,MCO646972630,MCO548576541,MCO621221511,MCO835953622,MCO630688159,MCO867220824,MCO855870969,MCO616477825,MCO866836562,MCO619299293,MCO623226653,MCO658983752,MCO487282431,MCO839245641,MCO658983657,MCO468795741,MCO800704856,MCO851248363,MCO857659492,MCO855581572,MCO857573183,MCO614941053,MCO844123932,MCO613185957,MCO561405885,MCO614532740,MCO856079201,MCO652325407,MCO621342714");
# meli_ga("set", "dimension86", "MCO-HEADPHONES,MCO-TABLETS,MCO-NOTEBOOKS,MCO-TELEPHONES,MCO-CELLPHONE_ACCESSORIES,MCO-CELLPHONE_COVERS");
# meli_ga("set", "dimension117", "PDP+officialStore");
# meli_ga("set", "dimension22", "224257");
# meli_ga("set", "dimension9", "NONE");
# meli_ga("set", "dimension23", "SEO-allowlist: in - SEARCH-noindex: false");
# meli_ga("set", "dimension21", "119");
# meli_ga("set", "dimension25", "{'frontend/assetsCdnDomainMCO':'DEFAULT','searchbackend/recommended-products':'6158','search/new-search-api':'8650','searchbackend/cbt-antiboost':'6333','mclics/show-pads-search-list':'5146','mclics/pseudo-search-buybox-query':'9461','mclics/show-pads-global':'5176','mclics/pseudo-search-pads-buybox':'7708','mclics/search-list-algorithms':'5528','frontend/assetsCdnDomainMLU':'DEFAULT'}");
# meli_ga("set", "dimension7", "MARKETPLACE");
# meli_ga("set", "dimension8", "CORE");
# meli_ga("set", "dimension48", "NONE");
# meli_ga("set", "dimension113", "17140da4-5d1e-49bf-b7e3-28c4b070a37d");
# meli_ga("set", "contentGroup1", "/MARKETPLACE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup2", "/CORE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup3", "/NONE/SEARCH/LISTING/");
# meli_ga("set", "dimension1", "desktop");
# meli_ga("set", "dimension6", "listing");
# meli_ga("set", "dimension7", "MARKETPLACE");
# meli_ga("set", "dimension8", "CORE");
# meli_ga("set", "dimension25", "{'cookiesConsentBanner':'8415'}");
# meli_ga("send", "pageview");
# (function(d) {
#       var i = d.createElement('iframe');
#       (i.frameElement || i).style.cssText = 'width: 0; height: 0; border: 0; position: absolute';
#       i.src = "about:srcdoc";
#       i.srcdoc="\<script\  src='https://http2.mlstatic.com/analytics/ga/mco-ml-analytics.min.js'>\</script\>";
#       i.id = "GoogleAnalyticsIframe";
#       var w = d.getElementsByTagName('script')[0];
#       w.parentNode.insertBefore(i, w);
#       var doc = i.contentWindow.document;
#       var s = doc.createElement('script');
#       s.type = 'text/javascript';
#       s.text ='window.inDapIF = true;';
#       doc.documentElement.appendChild(s);
#     })(document);
# </script>
# </head><body data-site="ML" data-country="CO"><input type="checkbox" id="nav-header-menu-switch"/><header role="banner" data-siteid="MCO" class="nav-header nav-header-plus"><div class="nav-bounds nav-bounds-with-cart nav-bounds-with-cp"><a id="nav-skip-to-main-content" role="button" href="#root-app" class="nav-skip-to-main-content" tabindex="1" aria-label="Ir al contenido principal"><span class="nav-skip-to-main-content__content">Ir al contenido principal</span></a><a class="nav-logo" href="//www.mercadolibre.com.co" tabindex="2">Mercado Libre Colombia - Donde comprar y vender de todo</a><div class="nav-header-menu-wrapper"><label for="nav-header-menu-switch" aria-controls="nav-header-menu"><span class="hamburger-top-bread"></span><span class="hamburger-patty"></span><span class="hamburger-bottom-bread"></span></label><nav id="nav-header-menu-mobile" class="nav-header-menu-mobile-guest"><div id="nav-header-menu-mobile-content"><div id="nav-header-menu-mobile-user-info" class="nav-header-menu-mobile-guest"><div class="nav-header-menu-mobile-guest-logo"><svg class="nav-header-menu-mobile-guest-icon" width="28" height="35" xmlns="http://www.w3.org/2000/svg"><path d="M27.343 33.706l-1.356.64A13.25 13.25 0 0 0 14 26.75c-5.17 0-9.8 2.988-11.978 7.578l-1.356-.643A14.75 14.75 0 0 1 14 25.25a14.75 14.75 0 0 1 13.343 8.456zM14 21.75C8.063 21.75 3.25 16.937 3.25 11S8.063.25 14 .25 24.75 5.063 24.75 11 19.937 21.75 14 21.75zm0-1.5a9.25 9.25 0 1 0 0-18.5 9.25 9.25 0 0 0 0 18.5zm0-2.5v-1.5a5.25 5.25 0 1 0 0-10.5v-1.5a6.75 6.75 0 0 1 0 13.5z" fill="#BBB" fill-rule="nonzero"></path></svg></div><h3 class="nav-header-menu-mobile-guest-title">Bienvenido</h3><p class="nav-header-menu-mobile-guest-text">Ingresa a tu cuenta para ver tus compras, favoritos, etc.</p><div class="nav-header-menu-mobile-guest-buttons"><a rel="nofollow" class="nav-mobile-button nav-mobile-button-filled" href="https://www.mercadolibre.com/jms/mco/lgz/login?platform_id=ML&amp;go=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos&amp;loginType=explicit">Ingresa</a><a rel="nofollow" class="nav-mobile-button nav-mobile-button-outline" href="https://www.mercadolibre.com.co/registration?confirmation_url=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos">Crea tu cuenta</a></div></div><ul><li><a href="https://www.mercadolibre.com.co#menu-user"><i class="nav-icon-home"></i><span>Inicio</span></a></li><li><a href="https://www.mercadolibre.com.co/ofertas#menu-user"><i class="nav-icon-deals-mobile"></i><span>Ofertas</span></a></li><li><a href="https://www.mercadolibre.com.co/gz/home/navigation#menu-user"><i class="nav-icon-history-mobile"></i><span>Historial</span></a></li><li><a href="https://www.mercadolibre.com.co/ayuda#menu-user"><i class="nav-icon-help-mobile"></i><span>Ayuda / PQR</span></a></li></ul><ul><li><a href="https://www.mercadolibre.com.co/ofertas/supermercado#menu-user"><i class="nav-icon-supermercado"></i><span>Supermercado</span></a></li><li><a href="https://www.mercadolibre.com.co/c/ropa-y-accesorios#menu-user"><i class="nav-icon-moda-mobile"></i><span>Moda</span></a></li><li><a href="https://www.mercadolibre.com.co/ofertas/compras-internacionales#menu-user"><i class="nav-icon-compra-internacional"></i><span>Compra Internacional</span><span class="nav-link-tag">Nuevo</span></a></li><li><a href="https://www.mercadolibre.com.co/tiendas-oficiales#menu-user"><i class="nav-icon-stores-mobile"></i><span>Tiendas oficiales</span></a></li><li><a href="https://www.mercadolibre.com.co/categorias#menu-user"><i class="nav-icon-categories-mobile"></i><span>Categorías</span></a></li></ul><ul><li><a href="https://www.mercadolibre.com.co/resumen#menu-user"><i class="nav-icon-summary-mobile"></i><span>Resumen</span></a></li><li><a href="https://www.mercadolibre.com.co/publicar#menu-user"><i class="nav-icon-vender-mobile"></i><span>Vender</span></a></li></ul><ul><li><a href="https://www.mercadolibre.com.co/l/app#menu-user" id="nav-header-menu-download-mobile"><i class="nav-ico ...
# (function(w, r) {
#   w[r] = w[r] || function() {
#     (w[r].q = w[r].q || []).push(arguments)
#   }
# })(window,'melidata');
# (function(d,u) {
#   if (!document.getElementById("MelidataIframe")) {
#     var i = d.createElement('iframe');
#     (i.frameElement || i).style.cssText = "width: 0; height: 0; border: 0; position: absolute";
#     i.src = "about:srcdoc";
#     i.srcdoc="\<script\  src='" + u + "'>\</script\>";
#     i.id = "MelidataIframe";
#     var t = d.getElementsByTagName('script')[0];
#     t.parentNode.insertBefore(i, t);
#     var doc = i.contentWindow.document;
#     var script = doc.createElement('script');
#     script.type = 'text/javascript';
#     script.text ='window.inDapIF = true;';
#     doc.documentElement.appendChild(script);
#   } else {
#     // This page is charged async via AJAX and inserted into another one who has
#     // already download melidata js lib => Just clean the track
#     melidata("clean");
#   }
# })(document,'https://http2.mlstatic.com/storage/melidata-js-sdk/js/3/0.3.21/melidata.min.js');
#
# melidata("add", "id", "036d69be-323f-41cc-9580-c02d9a88c105");
# melidata("add", "server_id", "036d69be-323f-41cc-9580-c02d9a88c105" );
# melidata("add", "application", {"version":"1.116.0-rc-2","server_hostname":"","server_poolname":"","app_name":"","sdk_version":{"node_version":"4.1.2"},"business":"mercadolibre","site_id":"MCO","secured":{"encrypted":"113fea3e6513856ec418c20713ed50b1:","signature":"eyJhbGciOiJIUzI1NiJ9.eyJ1aWQiOiJhZjMyMjA4Ni1lMThiLTQwNGEtOTBkNC1kNDY2MDAxYzM2ZjgiLCJzaXRlX2lkIjoiTUNPIiwicGxhdGZvcm0iOiIvd2ViL2Rlc2t0b3AifQ.HOe1HPVfliASXTAKlE7b2urX9l6V5aBPAWKyu4VXbiI"}});
# melidata("add", "user", {"uid":"af322086-e18b-404a-90d4-d466001c36f8","user_tags":[]});
# melidata("add", "device", {"platform":"/web/desktop","user_agent":"python-requests/2.25.1"});
# melidata("add", "platform", {"http":{"cookies":{},"headers":{"host":"listado.mercadolibre.com.co","x-device-js":"true","x-platform":"ml","x-d2id":"af322086-e18b-404a-90d4-d466001c36f8"},"http_url":"http://listado.mercadolibre.com.co/audifonos"}});
# melidata("add", "experiments", {"cookiesConsentBanner":8415,"frontend/assetsCdnDomainMCO":"DEFAULT","searchbackend/recommended-products":"6158","search/new-search-api":"8650","searchbackend/cbt-antiboost":"6333","mclics/show-pads-search-list":"5146","mclics/pseudo-search-buybox-query":"9461","mclics/show-pads-global":"5176","mclics/pseudo-search-pads-buybox":"7708","mclics/search-list-algorithms":"5528","frontend/assetsCdnDomainMLU":"DEFAULT"});
# melidata("add", "experiments_timestamp", "2022-03-11T16:35:19.23UTC");
# melidata("add", "event_data", {"query":"audifonos","limit":50,"offset":0,"total":224257,"category_id":"","category_path":[],"sort_id":"relevance","filters":{"notfinalized":"1647017514422"},"available_filters":{},"displayed_filters":[{"id":"shipping_highlighted_fulfillment","name":"Envío","type":"highlighted","position":1,"values_quantity":1},{"id":"shipping_cost_highlighted","name":"Costo de envío","type":"highlighted","position":2,"values_quantity":1},{"id":"SHIPPING_ORIGIN_HIGHLIGHTED","name":"Tipo de compra","type":"highlighted","position":3,"values_quantity":1},{"id":"official_store","name":"Tiendas oficiales","type":"text","position":4,"values_quantity":1},{"id":"category","name":"Categorías","type":"text","position":5,"values_quantity":47},{"id":"installments","name":"Pago","type":"text","position":6,"values_quantity":1},{"id":"shipping_cost","name":"Costo de envío","type":"text","position":7,"values_quantity":1},{"id":"shipping","name":"Envío","type":"text","position":8,"values_quantity":2},{"id":"ITEM_CONDITION","name":"Condición","type":"STRING","position":9,"values_quantity":3},{"id":"state","name":"Ubicación","type":"text","position":10,"values_quantity":29},{"id":"price","name":"Precio","type":"range","position":11,"values_quantity":3},{"id":"discount","name":"Descuentos","type":"numeric","position":12,"values_quantity":6},{"id":"promotion_type","name":"Tipo de promoción","type":"text","position":13,"values_quantity":2},{"id":"BRAND","name":"Marca","type":"STRING","position":14,"values_quantity":796},{"id":"SHIPPING_ORIGIN","name":"Tipo de compra","type":"STRING","position":15,"values_quantity":2},{"id":"power_seller","name":"Filtro por calidad de vendedores","type":"refine_by","position":16,"values_quantity":1},{"id":"accepts_mercadopago","name":"Filtro por MercadoPago","type":"refine_by","position":17,"values_quantity":1}],"autoselected_filters":[],"view_mode":"STACK","results":["MCO812367769","MCO618049088","MCO618542478","MCO613267539","MCO652324942","MCO613173279","MCO657809856","MCO618060363","MCO621222310","MCO643708663","MCO658984720","MCO860197401","MCO867220824","MCO866606051","MCO618050413","MCO640578413","MCO843371332","MCO618050281","MCO860956693","MCO613258796","MCO855935558","MCO865030065","MCO805848514","MCO646972630","MCO548576541","MCO621221511","MCO835953622","MCO855870969","MCO616477825","MCO866836562","MCO619299293","MCO623226653","MCO658983752","MCO487282431","MCO839245641","MCO658983657","MCO468795741","MCO800704856","MCO851248363","MCO857659492","MCO855581572","MCO857573183","MCO614941053","MCO844123932","MCO613185957","MCO561405885","MCO614532740","MCO856079201","MCO652325407","MCO621342714"],"billboards":[],"pads_info":{"blocks_strategy":"B4V2","ids":["MCO17828522","MCO18446994","MCO16269737","MCO16069888"],"item_ids":["MCO832876490","MCO862601588","MCO630688159","MCO867220824"],"discarded_ids":["MCO836145545","MCO613212910"],"printed_ads_prices":[4650000,209900,544902,48000],"discarded_ads_prices":[214755,919902],"results_avg_ads_asp":1097909.83,"results_avg_printed_ads_asp":1363200.5,"results_avg_discarded_ads_asp":567328.5,"results_avg_items_asp":168575.06,"printed_positions":[18,19,29,30],"original_positions":[7,8,18,19,29,30],"empty_positions":[7,8],"suggested_positions":[59,53,216,12,75,188],"original_suggested_positions":[59,53,216,12,75,188],"discarded_original_suggested_positions":[75,188],"printed_original_suggested_positions":[59,53,216,12],"domain_item_position_limit":true,"same_item_position_limit":false,"blocks_sizes":[],"printed_positions_size":4,"productads_factor":1,"domain":"VQCATCORE_LST","strategy":"DP_ADPOTENTIAL_CTRAVG_B4V2_BB_PRODUCT_BIDBSMULT","is_api_migrated":false},"catalog_product_id":"","backend_data":{"stems":["AURICULAR","AUDIFON"],"aa":[],"ab":"719","fsm":"50F","ac":["syn1","mcv-20","qwvG","qpE","s1","epq","pa","qpci","mc1"],"qas":[],"ab_bucket":["rpsv1","cbtoff"],"request_flow":{"origin":"backend"},"fbm_ids":[],"processed_query":"AUDIFONOS","ap":[]},"promis ...
# melidata("send", "view", {
#   path: "/search",
#   data: {}
# }, "melidata");</script>
# <script>
# (function(win, doc){
#   function loadScripts (s) {
#     if (!s || !s.length) return;
#     s = s.slice(0);
#     var h = doc.head || doc.getElementsByTagName('head')[0];
#     var cbStack = {}; var cbChild = {};
#
#     for (var i = 0; i < s.length; i++) {
#       var c = s[i];
#       var t = doc.createElement('script');
#
#       if (typeof c.s === 'function') {
#         t.textContent = '(' + c.s + ').apply(window);';
#       } else {
#         t.async = false;
#         t.defer = true;
#         t.crossOrigin = 'anonymous';
#         if (c.id) t.id = c.id;
#
#         if (c.s) t.src = c.s;
#         var x = t.src;
#         cbStack[x] = [];
#         while(s[i+1] && typeof s[i+1].s === 'function') {
#           cbStack[x].push(s[i+1].s);
#           i++;
#         }
#         if (typeof c.c === 'function') {
#           cbChild[x] = c.c
#         } else if (c.c) {
#           t.textContent = c.c;
#         }
#         t.onerror = function(err) {
#           cbStack[err.target.src] && cbStack[err.target.src].forEach(function(cb){ (cb).apply(window) });
#
#           var perfillNamespace = '_pfl';
#           (window[perfillNamespace] = window[perfillNamespace] || []).push(['script', err.target.src])
#
#           if (typeof meli_ga !== 'undefined') {
#             meli_ga('send', {
#               hitType: 'event',
#               eventCategory: 'FRONTEND-ERROR',
#               eventAction: 'SCRIPT-LOAD-ERROR',
#               eventLabel: err.target.src,
#               nonInteraction: true,
#             });
#           }
#         }
#         t.onload = function(e) {
#           cbChild[e.target.src] && (cbChild[e.target.src]).apply(window);
#           cbStack[e.target.src] && cbStack[e.target.src].forEach(function(cb){ (cb).apply(window) });
#         }
#       }
#       h.appendChild(t);
#     }
#   }
#   loadScripts([{s:function(){window.__NAVIGATION_PRELOADED_STATE__ = {"application":"search-nordic","siteId":"MCO","domain":"mercadolibre.com.co"};}},{s:function(){"use strict";function track(a){if(a.analytics&&"undefined"!=typeof meli_ga&&meli_ga("send",{hitType:a.analytics.hitType,eventCategory:a.analytics.category,eventAction:a.analytics.action,eventLabel:a.analytics.label}),a.melidata&&"undefined"!=typeof melidata){var b=a.melidata.data;melidata("cleanAndSend",a.melidata.type,{path:a.melidata.path,data:b})}}function navigationEventTracking(a,b,c){var d=document.querySelector(a);d&&d.addEventListener(b,function(){track(c)})}window.__navigation_tracking__=navigationEventTracking,window.__navigation_track__=track;}},{s:function(){"use strict";(function(){window.__navigation_tracking__("#nav-skip-to-main-content","click",{analytics:{category:"SKIP_TO_MAIN_CONTENT",action:"NAVIGATION",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"},melidata:{path:"/navigation/skip-to-main-content",type:"event",data:{app:window.__NAVIGATION_PRELOADED_STATE__.application}}})})();}},{s:function(){"use strict";(function(){window.__navigation_tracking__("#nav-header-menu-download-mobile","click",{analytics:{category:"MOBILE-APP-".concat(window.__NAVIGATION_PRELOADED_STATE__.os),action:"DOWNLOAD-MENU",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"}})})();}},{s:function(){"use strict";(function(){window.__navigation_tracking__("[data-js=cp]","click",{analytics:{category:"CURRENT_LOCATION",action:"NAVIGATION",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"},melidata:{path:"/current_location/navigation/pick",data:{app:window.__NAVIGATION_PRELOADED_STATE__.application},type:"event"}})})();}},{s:function(){(function() {
#     var defaults = {
#         imageLoadClassName: 'lazy-loadable', // 'lazy-loadable' || 'onload-loadable'
#         options: {
#             rootMargin: '360px',
#             loadMode: 'lazy' // 'lazy' || 'onload'
#         }
#     };
#     var dataSrcKey = 'data-src';
#     var dataSrcFallbackKey = 'data-src-fallback';
#     var dataSrcSetKey = 'data-srcset';
#
#     // IntersectionObserver has partial support in chrome <= 57 (https://caniuse.com/#feat=intersectionobserver)
#     var supportIntersectionObserver = 'IntersectionObserver' in window && 'IntersectionObserverEntry' in window && 'isIntersecting' in window.IntersectionObserverEntry.prototype;
#
#   function mergeOptions(target, source) {
#     var list = [target, source];
#     var cloned = {};
#
#     for (var i = 0; i <= list.length; i++) {
#       if (typeof list[i] === 'object' && list[i]) {
#         for (var prop in list[i]) {
#           cloned[prop] = list[i][prop];
#         }
#       }
#     }
#     return cloned;
#   }
#
#   function imageLazyLoading(imageLoadClassName, options) {
#         if (!imageLoadClassName && options && options.loadMode === 'onload') {
#           imageLoadClassName = 'onload-loadable';
#         }
#         imageLoadClassName = imageLoadClassName || defaults.imageLoadClassName;
#
#         options = mergeOptions(defaults.options, options);
#
#         var lazyImages = [].slice.call(document.querySelectorAll('.' + imageLoadClassName));
#
#         function loadImages(img) {
#             function setSource(attr, srcKey, srcFallbackKey) {
#                 if (img.hasAttribute(srcKey)) {
#                     var dataSrc = img.getAttribute(srcKey);
#                     if (srcFallbackKey && img.hasAttribute(srcFallbackKey)) {
#                       var dataSrcFallback = img.getAttribute(srcFallbackKey);
#                       img.onload = function() {
#                         img.removeAttribute(srcFallbackKey);
#                       }
#                       img.onerror = function() {
#                         this.src = dataSrcFallback;
#                         this.srcset = dataSrcFallback;
#                         img.removeAttribute(srcFallbackKey);
#                         img.onerror = null;
#                       };
#                     }
#                     img.setAttribute(attr, dataSrc);
#                     img.removeAttribute(srcKey);
#                 }
#             }
#
#             setSource('src', dataSrcKey, dataSrcFallbackKey);
#             setSource('srcset', dataSrcSetKey);
#
#             img.classList.remove(imageLoadClassName);
#
#             if (img.classList.length < 1) {
#                 img.removeAttribute('class');
#             }
#         }
#
#         function loadAllImages() {
#           lazyImages.forEach(function(image) {
#                 loadImages(image);
#             });
#         }
#
#         if (supportIntersectionObserver && options.loadMode === 'lazy') {
#             var lazyImageObserver = new IntersectionObserver(function(entries, observer) {
#                 entries.forEach(function(entry) {
#                 if (entry.isIntersecting) {
#                     var lazyImage = entry.target;
#                     loadImages(lazyImage);
#                     lazyImageObserver.unobserve(lazyImage);
#                 }
#                 });
#             }, options);
#
#             lazyImages.forEach(function(lazyImage) {
#                 lazyImageObserver.observe(lazyImage);
#             });
#
#             window.lazyImageObserver = lazyImageObserver;
#
#         } else if ((!supportIntersectionObserver && options.loadMode === 'lazy') || options.loadMode === 'onload') {
#             if (document.readyState === 'complete') {
#                 loadAllImages();
#             } else {
#                 window.addEventListener('load', function() {
#                     loadAllImages();
#                 });
#             }
#         }
#     }
#
#     function initLazyLoading() {
#       imageLazyLoading();
#       imageLazyLoading('onload-loadable', { loadMode: 'onload' });
#     }
#
#     window.imageLazyLoading = imageLazyLoading;
#     initLazyLoading();
# }());
# }}]);
#   var scripts = [{s:function(){(function(){var ccb=function(e){var n={};function t(o){if(n[o])return n[o].exports;var a=n[o]={i:o,l:!1,exports:{}};return e[o].call(a.exports,a,a.exports,t),a.l=!0,a.exports}return t.m=e,t.c=n,t.d=function(e,n,o){t.o(e,n)||Object.defineProperty(e,n,{enumerable:!0,get:o})},t.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},t.t=function(e,n){if(1&n&&(e=t(e)),8&n)return e;if(4&n&&"object"==typeof e&&e&&e.__esModule)return e;var o=Object.create(null);if(t.r(o),Object.defineProperty(o,"default",{enumerable:!0,value:e}),2&n&&"string"!=typeof e)for(var a in e)t.d(o,a,function(n){return e[n]}.bind(null,a));return o},t.n=function(e){var n=e&&e.__esModule?function(){return e.default}:function(){return e};return t.d(n,"a",n),n},t.o=function(e,n){return Object.prototype.hasOwnProperty.call(e,n)},t.p="",t(t.s=0)}([function(e,n,t){e.exports=t(1)},function(e,n,t){function o(e,n){var t=Object.keys(e);if(Object.getOwnPropertySymbols){var o=Object.getOwnPropertySymbols(e);n&&(o=o.filter((function(n){return Object.getOwnPropertyDescriptor(e,n).enumerable}))),t.push.apply(t,o)}return t}function a(e){for(var n=1;n<arguments.length;n++){var t=null!=arguments[n]?arguments[n]:{};n%2?o(Object(t),!0).forEach((function(n){c(e,n,t[n])})):Object.getOwnPropertyDescriptors?Object.defineProperties(e,Object.getOwnPropertyDescriptors(t)):o(Object(t)).forEach((function(n){Object.defineProperty(e,n,Object.getOwnPropertyDescriptor(t,n))}))}return e}function c(e,n,t){return n in e?Object.defineProperty(e,n,{value:t,enumerable:!0,configurable:!0,writable:!0}):e[n]=t,e}var r=t(2),i=t(3).bannerOptOutModalEvents;e.exports=function(e,n,t,o,c,s){var l=arguments.length>6&&void 0!==arguments[6]?arguments[6]:"cookie-consent-banner",u=arguments.length>7?arguments[7]:void 0,d=l,f="cookie-consent-snackbar--success",v="cookie-consent-snackbar--error",p="cookies-banner-top-content",m=function(n,t){var o=(t||e).getElementsByClassName(n);if(0===o.length)throw new Error("No element with class ".concat(n," is present"));if(1!==o.length)throw new Error("More than one element with class ".concat(n," is present"));return o[0]},_=function(e){return e.parentNode.removeChild(e)},b=function(){try{return m(p,m(d))}catch(e){return null}},y=function(e,n,t){var o=m(n);_(o);var a=m(e);t&&a.appendChild(t),a.classList.remove("cookie-consent-snackbar--hidden"),setTimeout((function(){return a.classList.remove("cookie-consent-snackbar--collapsed")})),m("cookie-consent-snackbar__close",a).addEventListener("click",(function(){a.classList.add("cookie-consent-snackbar--collapsed"),setTimeout((function(){_(a),window.onCookieConsentBannerClosed&&window.onCookieConsentBannerClosed()}),400)}))},E=function(e){return y(f,v,e)},k=function(e){return y(v,f,e)},h=function(t,c){if(o)try{var r={categories:a(a({},n),t)};o.userId&&(r.userId=o.userId);var i=o.cookieName,s=o.maxAge,l=o.path,u=o.domain,d=o.secure,f=o.sameSite,v=["".concat(i,"=").concat(encodeURIComponent(JSON.stringify(r))),"domain=".concat(u),"path=".concat(l)].concat(s?"max-age=".concat(s):[]).concat(f?"samesite=".concat(f):[]).concat(d?"secure":[]).join("; ");e.cookie=v}catch(e){k(c)}E(c)},g=function(e){if(!t)return h(null,e),void r(n);try{var o=new window.XMLHttpRequest;o.open("PUT",t.url,!0),o.setRequestHeader("Content-type","application/json;charset=UTF-8"),o.withCredentials=!0,o.onreadystatechange=function(){if(4===o.readyState)if(200===o.status){var t;try{t=JSON.parse(o.responseText).cookies_preferences}catch(e){t=null}h(t,e),r(a(a({},n),t))}else k(e)},o.send(JSON.stringify(a(a({},t.payload),{},{cookies_preferences:n})))}catch(n){k(e)}},w=m("".concat(d,"__action--key-accept")),O=m("".concat(d,"__action--key-customize")),C=function(e,n){"undefined"!=typeof melidata&&melidata("cleanAndSend",e,n)};w.addEventListener("click",(function(){var e=b();try{g(e),C("event",{path:"/navigation/cookies_con ...
# ccb(document,{"advertising":true},null,{"userId":null,"cookieName":"cookiesPreferencesNotLogged","path":"/","domain":"mercadolibre.com.co","secure":true,"sameSite":"none","maxAge":31536000},"bottomOptOut",{"closeElements":[]},"cookie-consent-banner-opt-out",{"openButton":"cookie-consent-banner-opt-out__action--key-customize","wrapper":"cookie-consent-banner-opt-out__modal","iframeUrl":"https://www.mercadolibre.com.co/privacy-preferences/cookies","saveText":"Guardar"});})()}},{s:function(){
#       !function(n,e){n.mitt=e()}(this,function(){function n(n){return n=n||Object.create(null),{on:function(e,t){(n[e]||(n[e]=[])).push(t)},off:function(e,t){n[e]&&n[e].splice(n[e].indexOf(t)>>>0,1)},emit:function(e,t){(n[e]||[]).map(function(n){n(t)}),(n["*"]||[]).map(function(n){n(e,t)})}}}return n});
#       window.freya = mitt();
#     }},{s:"https://http2.mlstatic.com/ui/searchbox/2.7.0/index.js",c:function(){
#       if (window.Searchbox) {
#         new window.Searchbox('.nav-search-input', {
#           platformId: 'ML',
#           siteId: 'MCO',
#           siteDomain: 'mercadolibre.com.co',
#           limit: 6,
#           searchEndpoint: 'https://listado.mercadolibre.com.co/$query',
#           categoryEndpoint: 'null',
#           categoryCheckbox: document.getElementById('categorySearch'),
#           loggedIn: false,
#
#           bus: window.freya,
#           deviceType: 'desktop'
#         });
#       }
#     }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/modal/v1.0.6/modal.js"},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/onboarding-cp/v1.0.15/onboarding-cp.js",c:function(){(function () {
#           new window.OnboardingCP({
#             bus: window.meli,
#             isNewBuyer: true,
#             isMobile: false,
#             trigger: '.nav-menu-cp',
#             locale: 'es_CO',
#             domain: 'mercadolibre.com.co',
#             siteId: 'MCO',
#             isInferred: false,
#           });
#         }());
#     }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/categories/v1.3.2/categories.js",c:function(){
#       (function(win, freya) {
#         if (win.CategoriesWidget && typeof freya !== 'undefined') {
#           new CategoriesWidget({
#             bus: freya,
#             endpoint: '//www.mercadolibre.com.co/menu/departments',
#           });
#         }
#       })(window, window.freya);
#     }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/nav-cart/v1.5.4/CartWidget.js",c:function(){
#         if (window.CartWidget) {
#           new window.CartWidget({
#             element: document.getElementById('nav-cart'),
#             endpoints: {
#               get: 'https://www.mercadolibre.com.co/gz/cart/info',
#               post: 'https://www.mercadolibre.com.co/gz/cart/api/item',
#             },
#             link: 'https://www.mercadolibre.com.co/gz/cart',
#             isMobile: false,
#             bus: freya,
#             locale: 'es',
#           });
#         }
#         }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/snackbar/v1.0.1/snackbar.js",c:function(){
#         (function (win, freya) {
#           if (win.SnackbarWidget && typeof freya !== 'undefined') {
#             new win.SnackbarWidget({
#               bus: freya,
#             });
#           }
#         }(window, window.freya));
#         }},{s:function(){!function(e,t){function n(){var n=setInterval(function(){try{var c=Math.max(t.body.scrollHeight,t.body.offsetHeight,t.documentElement.clientHeight,t.documentElement.scrollHeight,t.documentElement.offsetHeight),o=e.pageYOffset||t.documentElement.scrollTop||t.body.scrollTop||0;e.innerHeight+o>=c?clearInterval(n):e.scrollBy(0,20)}catch(e){clearInterval(n)}},15)}var c=t.getElementById("nav-footer-access-switch");e.addEventListener&&c&&c.addEventListener("change",function(){this.checked||setTimeout(n,200)})}(window,document);}},{s:"https://http2.mlstatic.com/storage/tag-manager/google-gtag-search-mco.js"},{s:function(){"use strict";(function(a){var b=a.location.hostname.substr(a.location.hostname.indexOf("."),a.location.hostname.length);if(-1!==b.indexOf("mercadolibre")||-1!==b.indexOf("mercadolivre")||-1!==b.indexOf("mercadopago")){var c="https://matt"+b,d=a.location.href;if(c=c.concat("?go=").concat(encodeURIComponent(d)),navigator&&navigator.sendBeacon)status=navigator.sendBeacon(c);else{var e=new XMLHttpRequest;e.open("GET",c),e.send()}}})(window);}},{s:function(){
#           window.__PRELOADED_STATE__ =
#       {"siteId":"MCO","cookies":{},"lowEnd":false,"deviceType":"desktop","country":{"id":"CO","name":"Colombia","locale":"es_CO","currency_id":"COP","decimal_separator":",","thousands_separator":".","time_zone":"GMT-05:00","geo_information":{"location":{"latitude":4.570868,"longitude":-74.29733}},"states":[{"id":"CO-AMA","name":"Amazonas"},{"id":"CO-ANT","name":"Antioquia"},{"id":"CO-ARA","name":"Arauca"},{"id":"CO-ATL","name":"Atlantico"},{"id":"CO-DC","name":"Bogotá D.C."},{"id":"CO-BOL","name":"Bolivar"},{"id":"CO-BOY","name":"Boyaca"},{"id":"CO-CAL","name":"Caldas"},{"id":"CO-CAQ","name":"Caqueta"},{"id":"CO-CAS","name":"Casanare"},{"id":"CO-CAU","name":"Cauca"},{"id":"CO-CES","name":"Cesar"},{"id":"CO-CHO","name":"Choco"},{"id":"CO-CUN","name":"Cundinamarca"},{"id":"CO-COR","name":"Córdoba"},{"id":"CO-GUA","name":"Guainía"},{"id":"CO-LAG","name":"Guajira"},{"id":"CO-GUV","name":"Guaviare"},{"id":"CO-HUI","name":"Huila"},{"id":"CO-MAG","name":"Magdalena"},{"id":"CO-MET","name":"Meta"},{"id":"CO-NAR","name":"Nariño"},{"id":"CO-NSA","name":"Norte De Santander"},{"id":"CO-PUT","name":"Putumayo"},{"id":"CO-QUI","name":"Quindio"},{"id":"CO-RIS","name":"Risaralda"},{"id":"CO-SAP","name":"San Andres y Providencia"},{"id":"CO-SAN","name":"Santander"},{"id":"CO-SUC","name":"Sucre"},{"id":"CO-TOL","name":"Tolima"},{"id":"CO-VAC","name":"Valle Del Cauca"},{"id":"CO-VAU","name":"Vaupes"},{"id":"CO-VID","name":"Vichada"}],"currencies":{"COP":{"id":"COP","symbol":"$","description":"Peso colombiano","decimal_places":0},"USD":{"id":"USD","symbol":"U$S","description":"Dólar","decimal_places":2}}},"currentUser":{"loggedIn":false,"loginUrl":"https:\u002F\u002Fwww.mercadolibre.com\u002Fjms\u002Fmco\u002Flgz\u002Flogin?platform_id=ML&go=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos&loginType=explicit","nickname":"","id":""},"initialState":{"adult_info":{"is_zrp_adult":false,"show_adult_filter":true,"adult_results":2},"view_options":{"id":"VIEW_OPTIONS","type":"VIEW_OPTIONS","state":"VISIBLE","tooltip":{"title":"¡Encuentra más fácil lo que buscas!","label":{"text":"Ordena los resultados por relevancia o precio, y elige verlos como lista o grilla."},"action":{"label":{"text":"Entendido"}}},"sort":{"label":"Ordenar por","sorts":[{"id":"relevance","name":"Más relevantes","disclaimer":"","selected":true,"has_disclaimer":false},{"url":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos_OrderId_PRICE_NoIndex_True","id":"price_asc","name":"Menor precio","selected":false,"has_disclaimer":false},{"url":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos_OrderId_PRICE*DESC_NoIndex_True","id":"price_desc","name":"Mayor precio","selected":false,"has_disclaimer":false}],"has_disclaimer":false}},"bookmark":{"label":{"text":"Favorito"},"show_user_bookmarks":true},"ads_metadata":{"destination_url":"https:\u002F\u002Fpublicidad.mercadolibre.com.co\u002Fmain","title":"","label_long":"Anuncia con MercadoLibre Publicidad","label_short":"Anuncia aquí","track_url":"https:\u002F\u002Fprint1.mercadoclics.com\u002Fmclics\u002Fv2\u002Fprints\u002Fexternal\u002FMCO\u002Fcount?d=RHtrAJjh8mWVOiZmhvS3BC2Le6YViHtkAeNNE5nY%2BM%2BeGQx2j4cCUQTVJNP1fiuIZJyFUnn0YLx6SIUA8%2BvdDqZKgy5rU4BqR4%2FoygV42pk5ORL%2FTXxLMK7dXfnf21Qv3%2BGEvR7soz1Wp6i5pLrMhoFg%2BsRlqR%2FpPolcMpqXscAfglyVYqTW42sbmdQwSH1aQKWfEkRgcY9boXTzVRHN6JZe%2FHrCSFXbtIPqHO5guxW%2FdvBuo1tzSMPRipg6mPXhwlLgJMy85VSzvXj2UqlCko63qJnj%2BIQQMr5ma24G1O5%2BLezGGDJa001mZJyI2kshwTo8QzlQO%2FVjIKoG%2FO4pind4VVELnjBAUY4TT%2FmaL6L7f8MH8oSwdeiYg2okUQRHSv3%2BYH%2Bj0dJJimGdDatLTXrLiDLKM1wIFmihlUdeL%2F2qZ2uG7k%2BaCyw%2Bl69DmsdJ5TgpQNk72b2pE0eIqw5daiqGLTpVU4DO%2FGDJy21aPUdsOPIJaJzIM9ZRnh%2B7r9CANdl4HJH08ymBtzFk5xNEo1g1dY65A0w5Wan0bcr8wHVVzpuzI%2B%2BSJnNk2crHSyVm%2Ffus0601fVP2gXCT3IJldTAc2%2Fd3o35VoN5I242v4zncL8rbZDj0%2B11WYfDSFmacI%2FgnqhLIG9HbrJcEnD6hcaz29vELUrc0wFPzudfx2%2B4etVhqYk7iUYwF%2FKh12CUZPpkjOYdDpYGo67LA%2BQBU%2FHHABD%2B6no%2FJ1mGej1DHCqfK0bOvjT9D4XnaQU0GE2dsZg5D8qCuYSLz3Jz2d1iTUQCp4rYohlfwJR7uo4mbnjMrhR ...
#         }},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/polyfill.102ca50a.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/search.desktop.5078c46c.js"},{s:function(){
#         var trackMclics = document.createElement('img');
#         trackMclics.src = 'https://print1.mercadoclics.com/mclics/v2/prints/external/MCO/count?d=RHtrAJjh8mWVOiZmhvS3BC2Le6YViHtkAeNNE5nY%2BM%2BeGQx2j4cCUQTVJNP1fiuIZJyFUnn0YLx6SIUA8%2BvdDqZKgy5rU4BqR4%2FoygV42pk5ORL%2FTXxLMK7dXfnf21Qv3%2BGEvR7soz1Wp6i5pLrMhoFg%2BsRlqR%2FpPolcMpqXscAfglyVYqTW42sbmdQwSH1aQKWfEkRgcY9boXTzVRHN6JZe%2FHrCSFXbtIPqHO5guxW%2FdvBuo1tzSMPRipg6mPXhwlLgJMy85VSzvXj2UqlCko63qJnj%2BIQQMr5ma24G1O5%2BLezGGDJa001mZJyI2kshwTo8QzlQO%2FVjIKoG%2FO4pind4VVELnjBAUY4TT%2FmaL6L7f8MH8oSwdeiYg2okUQRHSv3%2BYH%2Bj0dJJimGdDatLTXrLiDLKM1wIFmihlUdeL%2F2qZ2uG7k%2BaCyw%2Bl69DmsdJ5TgpQNk72b2pE0eIqw5daiqGLTpVU4DO%2FGDJy21aPUdsOPIJaJzIM9ZRnh%2B7r9CANdl4HJH08ymBtzFk5xNEo1g1dY65A0w5Wan0bcr8wHVVzpuzI%2B%2BSJnNk2crHSyVm%2Ffus0601fVP2gXCT3IJldTAc2%2Fd3o35VoN5I242v4zncL8rbZDj0%2B11WYfDSFmacI%2FgnqhLIG9HbrJcEnD6hcaz29vELUrc0wFPzudfx2%2B4etVhqYk7iUYwF%2FKh12CUZPpkjOYdDpYGo67LA%2BQBU%2FHHABD%2B6no%2FJ1mGej1DHCqfK0bOvjT9D4XnaQU0GE2dsZg5D8qCuYSLz3Jz2d1iTUQCp4rYohlfwJR7uo4mbnjMrhRqSwL01UpEH1V4bitGRdGd4FjJeSr6bidPu%2Fh4U0RSK6YsOniGVY%2B%2FI93bL7r1pXIVsWSj%2FcgerLvfDZmliC1pLR8yy%2BS2wdES1HK2QqinOe2nzhkAxmJ2IbEM5Xe6RQM%2Bqyh09xry1hK6jJHsWdK1C8YcCJFcDWjMrOVtBtCRfK6FJPQE8lc1QwbVenvSs0godbQxlTFgjrB6QEZQwgo%2FCQGyEg%2FszttT2JK5MQj6oKCRwc0QDQePAGZTJyRgCm4LMDcCuIecfpvAfr%2B0hhI1pqvQe7hsVMVrPNJtPE7YsmL9ZKFo0n9PXgu%2BNNvTZTXFHIRP3z4hdjtglKWiu6%2BoZlztCFAcOdMx9eyXNNkGrftRnJsJVi%2Brq1z3%2B%2F3j5bA5dg6CdcMKPlMPEwYLknxvsXz4hWmsiFin9Pe3nDnJbhlJCD6tcW389mKGLSbZet3a6NEKeYb6E5TjvCMq%2FjM2cNopQS9TIrwjIwO46hrpyfgr3bNzG6PEAbdUh3%2F2%2BciCV7Yxg7U8BAASIhNG4R5wUJ1twlJCptdq28d1Rlu9fABTuYSPm68Ybu3sYIArR%2BuK1Wy%2FsICSbipBkaFthK3x5M2FB%2FqREcYdB1HYph5mQeI1m69BU5%2Blc3qf2e%2F1Q8k0cuTlXlPjdg7RhWEavW02FQmmFJjGsybqLCWlGJYtmPY09Fkyija8ARljar0%2Bf0AX10G5DuCp1l3H0vFqbikCthimhRD1XdfoIeCc%3D&rb=x';
#       }},{s:function(){
#
#
#      var mktconfig = {
#     'selector' : 'searchResults',
#     'results': 'MCO812367769,MCO618049088,MCO618542478,MCO613267539,MCO652324942',
#     'categories': 'MCO5072,MCO3697,MCO5072,MCO31377,MCO3697',
#     'siteId' : 'MCO',
#     'd2id': '',
#     'query': 'audifonos',
#     'platform' : 'STD'
#         }
#
#         var Search = Search || {};
#
#
#         ;(function (Search, win, doc) {
#
#           function MarketingTags(options) {
#             this.platform = options.platform || '';
#             this.siteId = options.siteId || '';
#             this.items = options.results || [];
#             this.categories = options.categories || [];
#             this.d2id = options.d2id;
#             this.query = options.query;
#
#             if (!this.items || !this.platform || !this.siteId || !this.categories) { throw new Error('MarketingTags: error in incoming params')}
#
#               this.init();
#
#               return this;
#
#           };
#
#           MarketingTags.prototype.init = function () {
#             var data = {}, categoriesIds = [];
#
#             if (this.items) {
#               data.items = this.items;
#               categoriesIds = this.unique(this.categories);
#
#               if(categoriesIds.length == 1){
#                 data.categoryId = categoriesIds
#               }
#
#               if (this.d2id) {
#                 data.d2id = this.d2id
#               }
#
#               if (this.query) {
#                 data.query = this.query;
#               }
#
#               this.start(data);
#               this.createIframe();
#             }
#           };
#
#           MarketingTags.prototype.createIframe = function () {
#             var iframe = doc.createElement("iframe"),
#                   scriptTag = doc.getElementsByTagName('script')[0],
#               elem = iframe.frameElement || iframe;
#
#                 elem.style.width = 0;
#               elem.style.height = 0;
#               elem.style.border = 0;
#               elem.style.position = 'absolute';
#
#
#                 iframe.src = this.url;
#                 scriptTag.parentNode.insertBefore(iframe, scriptTag);
#           };
#
#           MarketingTags.prototype.start = function (data) {
#             var millisecondsInMinute = 60000
#             var minuteInPartition = 60 * 5
#             var currentMilliseconds = new Date().getTime()
#             var currentSeconds = parseInt(currentMilliseconds / millisecondsInMinute)
#             var timeHash = parseInt(currentSeconds/minuteInPartition)*minuteInPartition
#
#             this.url = "https://http2.mlstatic.com/storage/tag-manager/" + this.siteId + ".html?timehash="+ timeHash +"&platform=" + this.platform + "#" + JSON.stringify(data);
#
#           };
#
#           MarketingTags.prototype.unique = function(array){
#               var tmp = {},
#                 out = [];
#               for(var i = 0, n = array.length; i < n; ++i){
#                   if(!tmp[array[i]]) { tmp[array[i]] = true; out.push(array[i]); }
#               }
#               return out;
#           }
#
#             Search.MarketingTags = MarketingTags;
#
#         })(Search, window, document);
#
#           new Search.MarketingTags(mktconfig);
#     }},{s:function(){
#     (function(h,o,t,j,a,r){
#       h.hj= h.hj || function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#       h._hjSettings={hjid:550932,hjdebug:false,hjsv:5};
#       a=o.getElementsByTagName('head')[0];
#       r=o.createElement('script');r.async=1;
#       r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#       a.appendChild(r);
#     })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#     hj('tagRecording', ["user_type: normal"]);
#
#     }},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/framework.83d0c536.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/lib-428dfce9.5b2f9761.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/lib-47e0d0a8.33ffeeb6.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/lib-8547c38c.4fc00775.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/295.2c87c984.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/636.a5c4d7ed.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/652.c1695bf5.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/179.275b67dd.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/501.cb62b487.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/949.a1b9fe8f.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/880.e376bc8d.js"}];
#   if (doc.readyState === 'complete') {
#     loadScripts(scripts);
#   } else {
#     win.addEventListener('load', function(){ loadScripts(scripts); });
#   }
# })(window, document);</script></body></html>

# %% [markdown]
# Ahora lo organizamos *BeautifulSoup*

# %%
soup = BeautifulSoup(page.content, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="es-CO">
# <head><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://www.google.com" rel="preconnect"/><link href="https://data.mercadolibre.com" rel="preconnect"/><link href="https://http2.mlstatic.com" rel="preconnect"/><link href="https://stats.g.doubleclick.net" rel="preconnect"/><link href="https://analytics.mercadolibre.com.co" rel="preconnect"/><link href="https://analytics.mercadolibre.com" rel="preconnect"/><link href="https://www.google.com.co" rel="preconnect"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"3009922991","applicationID":"408441092","applicationTime":1557.2441760000002,"transactionName":"YlZQYEVZC0QEV0BZV1scd0xHSgBEFl5HH39wZx0bHQ==","queueTime":0,"ttGuid":"2dec517cac74361a","agentToken":null}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"XQ4OVF5VGwcAXFVWBgEOVA==",licenseKey:"3009922991",applicationID:"408441092"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(32),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(33),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v] ...
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="samesite=true" name="browser-support"/>
# <meta content="i4HkEUZT-81T1quIFPHPgmLoqjF-jbJLQHfQ" name="csrf-token"/>
# <link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2" rel="preload" type="font/woff2"/><style data-head-react="true">@font-face{font-family:'Proxima Nova';font-weight:300;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:400;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:600;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.ttf) format("truetype")}</style><link data-head-react="true" href="https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/favicon.svg" rel="icon"/><link data-head-react="true" href="https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/180x180.png" rel="apple-touch-icon"/><script type="application/ld+json">{"@context":"https:\u002F\u002Fschema.org","@graph":[{"@type":"SearchResultsPage","id":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos","name":"Audifonos","about":"Envíos Gratis en el día ✓ Compre Audifonos en cuotas sin interés! Conozca nuestras increíbles ofertas y promociones en millones de productos."},{"@type":"ItemList","id":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos\u002F#itemList","numberOfItems":1,"itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Product","name":"Audífonos in-ear inalámbricos Xiaomi Redmi AirDots 2 negro","url":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos","aggregateRating":{"@type":"AggregateRating","ratingCount":539,"bestRating":5,"ratingValue":4.2,"worstRating":1},"offers":{"@type":"AggregateOffer","price":74000,"lowPrice":74000,"priceCurrency":"COP","offerCount":1,"availability":"https:\u002F\u002Fschema.org\u002FInStock","itemCondition":"https:\u002F\u002Fschema.org\u002FNewCondition"},"brand":{"@type":"Brand","name":"Xiaomi"}}}]}]}</script><link data-head-react="true" href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link data-head-react="true" href="https://www.googletagservices.com" rel="preconnect"/><title>Audifonos | MercadoLibre 📦</title><meta content="Envíos Gratis en el día ✓ Compre Audifonos en cuotas sin interés! Conozca nuestras increíbles ofertas y promociones en millones de productos." data-head-react="true" name="description"/><link data-head-react="true" href="https://listado.mercadolibre.com.co/audifonos" rel="canonical"/><link data-head-react="true" href="android-app://com.mercadolibre/meli/search?go=https://listado.mercadolibre.com.co/audifonos" rel="alternate"/><link data-head-react="true" href="ios-app://463624852/meli/search?go=https://listado.mercadolibre.com.co/audifonos" rel="alte ...
# <style media="(min-width: 1024px)">@charset "UTF-8";/*!
#  * Navigation
#  * @platform "mercadolibre"
#  * @site "MCO"
#  * @version 5.18.9
#  * @author MercadoLibre.com
#  */[role=main],body,html{height:100%}.nav-footer-access-content [href*='twitter.com'],.nav-footer-access-content [href*='facebook.com'],.nav-footer-access-content [href*='plus.google.com'],.nav-footer-access-content [href*='youtube.com'],.nav-footer-access-content [href*='instagram.com'],[class*=' nav-icon-'],[class^=nav-icon-]{font-style:normal}@font-face{font-family:navigation;src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot);src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot#iefix) format("embedded-opentype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff2) format("woff2"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff) format("woff"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.ttf) format("truetype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.svg#navigation) format("svg");font-weight:400;font-style:normal}[class*=' nav-icon-']:before,[class^=nav-icon-]:before{font-variant:normal;margin:0;speak:none;text-align:center;width:1em;text-rendering:auto;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;font-family:navigation}.nav-header .nav-header-btn:before,.nav-icon-back-o:before{content:'\EA01'}#nav-header-menu a.option-bookmarks:after,.nav-icon-bookmarks-o:before{content:'\EA02'}.nav-icon-bookmarks:before{content:'\EA03'}.nav-icon-chevron-right-o:before{content:'\EA04'}.nav-icon-chevron-right:before{content:'\EA05'}.nav-icon-chevron-up-o:before{content:'\EA06'}.nav-icon-chevron-up:before{content:'\EA07'}.nav-icon-close:before{content:'\EA08'}.nav-icon-facebook:before{content:'\EA09'}.nav-icon-gplus:before{content:'\EA0A'}#nav-header-menu a.option-help:after,.nav-icon-help-o:before{content:'\EA0B'}.nav-icon-help:before{content:'\EA0C'}.nav-icon-instagram:before{content:'\EA0D'}#nav-header-menu a.option-login:after,.nav-icon-login-o:before{content:'\EA0E'}#nav-header-menu a.option-logout:after,.nav-icon-logout-o:before{content:'\EA0F'}.nav-icon-logout:before{content:'\EA10'}#nav-header-menu a.option-notifications:after,.nav-icon-notifications-o:before{content:'\EA11'}.nav-icon-notifications:before{content:'\EA12'}.nav-icon-official-store-o:before{content:'\EA13'}#nav-header-menu a.option-register:after,.nav-icon-register-o:before{content:'\EA14'}.nav-icon-search-o:before{content:'\EA15'}.nav-icon-search:before{content:'\EA16'}#nav-header-menu a.option-sell:after,.nav-icon-sell-o:before{content:'\EA17'}.nav-icon-time-o:before{content:'\EA18'}.nav-icon-twitter:before{content:'\EA19'}#nav-header-menu a.option-my-account:after,.nav-icon-user-o:before{content:'\EA1A'}.nav-icon-user:before{content:'\EA1B'}.nav-icon-youtube:before{content:'\EA1C'}.nav-icon-close-o:before{content:'\EA1D'}.nav-icon-bookmarks-medium:before{content:'\EA1E'}.nav-icon-cart-empty-medium:before{content:'\EA1F'}.nav-icon-phone:before{content:'\EA20'}.nav-cart.nav-cart-empty .nav-icon-cart:before,.nav-icon-cart-empty-small:before{content:'\EA21'}.nav-icon-cart-full-medium:before{content:'\EA22'}.nav-cart.nav-cart-full .nav-icon-cart:before,.nav-icon-cart-full-small:before{content:'\EA23'}.nav-icon-help-medium:before{content:'\EA24'}.nav-icon-notifications-medium:before{content:'\EA25'}.nav-icon-user-medium:before{content:'\EA26'}.nav-icon-search-ml:before{content:'\EA27'}.nav-icon-user-rounded:before{content:'\EA28'}.nav-icon-app:before{content:'\EA29'}.nav-icon-search-plus:before{content:'\EA2A'}.nav-icon-vender-mobile:before{content:'\EA2B'}.nav-icon-bookmarks-mobile:before{content:'\EA2C'}.nav-icon-categories-mobile:before{content:'\EA2D'}.nav-icon-create-account-mobile:before{content:'\EA2E'}.nav-icon-deals-mobile:before{content:'\EA2F'}.nav-icon-download-mobile:before{content:'\EA30'}.nav-icon-help-mobile:before{content:'\EA31'}.nav-icon-history-mobile:before{content:'\EA32'}.nav-icon-logout-mobile:before{content:'\EA33'}. ...
# <style media="(max-width: 1023px)">@charset "UTF-8";/*!
#  * Navigation
#  * @platform "mercadolibre"
#  * @site "MCO"
#  * @version 5.18.9
#  * @author MercadoLibre.com
#  */[role=main],body,html{height:100%}@font-face{font-family:navigation;src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot);src:url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.eot#iefix) format("embedded-opentype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff2) format("woff2"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.woff) format("woff"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.ttf) format("truetype"),url(https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/navigation.svg#navigation) format("svg");font-weight:400;font-style:normal}[class*=' nav-icon-'],[class^=nav-icon-]{font-style:normal}[class*=' nav-icon-']:before,[class^=nav-icon-]:before{display:inline-block;font-variant:normal;margin:0;speak:none;text-align:center;width:1em;text-rendering:auto;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;font-family:navigation}.nav-header .nav-header-btn:before,.nav-icon-back-o:before{content:'\EA01'}#nav-header-menu a.option-bookmarks:after,.nav-icon-bookmarks-o:before{content:'\EA02'}.nav-icon-bookmarks:before{content:'\EA03'}.nav-icon-chevron-right-o:before{content:'\EA04'}.nav-icon-chevron-right:before{content:'\EA05'}.nav-icon-chevron-up-o:before{content:'\EA06'}.nav-icon-chevron-up:before{content:'\EA07'}.nav-icon-close:before{content:'\EA08'}.nav-icon-facebook:before{content:'\EA09'}.nav-icon-gplus:before{content:'\EA0A'}#nav-header-menu a.option-help:after,.nav-icon-help-o:before{content:'\EA0B'}.nav-icon-help:before{content:'\EA0C'}.nav-icon-instagram:before{content:'\EA0D'}#nav-header-menu a.option-login:after,.nav-icon-login-o:before{content:'\EA0E'}#nav-header-menu a.option-logout:after,.nav-icon-logout-o:before{content:'\EA0F'}.nav-icon-logout:before{content:'\EA10'}#nav-header-menu a.option-notifications:after,.nav-icon-notifications-o:before{content:'\EA11'}.nav-icon-notifications:before{content:'\EA12'}.nav-icon-official-store-o:before{content:'\EA13'}#nav-header-menu a.option-register:after,.nav-icon-register-o:before{content:'\EA14'}.nav-icon-search-o:before{content:'\EA15'}.nav-icon-search:before{content:'\EA16'}#nav-header-menu a.option-sell:after,.nav-icon-sell-o:before{content:'\EA17'}.nav-icon-time-o:before{content:'\EA18'}.nav-icon-twitter:before{content:'\EA19'}#nav-header-menu a.option-my-account:after,.nav-icon-user-o:before{content:'\EA1A'}.nav-icon-user:before{content:'\EA1B'}.nav-icon-youtube:before{content:'\EA1C'}.nav-icon-close-o:before{content:'\EA1D'}.nav-icon-bookmarks-medium:before{content:'\EA1E'}.nav-icon-cart-empty-medium:before{content:'\EA1F'}.nav-icon-phone:before{content:'\EA20'}.nav-cart.nav-cart-empty .nav-icon-cart:before,.nav-icon-cart-empty-small:before{content:'\EA21'}.nav-icon-cart-full-medium:before{content:'\EA22'}.nav-cart.nav-cart-full .nav-icon-cart:before,.nav-icon-cart-full-small:before{content:'\EA23'}.nav-icon-help-medium:before{content:'\EA24'}.nav-icon-notifications-medium:before{content:'\EA25'}.nav-icon-user-medium:before{content:'\EA26'}.nav-icon-search-ml:before{content:'\EA27'}.nav-icon-user-rounded:before{content:'\EA28'}.nav-icon-app:before{content:'\EA29'}.nav-icon-search-plus:before{content:'\EA2A'}.nav-icon-vender-mobile:before{content:'\EA2B'}.nav-icon-bookmarks-mobile:before{content:'\EA2C'}.nav-icon-categories-mobile:before{content:'\EA2D'}.nav-icon-create-account-mobile:before{content:'\EA2E'}.nav-icon-deals-mobile:before{content:'\EA2F'}.nav-icon-download-mobile:before{content:'\EA30'}.nav-icon-help-mobile:before{content:'\EA31'}.nav-icon-history-mobile:before{content:'\EA32'}.nav-icon-logout-mobile:before{content:'\EA33'}.nav-icon-my-account-mobile:before{content:'\EA34'}.nav-icon-navigation-mobile:before{content:'\EA35'}.nav-icon-notifications-mobile:before{content:'\EA36'}.nav-icon-points-mobile:before{content:'\EA37'}.nav-icon-purchases-mobile:be ...
# <style>a.nav-skip-to-main-content{border:0;border-bottom-left-radius:4px;border-bottom-right-radius:4px;position:absolute;color:#fff;font-weight:100;text-decoration:none;text-align:center;background:#3484fa;top:0;left:0;z-index:999;cursor:pointer;height:0;padding:0;line-height:normal}a.nav-skip-to-main-content:focus{border:1px solid #3484fa;height:54px;padding:8px 8px}.nav-skip-to-main-content>.nav-skip-to-main-content__content{display:none}.nav-skip-to-main-content:focus>.nav-skip-to-main-content__content{display:block;padding:8px;border:1px solid #fff;border-radius:4px}</style>
# <link href="https://http2.mlstatic.com/frontend-assets/search-nordic/search.desktop.c22a72d7.css" onerror="(window['_pfl'] = window['_pfl'] || []).push(['css', this.href])" rel="stylesheet" type="text/css"/>
# <script>
# (function(win, doc) {
#
# function preloadCriticalPath() {
#   var head = doc.getElementsByTagName('head')[0],
#       assets = ["https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/navigation-desktop-MCO.css","https://http2.mlstatic.com/frontend-assets/ui-navigation/5.18.9/mercadolibre/navigation-mobile-MCO.css"],
#       link,
#       i;
#   for(i = 0; i < assets.length; i++) {
#     link = doc.createElement('link');
#     link.rel = 'prefetch';
#     link.href = assets[i];
#     link.onerror = function(e) {
#       (window['_pfl'] = window['_pfl'] || []).push(['css', e.target.href]);
#     }
#     head.appendChild(link);
#   }
# }
#   if (doc.readyState === 'complete') {
#     setTimeout(preloadCriticalPath, 0);
#   } else {
#     win.addEventListener('load', function() {
#       preloadCriticalPath();
#     });
#   }
# })(window, document);
# </script>
# <script>
# (function(a,b){a.GoogleAnalyticsObject=b;a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};a[b].l=1*new Date})(window,"meli_ga");
# meli_ga("set", "title", "app-search-nordic-nodejs-3.1.1");
# meli_ga("set", "page", "/SEARCH/LISTING/?q=audifonos");
# meli_ga("set", "dimension49", "MCO812367769,MCO618049088,MCO618542478,MCO613267539,MCO652324942,MCO613173279,MCO657809856,MCO618060363,MCO621222310,MCO643708663,MCO658984720,MCO860197401,MCO867220824,MCO866606051,MCO618050413,MCO640578413,MCO843371332,MCO618050281,MCO832876490,MCO862601588,MCO860956693,MCO613258796,MCO855935558,MCO865030065,MCO805848514,MCO646972630,MCO548576541,MCO621221511,MCO835953622,MCO630688159,MCO867220824,MCO855870969,MCO616477825,MCO866836562,MCO619299293,MCO623226653,MCO658983752,MCO487282431,MCO839245641,MCO658983657,MCO468795741,MCO800704856,MCO851248363,MCO857659492,MCO855581572,MCO857573183,MCO614941053,MCO844123932,MCO613185957,MCO561405885,MCO614532740,MCO856079201,MCO652325407,MCO621342714");
# meli_ga("set", "dimension86", "MCO-HEADPHONES,MCO-TABLETS,MCO-NOTEBOOKS,MCO-TELEPHONES,MCO-CELLPHONE_ACCESSORIES,MCO-CELLPHONE_COVERS");
# meli_ga("set", "dimension117", "PDP+officialStore");
# meli_ga("set", "dimension22", "224257");
# meli_ga("set", "dimension9", "NONE");
# meli_ga("set", "dimension23", "SEO-allowlist: in - SEARCH-noindex: false");
# meli_ga("set", "dimension21", "119");
# meli_ga("set", "dimension25", "{'frontend/assetsCdnDomainMCO':'DEFAULT','searchbackend/recommended-products':'6158','search/new-search-api':'8650','searchbackend/cbt-antiboost':'6333','mclics/show-pads-search-list':'5146','mclics/pseudo-search-buybox-query':'9461','mclics/show-pads-global':'5176','mclics/pseudo-search-pads-buybox':'7708','mclics/search-list-algorithms':'5528','frontend/assetsCdnDomainMLU':'DEFAULT'}");
# meli_ga("set", "dimension7", "MARKETPLACE");
# meli_ga("set", "dimension8", "CORE");
# meli_ga("set", "dimension48", "NONE");
# meli_ga("set", "dimension113", "17140da4-5d1e-49bf-b7e3-28c4b070a37d");
# meli_ga("set", "contentGroup1", "/MARKETPLACE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup2", "/CORE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup3", "/NONE/SEARCH/LISTING/");
# meli_ga("set", "dimension1", "desktop");
# meli_ga("set", "dimension6", "listing");
# meli_ga("set", "dimension7", "MARKETPLACE");
# meli_ga("set", "dimension8", "CORE");
# meli_ga("set", "dimension25", "{'cookiesConsentBanner':'8415'}");
# meli_ga("send", "pageview");
# (function(d) {
#       var i = d.createElement('iframe');
#       (i.frameElement || i).style.cssText = 'width: 0; height: 0; border: 0; position: absolute';
#       i.src = "about:srcdoc";
#       i.srcdoc="\<script\  src='https://http2.mlstatic.com/analytics/ga/mco-ml-analytics.min.js'>\</script\>";
#       i.id = "GoogleAnalyticsIframe";
#       var w = d.getElementsByTagName('script')[0];
#       w.parentNode.insertBefore(i, w);
#       var doc = i.contentWindow.document;
#       var s = doc.createElement('script');
#       s.type = 'text/javascript';
#       s.text ='window.inDapIF = true;';
#       doc.documentElement.appendChild(s);
#     })(document);
# </script>
# </head><body data-country="CO" data-site="ML"><input id="nav-header-menu-switch" type="checkbox"/><header class="nav-header nav-header-plus" data-siteid="MCO" role="banner"><div class="nav-bounds nav-bounds-with-cart nav-bounds-with-cp"><a aria-label="Ir al contenido principal" class="nav-skip-to-main-content" href="#root-app" id="nav-skip-to-main-content" role="button" tabindex="1"><span class="nav-skip-to-main-content__content">Ir al contenido principal</span></a><a class="nav-logo" href="//www.mercadolibre.com.co" tabindex="2">Mercado Libre Colombia - Donde comprar y vender de todo</a><div class="nav-header-menu-wrapper"><label aria-controls="nav-header-menu" for="nav-header-menu-switch"><span class="hamburger-top-bread"></span><span class="hamburger-patty"></span><span class="hamburger-bottom-bread"></span></label><nav class="nav-header-menu-mobile-guest" id="nav-header-menu-mobile"><div id="nav-header-menu-mobile-content"><div class="nav-header-menu-mobile-guest" id="nav-header-menu-mobile-user-info"><div class="nav-header-menu-mobile-guest-logo"><svg class="nav-header-menu-mobile-guest-icon" height="35" width="28" xmlns="http://www.w3.org/2000/svg"><path d="M27.343 33.706l-1.356.64A13.25 13.25 0 0 0 14 26.75c-5.17 0-9.8 2.988-11.978 7.578l-1.356-.643A14.75 14.75 0 0 1 14 25.25a14.75 14.75 0 0 1 13.343 8.456zM14 21.75C8.063 21.75 3.25 16.937 3.25 11S8.063.25 14 .25 24.75 5.063 24.75 11 19.937 21.75 14 21.75zm0-1.5a9.25 9.25 0 1 0 0-18.5 9.25 9.25 0 0 0 0 18.5zm0-2.5v-1.5a5.25 5.25 0 1 0 0-10.5v-1.5a6.75 6.75 0 0 1 0 13.5z" fill="#BBB" fill-rule="nonzero"></path></svg></div><h3 class="nav-header-menu-mobile-guest-title">Bienvenido</h3><p class="nav-header-menu-mobile-guest-text">Ingresa a tu cuenta para ver tus compras, favoritos, etc.</p><div class="nav-header-menu-mobile-guest-buttons"><a class="nav-mobile-button nav-mobile-button-filled" href="https://www.mercadolibre.com/jms/mco/lgz/login?platform_id=ML&amp;go=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos&amp;loginType=explicit" rel="nofollow">Ingresa</a><a class="nav-mobile-button nav-mobile-button-outline" href="https://www.mercadolibre.com.co/registration?confirmation_url=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos" rel="nofollow">Crea tu cuenta</a></div></div><ul><li><a href="https://www.mercadolibre.com.co#menu-user"><i class="nav-icon-home"></i><span>Inicio</span></a></li><li><a href="https://www.mercadolibre.com.co/ofertas#menu-user"><i class="nav-icon-deals-mobile"></i><span>Ofertas</span></a></li><li><a href="https://www.mercadolibre.com.co/gz/home/navigation#menu-user"><i class="nav-icon-history-mobile"></i><span>Historial</span></a></li><li><a href="https://www.mercadolibre.com.co/ayuda#menu-user"><i class="nav-icon-help-mobile"></i><span>Ayuda / PQR</span></a></li></ul><ul><li><a href="https://www.mercadolibre.com.co/ofertas/supermercado#menu-user"><i class="nav-icon-supermercado"></i><span>Supermercado</span></a></li><li><a href="https://www.mercadolibre.com.co/c/ropa-y-accesorios#menu-user"><i class="nav-icon-moda-mobile"></i><span>Moda</span></a></li><li><a href="https://www.mercadolibre.com.co/ofertas/compras-internacionales#menu-user"><i class="nav-icon-compra-internacional"></i><span>Compra Internacional</span><span class="nav-link-tag">Nuevo</span></a></li><li><a href="https://www.mercadolibre.com.co/tiendas-oficiales#menu-user"><i class="nav-icon-stores-mobile"></i><span>Tiendas oficiales</span></a></li><li><a href="https://www.mercadolibre.com.co/categorias#menu-user"><i class="nav-icon-categories-mobile"></i><span>Categorías</span></a></li></ul><ul><li><a href="https://www.mercadolibre.com.co/resumen#menu-user"><i class="nav-icon-summary-mobile"></i><span>Resumen</span></a></li><li><a href="https://www.mercadolibre.com.co/publicar#menu-user"><i class="nav-icon-vender-mobile"></i><span>Vender</span></a></li></ul><ul><li><a href="https://www.mercadolibre.com.co/l/app#menu-user" id="nav-header-menu-download-mobile"><i class="nav-ico ...
# (function(w, r) {
#   w[r] = w[r] || function() {
#     (w[r].q = w[r].q || []).push(arguments)
#   }
# })(window,'melidata');
# (function(d,u) {
#   if (!document.getElementById("MelidataIframe")) {
#     var i = d.createElement('iframe');
#     (i.frameElement || i).style.cssText = "width: 0; height: 0; border: 0; position: absolute";
#     i.src = "about:srcdoc";
#     i.srcdoc="\<script\  src='" + u + "'>\</script\>";
#     i.id = "MelidataIframe";
#     var t = d.getElementsByTagName('script')[0];
#     t.parentNode.insertBefore(i, t);
#     var doc = i.contentWindow.document;
#     var script = doc.createElement('script');
#     script.type = 'text/javascript';
#     script.text ='window.inDapIF = true;';
#     doc.documentElement.appendChild(script);
#   } else {
#     // This page is charged async via AJAX and inserted into another one who has
#     // already download melidata js lib => Just clean the track
#     melidata("clean");
#   }
# })(document,'https://http2.mlstatic.com/storage/melidata-js-sdk/js/3/0.3.21/melidata.min.js');
#
# melidata("add", "id", "036d69be-323f-41cc-9580-c02d9a88c105");
# melidata("add", "server_id", "036d69be-323f-41cc-9580-c02d9a88c105" );
# melidata("add", "application", {"version":"1.116.0-rc-2","server_hostname":"","server_poolname":"","app_name":"","sdk_version":{"node_version":"4.1.2"},"business":"mercadolibre","site_id":"MCO","secured":{"encrypted":"113fea3e6513856ec418c20713ed50b1:","signature":"eyJhbGciOiJIUzI1NiJ9.eyJ1aWQiOiJhZjMyMjA4Ni1lMThiLTQwNGEtOTBkNC1kNDY2MDAxYzM2ZjgiLCJzaXRlX2lkIjoiTUNPIiwicGxhdGZvcm0iOiIvd2ViL2Rlc2t0b3AifQ.HOe1HPVfliASXTAKlE7b2urX9l6V5aBPAWKyu4VXbiI"}});
# melidata("add", "user", {"uid":"af322086-e18b-404a-90d4-d466001c36f8","user_tags":[]});
# melidata("add", "device", {"platform":"/web/desktop","user_agent":"python-requests/2.25.1"});
# melidata("add", "platform", {"http":{"cookies":{},"headers":{"host":"listado.mercadolibre.com.co","x-device-js":"true","x-platform":"ml","x-d2id":"af322086-e18b-404a-90d4-d466001c36f8"},"http_url":"http://listado.mercadolibre.com.co/audifonos"}});
# melidata("add", "experiments", {"cookiesConsentBanner":8415,"frontend/assetsCdnDomainMCO":"DEFAULT","searchbackend/recommended-products":"6158","search/new-search-api":"8650","searchbackend/cbt-antiboost":"6333","mclics/show-pads-search-list":"5146","mclics/pseudo-search-buybox-query":"9461","mclics/show-pads-global":"5176","mclics/pseudo-search-pads-buybox":"7708","mclics/search-list-algorithms":"5528","frontend/assetsCdnDomainMLU":"DEFAULT"});
# melidata("add", "experiments_timestamp", "2022-03-11T16:35:19.23UTC");
# melidata("add", "event_data", {"query":"audifonos","limit":50,"offset":0,"total":224257,"category_id":"","category_path":[],"sort_id":"relevance","filters":{"notfinalized":"1647017514422"},"available_filters":{},"displayed_filters":[{"id":"shipping_highlighted_fulfillment","name":"Envío","type":"highlighted","position":1,"values_quantity":1},{"id":"shipping_cost_highlighted","name":"Costo de envío","type":"highlighted","position":2,"values_quantity":1},{"id":"SHIPPING_ORIGIN_HIGHLIGHTED","name":"Tipo de compra","type":"highlighted","position":3,"values_quantity":1},{"id":"official_store","name":"Tiendas oficiales","type":"text","position":4,"values_quantity":1},{"id":"category","name":"Categorías","type":"text","position":5,"values_quantity":47},{"id":"installments","name":"Pago","type":"text","position":6,"values_quantity":1},{"id":"shipping_cost","name":"Costo de envío","type":"text","position":7,"values_quantity":1},{"id":"shipping","name":"Envío","type":"text","position":8,"values_quantity":2},{"id":"ITEM_CONDITION","name":"Condición","type":"STRING","position":9,"values_quantity":3},{"id":"state","name":"Ubicación","type":"text","position":10,"values_quantity":29},{"id":"price","name":"Precio","type":"range","position":11,"values_quantity":3},{"id":"discount","name":"Descuentos","type":"numeric","position":12,"values_quantity":6},{"id":"promotion_type","name":"Tipo de promoción","type":"text","position":13,"values_quantity":2},{"id":"BRAND","name":"Marca","type":"STRING","position":14,"values_quantity":796},{"id":"SHIPPING_ORIGIN","name":"Tipo de compra","type":"STRING","position":15,"values_quantity":2},{"id":"power_seller","name":"Filtro por calidad de vendedores","type":"refine_by","position":16,"values_quantity":1},{"id":"accepts_mercadopago","name":"Filtro por MercadoPago","type":"refine_by","position":17,"values_quantity":1}],"autoselected_filters":[],"view_mode":"STACK","results":["MCO812367769","MCO618049088","MCO618542478","MCO613267539","MCO652324942","MCO613173279","MCO657809856","MCO618060363","MCO621222310","MCO643708663","MCO658984720","MCO860197401","MCO867220824","MCO866606051","MCO618050413","MCO640578413","MCO843371332","MCO618050281","MCO860956693","MCO613258796","MCO855935558","MCO865030065","MCO805848514","MCO646972630","MCO548576541","MCO621221511","MCO835953622","MCO855870969","MCO616477825","MCO866836562","MCO619299293","MCO623226653","MCO658983752","MCO487282431","MCO839245641","MCO658983657","MCO468795741","MCO800704856","MCO851248363","MCO857659492","MCO855581572","MCO857573183","MCO614941053","MCO844123932","MCO613185957","MCO561405885","MCO614532740","MCO856079201","MCO652325407","MCO621342714"],"billboards":[],"pads_info":{"blocks_strategy":"B4V2","ids":["MCO17828522","MCO18446994","MCO16269737","MCO16069888"],"item_ids":["MCO832876490","MCO862601588","MCO630688159","MCO867220824"],"discarded_ids":["MCO836145545","MCO613212910"],"printed_ads_prices":[4650000,209900,544902,48000],"discarded_ads_prices":[214755,919902],"results_avg_ads_asp":1097909.83,"results_avg_printed_ads_asp":1363200.5,"results_avg_discarded_ads_asp":567328.5,"results_avg_items_asp":168575.06,"printed_positions":[18,19,29,30],"original_positions":[7,8,18,19,29,30],"empty_positions":[7,8],"suggested_positions":[59,53,216,12,75,188],"original_suggested_positions":[59,53,216,12,75,188],"discarded_original_suggested_positions":[75,188],"printed_original_suggested_positions":[59,53,216,12],"domain_item_position_limit":true,"same_item_position_limit":false,"blocks_sizes":[],"printed_positions_size":4,"productads_factor":1,"domain":"VQCATCORE_LST","strategy":"DP_ADPOTENTIAL_CTRAVG_B4V2_BB_PRODUCT_BIDBSMULT","is_api_migrated":false},"catalog_product_id":"","backend_data":{"stems":["AURICULAR","AUDIFON"],"aa":[],"ab":"719","fsm":"50F","ac":["syn1","mcv-20","qwvG","qpE","s1","epq","pa","qpci","mc1"],"qas":[],"ab_bucket":["rpsv1","cbtoff"],"request_flow":{"origin":"backend"},"fbm_ids":[],"processed_query":"AUDIFONOS","ap":[]},"promis ...
# melidata("send", "view", {
#   path: "/search",
#   data: {}
# }, "melidata");</script>
# <script>
# (function(win, doc){
#   function loadScripts (s) {
#     if (!s || !s.length) return;
#     s = s.slice(0);
#     var h = doc.head || doc.getElementsByTagName('head')[0];
#     var cbStack = {}; var cbChild = {};
#
#     for (var i = 0; i < s.length; i++) {
#       var c = s[i];
#       var t = doc.createElement('script');
#
#       if (typeof c.s === 'function') {
#         t.textContent = '(' + c.s + ').apply(window);';
#       } else {
#         t.async = false;
#         t.defer = true;
#         t.crossOrigin = 'anonymous';
#         if (c.id) t.id = c.id;
#
#         if (c.s) t.src = c.s;
#         var x = t.src;
#         cbStack[x] = [];
#         while(s[i+1] && typeof s[i+1].s === 'function') {
#           cbStack[x].push(s[i+1].s);
#           i++;
#         }
#         if (typeof c.c === 'function') {
#           cbChild[x] = c.c
#         } else if (c.c) {
#           t.textContent = c.c;
#         }
#         t.onerror = function(err) {
#           cbStack[err.target.src] && cbStack[err.target.src].forEach(function(cb){ (cb).apply(window) });
#
#           var perfillNamespace = '_pfl';
#           (window[perfillNamespace] = window[perfillNamespace] || []).push(['script', err.target.src])
#
#           if (typeof meli_ga !== 'undefined') {
#             meli_ga('send', {
#               hitType: 'event',
#               eventCategory: 'FRONTEND-ERROR',
#               eventAction: 'SCRIPT-LOAD-ERROR',
#               eventLabel: err.target.src,
#               nonInteraction: true,
#             });
#           }
#         }
#         t.onload = function(e) {
#           cbChild[e.target.src] && (cbChild[e.target.src]).apply(window);
#           cbStack[e.target.src] && cbStack[e.target.src].forEach(function(cb){ (cb).apply(window) });
#         }
#       }
#       h.appendChild(t);
#     }
#   }
#   loadScripts([{s:function(){window.__NAVIGATION_PRELOADED_STATE__ = {"application":"search-nordic","siteId":"MCO","domain":"mercadolibre.com.co"};}},{s:function(){"use strict";function track(a){if(a.analytics&&"undefined"!=typeof meli_ga&&meli_ga("send",{hitType:a.analytics.hitType,eventCategory:a.analytics.category,eventAction:a.analytics.action,eventLabel:a.analytics.label}),a.melidata&&"undefined"!=typeof melidata){var b=a.melidata.data;melidata("cleanAndSend",a.melidata.type,{path:a.melidata.path,data:b})}}function navigationEventTracking(a,b,c){var d=document.querySelector(a);d&&d.addEventListener(b,function(){track(c)})}window.__navigation_tracking__=navigationEventTracking,window.__navigation_track__=track;}},{s:function(){"use strict";(function(){window.__navigation_tracking__("#nav-skip-to-main-content","click",{analytics:{category:"SKIP_TO_MAIN_CONTENT",action:"NAVIGATION",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"},melidata:{path:"/navigation/skip-to-main-content",type:"event",data:{app:window.__NAVIGATION_PRELOADED_STATE__.application}}})})();}},{s:function(){"use strict";(function(){window.__navigation_tracking__("#nav-header-menu-download-mobile","click",{analytics:{category:"MOBILE-APP-".concat(window.__NAVIGATION_PRELOADED_STATE__.os),action:"DOWNLOAD-MENU",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"}})})();}},{s:function(){"use strict";(function(){window.__navigation_tracking__("[data-js=cp]","click",{analytics:{category:"CURRENT_LOCATION",action:"NAVIGATION",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"},melidata:{path:"/current_location/navigation/pick",data:{app:window.__NAVIGATION_PRELOADED_STATE__.application},type:"event"}})})();}},{s:function(){(function() {
#     var defaults = {
#         imageLoadClassName: 'lazy-loadable', // 'lazy-loadable' || 'onload-loadable'
#         options: {
#             rootMargin: '360px',
#             loadMode: 'lazy' // 'lazy' || 'onload'
#         }
#     };
#     var dataSrcKey = 'data-src';
#     var dataSrcFallbackKey = 'data-src-fallback';
#     var dataSrcSetKey = 'data-srcset';
#
#     // IntersectionObserver has partial support in chrome <= 57 (https://caniuse.com/#feat=intersectionobserver)
#     var supportIntersectionObserver = 'IntersectionObserver' in window && 'IntersectionObserverEntry' in window && 'isIntersecting' in window.IntersectionObserverEntry.prototype;
#
#   function mergeOptions(target, source) {
#     var list = [target, source];
#     var cloned = {};
#
#     for (var i = 0; i <= list.length; i++) {
#       if (typeof list[i] === 'object' && list[i]) {
#         for (var prop in list[i]) {
#           cloned[prop] = list[i][prop];
#         }
#       }
#     }
#     return cloned;
#   }
#
#   function imageLazyLoading(imageLoadClassName, options) {
#         if (!imageLoadClassName && options && options.loadMode === 'onload') {
#           imageLoadClassName = 'onload-loadable';
#         }
#         imageLoadClassName = imageLoadClassName || defaults.imageLoadClassName;
#
#         options = mergeOptions(defaults.options, options);
#
#         var lazyImages = [].slice.call(document.querySelectorAll('.' + imageLoadClassName));
#
#         function loadImages(img) {
#             function setSource(attr, srcKey, srcFallbackKey) {
#                 if (img.hasAttribute(srcKey)) {
#                     var dataSrc = img.getAttribute(srcKey);
#                     if (srcFallbackKey && img.hasAttribute(srcFallbackKey)) {
#                       var dataSrcFallback = img.getAttribute(srcFallbackKey);
#                       img.onload = function() {
#                         img.removeAttribute(srcFallbackKey);
#                       }
#                       img.onerror = function() {
#                         this.src = dataSrcFallback;
#                         this.srcset = dataSrcFallback;
#                         img.removeAttribute(srcFallbackKey);
#                         img.onerror = null;
#                       };
#                     }
#                     img.setAttribute(attr, dataSrc);
#                     img.removeAttribute(srcKey);
#                 }
#             }
#
#             setSource('src', dataSrcKey, dataSrcFallbackKey);
#             setSource('srcset', dataSrcSetKey);
#
#             img.classList.remove(imageLoadClassName);
#
#             if (img.classList.length < 1) {
#                 img.removeAttribute('class');
#             }
#         }
#
#         function loadAllImages() {
#           lazyImages.forEach(function(image) {
#                 loadImages(image);
#             });
#         }
#
#         if (supportIntersectionObserver && options.loadMode === 'lazy') {
#             var lazyImageObserver = new IntersectionObserver(function(entries, observer) {
#                 entries.forEach(function(entry) {
#                 if (entry.isIntersecting) {
#                     var lazyImage = entry.target;
#                     loadImages(lazyImage);
#                     lazyImageObserver.unobserve(lazyImage);
#                 }
#                 });
#             }, options);
#
#             lazyImages.forEach(function(lazyImage) {
#                 lazyImageObserver.observe(lazyImage);
#             });
#
#             window.lazyImageObserver = lazyImageObserver;
#
#         } else if ((!supportIntersectionObserver && options.loadMode === 'lazy') || options.loadMode === 'onload') {
#             if (document.readyState === 'complete') {
#                 loadAllImages();
#             } else {
#                 window.addEventListener('load', function() {
#                     loadAllImages();
#                 });
#             }
#         }
#     }
#
#     function initLazyLoading() {
#       imageLazyLoading();
#       imageLazyLoading('onload-loadable', { loadMode: 'onload' });
#     }
#
#     window.imageLazyLoading = imageLazyLoading;
#     initLazyLoading();
# }());
# }}]);
#   var scripts = [{s:function(){(function(){var ccb=function(e){var n={};function t(o){if(n[o])return n[o].exports;var a=n[o]={i:o,l:!1,exports:{}};return e[o].call(a.exports,a,a.exports,t),a.l=!0,a.exports}return t.m=e,t.c=n,t.d=function(e,n,o){t.o(e,n)||Object.defineProperty(e,n,{enumerable:!0,get:o})},t.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},t.t=function(e,n){if(1&n&&(e=t(e)),8&n)return e;if(4&n&&"object"==typeof e&&e&&e.__esModule)return e;var o=Object.create(null);if(t.r(o),Object.defineProperty(o,"default",{enumerable:!0,value:e}),2&n&&"string"!=typeof e)for(var a in e)t.d(o,a,function(n){return e[n]}.bind(null,a));return o},t.n=function(e){var n=e&&e.__esModule?function(){return e.default}:function(){return e};return t.d(n,"a",n),n},t.o=function(e,n){return Object.prototype.hasOwnProperty.call(e,n)},t.p="",t(t.s=0)}([function(e,n,t){e.exports=t(1)},function(e,n,t){function o(e,n){var t=Object.keys(e);if(Object.getOwnPropertySymbols){var o=Object.getOwnPropertySymbols(e);n&&(o=o.filter((function(n){return Object.getOwnPropertyDescriptor(e,n).enumerable}))),t.push.apply(t,o)}return t}function a(e){for(var n=1;n<arguments.length;n++){var t=null!=arguments[n]?arguments[n]:{};n%2?o(Object(t),!0).forEach((function(n){c(e,n,t[n])})):Object.getOwnPropertyDescriptors?Object.defineProperties(e,Object.getOwnPropertyDescriptors(t)):o(Object(t)).forEach((function(n){Object.defineProperty(e,n,Object.getOwnPropertyDescriptor(t,n))}))}return e}function c(e,n,t){return n in e?Object.defineProperty(e,n,{value:t,enumerable:!0,configurable:!0,writable:!0}):e[n]=t,e}var r=t(2),i=t(3).bannerOptOutModalEvents;e.exports=function(e,n,t,o,c,s){var l=arguments.length>6&&void 0!==arguments[6]?arguments[6]:"cookie-consent-banner",u=arguments.length>7?arguments[7]:void 0,d=l,f="cookie-consent-snackbar--success",v="cookie-consent-snackbar--error",p="cookies-banner-top-content",m=function(n,t){var o=(t||e).getElementsByClassName(n);if(0===o.length)throw new Error("No element with class ".concat(n," is present"));if(1!==o.length)throw new Error("More than one element with class ".concat(n," is present"));return o[0]},_=function(e){return e.parentNode.removeChild(e)},b=function(){try{return m(p,m(d))}catch(e){return null}},y=function(e,n,t){var o=m(n);_(o);var a=m(e);t&&a.appendChild(t),a.classList.remove("cookie-consent-snackbar--hidden"),setTimeout((function(){return a.classList.remove("cookie-consent-snackbar--collapsed")})),m("cookie-consent-snackbar__close",a).addEventListener("click",(function(){a.classList.add("cookie-consent-snackbar--collapsed"),setTimeout((function(){_(a),window.onCookieConsentBannerClosed&&window.onCookieConsentBannerClosed()}),400)}))},E=function(e){return y(f,v,e)},k=function(e){return y(v,f,e)},h=function(t,c){if(o)try{var r={categories:a(a({},n),t)};o.userId&&(r.userId=o.userId);var i=o.cookieName,s=o.maxAge,l=o.path,u=o.domain,d=o.secure,f=o.sameSite,v=["".concat(i,"=").concat(encodeURIComponent(JSON.stringify(r))),"domain=".concat(u),"path=".concat(l)].concat(s?"max-age=".concat(s):[]).concat(f?"samesite=".concat(f):[]).concat(d?"secure":[]).join("; ");e.cookie=v}catch(e){k(c)}E(c)},g=function(e){if(!t)return h(null,e),void r(n);try{var o=new window.XMLHttpRequest;o.open("PUT",t.url,!0),o.setRequestHeader("Content-type","application/json;charset=UTF-8"),o.withCredentials=!0,o.onreadystatechange=function(){if(4===o.readyState)if(200===o.status){var t;try{t=JSON.parse(o.responseText).cookies_preferences}catch(e){t=null}h(t,e),r(a(a({},n),t))}else k(e)},o.send(JSON.stringify(a(a({},t.payload),{},{cookies_preferences:n})))}catch(n){k(e)}},w=m("".concat(d,"__action--key-accept")),O=m("".concat(d,"__action--key-customize")),C=function(e,n){"undefined"!=typeof melidata&&melidata("cleanAndSend",e,n)};w.addEventListener("click",(function(){var e=b();try{g(e),C("event",{path:"/navigation/cookies_con ...
# ccb(document,{"advertising":true},null,{"userId":null,"cookieName":"cookiesPreferencesNotLogged","path":"/","domain":"mercadolibre.com.co","secure":true,"sameSite":"none","maxAge":31536000},"bottomOptOut",{"closeElements":[]},"cookie-consent-banner-opt-out",{"openButton":"cookie-consent-banner-opt-out__action--key-customize","wrapper":"cookie-consent-banner-opt-out__modal","iframeUrl":"https://www.mercadolibre.com.co/privacy-preferences/cookies","saveText":"Guardar"});})()}},{s:function(){
#       !function(n,e){n.mitt=e()}(this,function(){function n(n){return n=n||Object.create(null),{on:function(e,t){(n[e]||(n[e]=[])).push(t)},off:function(e,t){n[e]&&n[e].splice(n[e].indexOf(t)>>>0,1)},emit:function(e,t){(n[e]||[]).map(function(n){n(t)}),(n["*"]||[]).map(function(n){n(e,t)})}}}return n});
#       window.freya = mitt();
#     }},{s:"https://http2.mlstatic.com/ui/searchbox/2.7.0/index.js",c:function(){
#       if (window.Searchbox) {
#         new window.Searchbox('.nav-search-input', {
#           platformId: 'ML',
#           siteId: 'MCO',
#           siteDomain: 'mercadolibre.com.co',
#           limit: 6,
#           searchEndpoint: 'https://listado.mercadolibre.com.co/$query',
#           categoryEndpoint: 'null',
#           categoryCheckbox: document.getElementById('categorySearch'),
#           loggedIn: false,
#
#           bus: window.freya,
#           deviceType: 'desktop'
#         });
#       }
#     }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/modal/v1.0.6/modal.js"},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/onboarding-cp/v1.0.15/onboarding-cp.js",c:function(){(function () {
#           new window.OnboardingCP({
#             bus: window.meli,
#             isNewBuyer: true,
#             isMobile: false,
#             trigger: '.nav-menu-cp',
#             locale: 'es_CO',
#             domain: 'mercadolibre.com.co',
#             siteId: 'MCO',
#             isInferred: false,
#           });
#         }());
#     }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/categories/v1.3.2/categories.js",c:function(){
#       (function(win, freya) {
#         if (win.CategoriesWidget && typeof freya !== 'undefined') {
#           new CategoriesWidget({
#             bus: freya,
#             endpoint: '//www.mercadolibre.com.co/menu/departments',
#           });
#         }
#       })(window, window.freya);
#     }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/nav-cart/v1.5.4/CartWidget.js",c:function(){
#         if (window.CartWidget) {
#           new window.CartWidget({
#             element: document.getElementById('nav-cart'),
#             endpoints: {
#               get: 'https://www.mercadolibre.com.co/gz/cart/info',
#               post: 'https://www.mercadolibre.com.co/gz/cart/api/item',
#             },
#             link: 'https://www.mercadolibre.com.co/gz/cart',
#             isMobile: false,
#             bus: freya,
#             locale: 'es',
#           });
#         }
#         }},{s:"https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/snackbar/v1.0.1/snackbar.js",c:function(){
#         (function (win, freya) {
#           if (win.SnackbarWidget && typeof freya !== 'undefined') {
#             new win.SnackbarWidget({
#               bus: freya,
#             });
#           }
#         }(window, window.freya));
#         }},{s:function(){!function(e,t){function n(){var n=setInterval(function(){try{var c=Math.max(t.body.scrollHeight,t.body.offsetHeight,t.documentElement.clientHeight,t.documentElement.scrollHeight,t.documentElement.offsetHeight),o=e.pageYOffset||t.documentElement.scrollTop||t.body.scrollTop||0;e.innerHeight+o>=c?clearInterval(n):e.scrollBy(0,20)}catch(e){clearInterval(n)}},15)}var c=t.getElementById("nav-footer-access-switch");e.addEventListener&&c&&c.addEventListener("change",function(){this.checked||setTimeout(n,200)})}(window,document);}},{s:"https://http2.mlstatic.com/storage/tag-manager/google-gtag-search-mco.js"},{s:function(){"use strict";(function(a){var b=a.location.hostname.substr(a.location.hostname.indexOf("."),a.location.hostname.length);if(-1!==b.indexOf("mercadolibre")||-1!==b.indexOf("mercadolivre")||-1!==b.indexOf("mercadopago")){var c="https://matt"+b,d=a.location.href;if(c=c.concat("?go=").concat(encodeURIComponent(d)),navigator&&navigator.sendBeacon)status=navigator.sendBeacon(c);else{var e=new XMLHttpRequest;e.open("GET",c),e.send()}}})(window);}},{s:function(){
#           window.__PRELOADED_STATE__ =
#       {"siteId":"MCO","cookies":{},"lowEnd":false,"deviceType":"desktop","country":{"id":"CO","name":"Colombia","locale":"es_CO","currency_id":"COP","decimal_separator":",","thousands_separator":".","time_zone":"GMT-05:00","geo_information":{"location":{"latitude":4.570868,"longitude":-74.29733}},"states":[{"id":"CO-AMA","name":"Amazonas"},{"id":"CO-ANT","name":"Antioquia"},{"id":"CO-ARA","name":"Arauca"},{"id":"CO-ATL","name":"Atlantico"},{"id":"CO-DC","name":"Bogotá D.C."},{"id":"CO-BOL","name":"Bolivar"},{"id":"CO-BOY","name":"Boyaca"},{"id":"CO-CAL","name":"Caldas"},{"id":"CO-CAQ","name":"Caqueta"},{"id":"CO-CAS","name":"Casanare"},{"id":"CO-CAU","name":"Cauca"},{"id":"CO-CES","name":"Cesar"},{"id":"CO-CHO","name":"Choco"},{"id":"CO-CUN","name":"Cundinamarca"},{"id":"CO-COR","name":"Córdoba"},{"id":"CO-GUA","name":"Guainía"},{"id":"CO-LAG","name":"Guajira"},{"id":"CO-GUV","name":"Guaviare"},{"id":"CO-HUI","name":"Huila"},{"id":"CO-MAG","name":"Magdalena"},{"id":"CO-MET","name":"Meta"},{"id":"CO-NAR","name":"Nariño"},{"id":"CO-NSA","name":"Norte De Santander"},{"id":"CO-PUT","name":"Putumayo"},{"id":"CO-QUI","name":"Quindio"},{"id":"CO-RIS","name":"Risaralda"},{"id":"CO-SAP","name":"San Andres y Providencia"},{"id":"CO-SAN","name":"Santander"},{"id":"CO-SUC","name":"Sucre"},{"id":"CO-TOL","name":"Tolima"},{"id":"CO-VAC","name":"Valle Del Cauca"},{"id":"CO-VAU","name":"Vaupes"},{"id":"CO-VID","name":"Vichada"}],"currencies":{"COP":{"id":"COP","symbol":"$","description":"Peso colombiano","decimal_places":0},"USD":{"id":"USD","symbol":"U$S","description":"Dólar","decimal_places":2}}},"currentUser":{"loggedIn":false,"loginUrl":"https:\u002F\u002Fwww.mercadolibre.com\u002Fjms\u002Fmco\u002Flgz\u002Flogin?platform_id=ML&go=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos&loginType=explicit","nickname":"","id":""},"initialState":{"adult_info":{"is_zrp_adult":false,"show_adult_filter":true,"adult_results":2},"view_options":{"id":"VIEW_OPTIONS","type":"VIEW_OPTIONS","state":"VISIBLE","tooltip":{"title":"¡Encuentra más fácil lo que buscas!","label":{"text":"Ordena los resultados por relevancia o precio, y elige verlos como lista o grilla."},"action":{"label":{"text":"Entendido"}}},"sort":{"label":"Ordenar por","sorts":[{"id":"relevance","name":"Más relevantes","disclaimer":"","selected":true,"has_disclaimer":false},{"url":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos_OrderId_PRICE_NoIndex_True","id":"price_asc","name":"Menor precio","selected":false,"has_disclaimer":false},{"url":"https:\u002F\u002Flistado.mercadolibre.com.co\u002Faudifonos_OrderId_PRICE*DESC_NoIndex_True","id":"price_desc","name":"Mayor precio","selected":false,"has_disclaimer":false}],"has_disclaimer":false}},"bookmark":{"label":{"text":"Favorito"},"show_user_bookmarks":true},"ads_metadata":{"destination_url":"https:\u002F\u002Fpublicidad.mercadolibre.com.co\u002Fmain","title":"","label_long":"Anuncia con MercadoLibre Publicidad","label_short":"Anuncia aquí","track_url":"https:\u002F\u002Fprint1.mercadoclics.com\u002Fmclics\u002Fv2\u002Fprints\u002Fexternal\u002FMCO\u002Fcount?d=RHtrAJjh8mWVOiZmhvS3BC2Le6YViHtkAeNNE5nY%2BM%2BeGQx2j4cCUQTVJNP1fiuIZJyFUnn0YLx6SIUA8%2BvdDqZKgy5rU4BqR4%2FoygV42pk5ORL%2FTXxLMK7dXfnf21Qv3%2BGEvR7soz1Wp6i5pLrMhoFg%2BsRlqR%2FpPolcMpqXscAfglyVYqTW42sbmdQwSH1aQKWfEkRgcY9boXTzVRHN6JZe%2FHrCSFXbtIPqHO5guxW%2FdvBuo1tzSMPRipg6mPXhwlLgJMy85VSzvXj2UqlCko63qJnj%2BIQQMr5ma24G1O5%2BLezGGDJa001mZJyI2kshwTo8QzlQO%2FVjIKoG%2FO4pind4VVELnjBAUY4TT%2FmaL6L7f8MH8oSwdeiYg2okUQRHSv3%2BYH%2Bj0dJJimGdDatLTXrLiDLKM1wIFmihlUdeL%2F2qZ2uG7k%2BaCyw%2Bl69DmsdJ5TgpQNk72b2pE0eIqw5daiqGLTpVU4DO%2FGDJy21aPUdsOPIJaJzIM9ZRnh%2B7r9CANdl4HJH08ymBtzFk5xNEo1g1dY65A0w5Wan0bcr8wHVVzpuzI%2B%2BSJnNk2crHSyVm%2Ffus0601fVP2gXCT3IJldTAc2%2Fd3o35VoN5I242v4zncL8rbZDj0%2B11WYfDSFmacI%2FgnqhLIG9HbrJcEnD6hcaz29vELUrc0wFPzudfx2%2B4etVhqYk7iUYwF%2FKh12CUZPpkjOYdDpYGo67LA%2BQBU%2FHHABD%2B6no%2FJ1mGej1DHCqfK0bOvjT9D4XnaQU0GE2dsZg5D8qCuYSLz3Jz2d1iTUQCp4rYohlfwJR7uo4mbnjMrhR ...
#         }},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/polyfill.102ca50a.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/search.desktop.5078c46c.js"},{s:function(){
#         var trackMclics = document.createElement('img');
#         trackMclics.src = 'https://print1.mercadoclics.com/mclics/v2/prints/external/MCO/count?d=RHtrAJjh8mWVOiZmhvS3BC2Le6YViHtkAeNNE5nY%2BM%2BeGQx2j4cCUQTVJNP1fiuIZJyFUnn0YLx6SIUA8%2BvdDqZKgy5rU4BqR4%2FoygV42pk5ORL%2FTXxLMK7dXfnf21Qv3%2BGEvR7soz1Wp6i5pLrMhoFg%2BsRlqR%2FpPolcMpqXscAfglyVYqTW42sbmdQwSH1aQKWfEkRgcY9boXTzVRHN6JZe%2FHrCSFXbtIPqHO5guxW%2FdvBuo1tzSMPRipg6mPXhwlLgJMy85VSzvXj2UqlCko63qJnj%2BIQQMr5ma24G1O5%2BLezGGDJa001mZJyI2kshwTo8QzlQO%2FVjIKoG%2FO4pind4VVELnjBAUY4TT%2FmaL6L7f8MH8oSwdeiYg2okUQRHSv3%2BYH%2Bj0dJJimGdDatLTXrLiDLKM1wIFmihlUdeL%2F2qZ2uG7k%2BaCyw%2Bl69DmsdJ5TgpQNk72b2pE0eIqw5daiqGLTpVU4DO%2FGDJy21aPUdsOPIJaJzIM9ZRnh%2B7r9CANdl4HJH08ymBtzFk5xNEo1g1dY65A0w5Wan0bcr8wHVVzpuzI%2B%2BSJnNk2crHSyVm%2Ffus0601fVP2gXCT3IJldTAc2%2Fd3o35VoN5I242v4zncL8rbZDj0%2B11WYfDSFmacI%2FgnqhLIG9HbrJcEnD6hcaz29vELUrc0wFPzudfx2%2B4etVhqYk7iUYwF%2FKh12CUZPpkjOYdDpYGo67LA%2BQBU%2FHHABD%2B6no%2FJ1mGej1DHCqfK0bOvjT9D4XnaQU0GE2dsZg5D8qCuYSLz3Jz2d1iTUQCp4rYohlfwJR7uo4mbnjMrhRqSwL01UpEH1V4bitGRdGd4FjJeSr6bidPu%2Fh4U0RSK6YsOniGVY%2B%2FI93bL7r1pXIVsWSj%2FcgerLvfDZmliC1pLR8yy%2BS2wdES1HK2QqinOe2nzhkAxmJ2IbEM5Xe6RQM%2Bqyh09xry1hK6jJHsWdK1C8YcCJFcDWjMrOVtBtCRfK6FJPQE8lc1QwbVenvSs0godbQxlTFgjrB6QEZQwgo%2FCQGyEg%2FszttT2JK5MQj6oKCRwc0QDQePAGZTJyRgCm4LMDcCuIecfpvAfr%2B0hhI1pqvQe7hsVMVrPNJtPE7YsmL9ZKFo0n9PXgu%2BNNvTZTXFHIRP3z4hdjtglKWiu6%2BoZlztCFAcOdMx9eyXNNkGrftRnJsJVi%2Brq1z3%2B%2F3j5bA5dg6CdcMKPlMPEwYLknxvsXz4hWmsiFin9Pe3nDnJbhlJCD6tcW389mKGLSbZet3a6NEKeYb6E5TjvCMq%2FjM2cNopQS9TIrwjIwO46hrpyfgr3bNzG6PEAbdUh3%2F2%2BciCV7Yxg7U8BAASIhNG4R5wUJ1twlJCptdq28d1Rlu9fABTuYSPm68Ybu3sYIArR%2BuK1Wy%2FsICSbipBkaFthK3x5M2FB%2FqREcYdB1HYph5mQeI1m69BU5%2Blc3qf2e%2F1Q8k0cuTlXlPjdg7RhWEavW02FQmmFJjGsybqLCWlGJYtmPY09Fkyija8ARljar0%2Bf0AX10G5DuCp1l3H0vFqbikCthimhRD1XdfoIeCc%3D&rb=x';
#       }},{s:function(){
#
#
#      var mktconfig = {
#     'selector' : 'searchResults',
#     'results': 'MCO812367769,MCO618049088,MCO618542478,MCO613267539,MCO652324942',
#     'categories': 'MCO5072,MCO3697,MCO5072,MCO31377,MCO3697',
#     'siteId' : 'MCO',
#     'd2id': '',
#     'query': 'audifonos',
#     'platform' : 'STD'
#         }
#
#         var Search = Search || {};
#
#
#         ;(function (Search, win, doc) {
#
#           function MarketingTags(options) {
#             this.platform = options.platform || '';
#             this.siteId = options.siteId || '';
#             this.items = options.results || [];
#             this.categories = options.categories || [];
#             this.d2id = options.d2id;
#             this.query = options.query;
#
#             if (!this.items || !this.platform || !this.siteId || !this.categories) { throw new Error('MarketingTags: error in incoming params')}
#
#               this.init();
#
#               return this;
#
#           };
#
#           MarketingTags.prototype.init = function () {
#             var data = {}, categoriesIds = [];
#
#             if (this.items) {
#               data.items = this.items;
#               categoriesIds = this.unique(this.categories);
#
#               if(categoriesIds.length == 1){
#                 data.categoryId = categoriesIds
#               }
#
#               if (this.d2id) {
#                 data.d2id = this.d2id
#               }
#
#               if (this.query) {
#                 data.query = this.query;
#               }
#
#               this.start(data);
#               this.createIframe();
#             }
#           };
#
#           MarketingTags.prototype.createIframe = function () {
#             var iframe = doc.createElement("iframe"),
#                   scriptTag = doc.getElementsByTagName('script')[0],
#               elem = iframe.frameElement || iframe;
#
#                 elem.style.width = 0;
#               elem.style.height = 0;
#               elem.style.border = 0;
#               elem.style.position = 'absolute';
#
#
#                 iframe.src = this.url;
#                 scriptTag.parentNode.insertBefore(iframe, scriptTag);
#           };
#
#           MarketingTags.prototype.start = function (data) {
#             var millisecondsInMinute = 60000
#             var minuteInPartition = 60 * 5
#             var currentMilliseconds = new Date().getTime()
#             var currentSeconds = parseInt(currentMilliseconds / millisecondsInMinute)
#             var timeHash = parseInt(currentSeconds/minuteInPartition)*minuteInPartition
#
#             this.url = "https://http2.mlstatic.com/storage/tag-manager/" + this.siteId + ".html?timehash="+ timeHash +"&platform=" + this.platform + "#" + JSON.stringify(data);
#
#           };
#
#           MarketingTags.prototype.unique = function(array){
#               var tmp = {},
#                 out = [];
#               for(var i = 0, n = array.length; i < n; ++i){
#                   if(!tmp[array[i]]) { tmp[array[i]] = true; out.push(array[i]); }
#               }
#               return out;
#           }
#
#             Search.MarketingTags = MarketingTags;
#
#         })(Search, window, document);
#
#           new Search.MarketingTags(mktconfig);
#     }},{s:function(){
#     (function(h,o,t,j,a,r){
#       h.hj= h.hj || function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#       h._hjSettings={hjid:550932,hjdebug:false,hjsv:5};
#       a=o.getElementsByTagName('head')[0];
#       r=o.createElement('script');r.async=1;
#       r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#       a.appendChild(r);
#     })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#     hj('tagRecording', ["user_type: normal"]);
#
#     }},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/framework.83d0c536.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/lib-428dfce9.5b2f9761.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/lib-47e0d0a8.33ffeeb6.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/lib-8547c38c.4fc00775.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/295.2c87c984.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/636.a5c4d7ed.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/652.c1695bf5.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/179.275b67dd.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/501.cb62b487.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/949.a1b9fe8f.js"},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/880.e376bc8d.js"}];
#   if (doc.readyState === 'complete') {
#     loadScripts(scripts);
#   } else {
#     win.addEventListener('load', function(){ loadScripts(scripts); });
#   }
# })(window, document);</script></body></html>

# %% [markdown]
# Y tomamos lo que nos interesa...

# %%
results = soup.find(id="root-app")
print(results.prettify())
# Out:
# <main id="root-app" role="main">
#  <div class="ui-search">
#   <svg class="ui-search-svg-sprites" height="0" width="0" xmlns="http://www.w3.org/2000/svg">
#    <defs>
#     <symbol id="full" viewbox="0 0 100 32">
#      <path d="M6.4 0h12.8l-6.4 11.429h10.667l-17.067 20.571 4.267-13.714h-10.667l6.4-18.286zM34.626 23.467h-4.77l4.077-18.498h13.562l-0.915 4.16h-8.791l-0.61 2.884h8.57l-0.915 4.16h-8.597l-1.609 7.294zM57.687 23.799c-5.685 0-8.486-2.718-8.486-6.601 0-0.305 0.083-0.943 0.139-1.22l2.441-11.010h4.853l-2.413 10.899c-0.028 0.139-0.083 0.444-0.083 0.777 0.028 1.525 1.193 2.995 3.55 2.995 2.551 0 3.855-1.609 4.326-3.772l2.413-10.899h4.826l-2.413 10.982c-0.998 4.493-3.439 7.849-9.152 7.849zM82.33 23.467h-12.203l4.077-18.498h4.77l-3.134 14.338h7.405l-0.915 4.16zM98.596 23.467h-12.203l4.077-18.498h4.77l-3.134 14.338h7.405l-0.915 4.16z">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="start-empty">
#      <path d="M5.256 8L2.131 9.648l.597-3.49L.2 3.684l3.494-.509L5.256 0l1.562 3.176 3.494.51-2.528 2.471.597 3.491z" fill="#ddd" fill-rule="evenodd">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="start-full">
#      <path d="M5.056 8L1.931 9.648l.597-3.49L0 3.684l3.494-.509L5.056 0l1.562 3.176 3.494.51-2.528 2.471.597 3.491z" fill-rule="evenodd">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="start-half">
#      <g fill-rule="evenodd">
#       <path d="M5.256 8L2.131 9.648l.597-3.49L.2 3.684l3.494-.509L5.256 0l1.562 3.176 3.494.51-2.528 2.471.597 3.491z" fill="#ddd">
#       </path>
#       <path d="M5.272 8.026L2.137 9.679l.6-3.502L.2 3.697l3.505-.51L5.272 0z">
#       </path>
#      </g>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="bookmark">
#      <g fill-rule="evenodd" stroke-width="1.0">
#       <path d="M10.977 2.705C11.93 1.618 13.162 1 14.895 1c3.333 0 5.607 2.152 5.607 6.274 0 .08-.002.16-.005.24-.107 2.596-1.876 5.253-4.737 7.892a33.77 33.77 0 0 1-3.165 2.57 32.447 32.447 0 0 1-1.45.983l-.394.243-.394-.243-.009-.005-.021-.014-.08-.05a32.447 32.447 0 0 1-1.34-.914 33.77 33.77 0 0 1-3.165-2.57c-2.86-2.639-4.63-5.296-4.737-7.892A5.839 5.839 0 0 1 1 7.274C1 3.152 3.274 1 6.607 1c1.733 0 2.966.618 3.918 1.705.056.064.137.165.226.282.09-.117.17-.218.226-.282z">
#       </path>
#      </g>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="sum">
#      <path d="M625.784 488.568h187.392v46.863h-187.392v187.392h-46.863v-187.392h-187.392v-46.863h187.392v-187.392h46.863v187.392z">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="rest">
#      <path d="M391.529 542.118v-60.235h421.647v60.235z">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="close">
#      <path d="M409.6 512l-358.4 358.4 102.4 102.4 358.4-358.4 358.4 358.4 102.4-102.4-358.4-358.4 358.4-358.4-102.4-102.4-358.4 358.4-358.4-358.4-102.4 102.4z">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="supermarket-logo">
#      <path d="M7.731 23.774c4.224 0 6.733-2.739 6.733-5.862 0-4.941-8.346-4.659-8.346-6.886 0-0.922 0.973-1.69 2.278-1.69 1.741 0 3.814 0.691 5.094 2.176l2.278-2.611c-1.536-1.766-4.096-2.765-6.81-2.765-4.198 0-6.682 2.739-6.682 5.555 0 4.992 8.32 4.531 8.32 6.938 0 0.87-0.742 1.92-2.586 1.92-2.355 0-4.582-1.075-5.76-2.662l-2.253 2.688c1.434 1.894 4.378 3.2 7.731 3.2zM24.926 23.774c5.043 0 7.194-2.995 8.090-7.142l2.278-10.24h-3.712l-2.227 10.163c-0.538 2.381-1.818 4.019-4.429 4.019-2.406 0-3.661-1.459-3.686-3.174 0-0.358 0.051-0.691 0.102-0.845l2.227-10.163h-3.686l-2.253 10.24c-0.051 0.282-0.128 0.845-0.128 1.178 0 3.558 2.534 5.965 7.424 5.965zM38.972 23.467l1.357-6.093h4.275c5.35 0 7.066-3.712 7.066-6.246 0-2.586-2.022-4.736-4.762-4.736h-7.808l-3.763 17.075h3.635zM44.834 14.174h-3.814l1.024-4.582h3.712c1.254 0 2.125 0.794 2.125 1.92 0 1.51-1.229 2.662-3.046 2.662zM63.846 23.467l0.691-3.2h-8.422l0.845-3.891h8.269l0.691-3.2h-8.243l0.794-3.584h8.422l0.717-3.2h-12.083l-3.763 17.075h12.083zM70.75 23.467l1.331-6.067h2.816l2.022 6.067h4.045l-2.381-6.323c2.765-0.512 4.864-2.867 4.864-5.939 0-2.97-2.509-4.813-5.274-4.813h-7.296l-3.763 17.075h3.635zM76.612 14.199h-3.814l1.024-4.608h3.661c1.126 0 2.176 0.819 2.176 1.971 0 1.536-1.152 2.637-3.046 2.637zM87.637 23.467l2.714-12.314 2.099 12.314h1.587l7.526-12.314-2.714 12.314h3.661l3.763-17.075h-5.248l-6.502 10.675-1.792-10.675h-4.966l-3.763 17.075h3.635zM118.4 23.467l0.691-3.2h-8.422l0.845-3.891h8.269l0.691-3.2h-8.243l0.794-3.584h8.422l0.717-3.2h-12.083l-3.763 17.075h12.083zM125.303 23.467l1.331-6.067h2.816l2.022 6.067h4.045l-2.381-6.323c2.765-0.512 4.864-2.867 4.864-5.939 0-2.97-2.509-4.813-5.274-4.813h-7.296l-3.763 17.075h3.635zM131.166 14.199h-3.814l1.024-4.608h3.661c1.126 0 2.176 0.819 2.176 1.971 0 1.536-1.152 2.637-3.046 2.637zM147.772 23.774c2.227 0 5.069-0.794 7.040-3.302l-2.816-1.894c-0.973 1.203-2.56 1.971-4.019 1.971-2.944 0-4.787-1.997-4.787-4.659 0-3.763 2.714-6.554 5.939-6.554 1.971 0 3.61 0.973 4.275 2.79l3.482-1.178c-0.998-2.586-3.405-4.838-7.578-4.838-5.299 0-9.933 3.968-9.933 10.010 0 4.659 3.686 7.654 8.397 7.654zM158.925 23.467l1.69-2.893h7.322l0.435 2.893h3.942l-2.816-17.075h-4.557l-10.342 17.075h4.326zM167.654 17.374h-5.325l4.275-7.347 1.050 7.347zM181.035 23.467c8.038 0 11.059-5.248 11.059-9.754 0-4.403-3.61-7.322-7.398-7.322h-6.605l-3.763 17.075h6.707zM181.7 20.267h-3.021l2.355-10.675h2.995c2.509 0 4.301 1.894 4.301 4.378 0 3.405-2.509 6.298-6.63 6.298zM202.351 23.774c5.632 0 9.933-4.454 9.933-10.035 0-4.685-3.686-7.629-8.397-7.629-5.632 0-9.933 4.429-9.933 10.010 0 4.685 3.661 7.654 8.397 7.654zM202.556 20.548c-2.739 0-4.787-1.792-4.787-4.659 0-3.661 2.586-6.554 5.888-6.554 2.739 0 4.813 1.792 4.813 4.659 0 3.661-2.611 6.554-5.914 6.554z">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="cart-volume-discount">
#      <path d="M2.04388 2.57091L3.77432 10.97H13.8226L15.265 3.77064H14.1025L12.8392 9.76997H4.75229L3.02185 1.37091H0.734863V2.57091H2.04388Z">
#      </path>
#      <path d="M4.93086 13.9697C5.59361 13.9697 6.13086 13.4324 6.13086 12.7697C6.13086 12.107 5.59361 11.5697 4.93086 11.5697C4.26812 11.5697 3.73086 12.107 3.73086 12.7697C3.73086 13.4324 4.26812 13.9697 4.93086 13.9697Z">
#      </path>
#      <path d="M12.7289 13.9697C13.3916 13.9697 13.9289 13.4324 13.9289 12.7697C13.9289 12.107 13.3916 11.5697 12.7289 11.5697C12.0661 11.5697 11.5289 12.107 11.5289 12.7697C11.5289 13.4324 12.0661 13.9697 12.7289 13.9697Z">
#      </path>
#      <path d="M6.53383 8.15687L12.1338 2.55687L11.2853 1.70834L5.6853 7.30834L6.53383 8.15687Z">
#      </path>
#      <path d="M6.73378 3.75697C7.28607 3.75697 7.73378 3.30925 7.73378 2.75697C7.73378 2.20468 7.28607 1.75697 6.73378 1.75697C6.1815 1.75697 5.73378 2.20468 5.73378 2.75697C5.73378 3.30925 6.1815 3.75697 6.73378 3.75697Z">
#      </path>
#      <path d="M11.9337 6.97023C11.9337 7.52251 11.486 7.97023 10.9337 7.97023C10.3814 7.97023 9.93373 7.52251 9.93373 6.97023C9.93373 6.41794 10.3814 5.97023 10.9337 5.97023C11.486 5.97023 11.9337 6.41794 11.9337 6.97023Z">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="international-logo">
#      <path d="M4.102 9.15c1.089 0 2.477-.388 3.44-1.613L6.166 6.61c-.475.588-1.25.963-1.964.963-1.438 0-2.338-.975-2.338-2.276 0-1.839 1.325-3.202 2.901-3.202.963 0 1.764.475 2.089 1.363l1.701-.575C8.067 1.62 6.891.52 4.853.52 2.263.52 0 2.459 0 5.41c0 2.277 1.801 3.74 4.102 3.74zM12.774 9.15c2.752 0 4.853-2.176 4.853-4.903 0-2.289-1.8-3.727-4.102-3.727-2.752 0-4.853 2.164-4.853 4.89 0 2.29 1.789 3.74 4.102 3.74zm.1-1.576c-1.338 0-2.338-.875-2.338-2.276 0-1.789 1.263-3.202 2.876-3.202 1.338 0 2.352.875 2.352 2.276 0 1.789-1.276 3.202-2.89 3.202zM26.878 9L28.717.658h-2.564l-3.177 5.215L22.1.658h-2.426L17.835 9h1.776l1.326-6.016L21.963 9h.775l3.677-6.016L25.09 9h1.788zM30.311 9l.663-2.977h2.089c2.614 0 3.452-1.813 3.452-3.052A2.296 2.296 0 0 0 34.188.658h-3.814L28.535 9h1.776zm2.852-4.54h-1.851l.5-2.239h1.813c.613 0 1.038.388 1.038.938 0 .738-.6 1.3-1.488 1.3h-.012zM43.118 9l-1.163-3.09c1.351-.25 2.377-1.4 2.377-2.901 0-1.45-1.226-2.351-2.577-2.351h-3.564L36.352 9h1.776l.65-2.964h1.376L41.142 9h1.976zM40.98 4.472h-1.851l.5-2.251h1.788c.55 0 1.064.4 1.064.963 0 .75-.563 1.288-1.489 1.288h-.012zM52.168 9L50.793.658h-2.227L43.513 9h2.114l.826-1.413h3.577L50.242 9h1.926zm-2.276-2.977h-2.601l2.088-3.59.513 3.59zM57.927 9L59.766.658H57.99L56.15 9h1.776zM67.05 9L68.89.658h-1.776l-1.189 5.315L63.248.658h-1.826L59.583 9h1.776l1.226-5.528L65.337 9h1.713zM72.41 9l1.488-6.779h2.439l.338-1.563H70.02l-.338 1.563h2.439L70.622 9h1.788zM81.878 9l.338-1.563H78.1l.412-1.902h4.04l.338-1.563h-4.027l.387-1.751h4.115l.35-1.563h-5.903L75.975 9h5.903zM90.033 9L88.87 5.91c1.35-.25 2.376-1.4 2.376-2.901 0-1.45-1.226-2.351-2.576-2.351h-3.565L83.266 9h1.776l.65-2.964h1.377L88.057 9h1.976zm-2.139-4.528h-1.851l.5-2.251h1.789c.55 0 1.063.4 1.063.963 0 .75-.563 1.288-1.488 1.288h-.013zM98.77 9L100.61.658h-1.776l-1.189 5.315L94.968.658h-1.826L91.303 9h1.776l1.226-5.528L97.057 9h1.713zM108.195 9L106.819.658h-2.227L99.54 9h2.113l.826-1.413h3.577L106.268 9h1.927zm-2.277-2.977h-2.601l2.088-3.59.513 3.59zM112.918 9.15c1.088 0 2.476-.388 3.439-1.613l-1.375-.926c-.476.588-1.251.963-1.964.963-1.438 0-2.339-.975-2.339-2.276 0-1.839 1.326-3.202 2.902-3.202.963 0 1.763.475 2.088 1.363l1.701-.575C116.883 1.62 115.707.52 113.668.52c-2.589 0-4.853 1.939-4.853 4.89 0 2.277 1.802 3.74 4.103 3.74zM118.778 9l1.838-8.342h-1.776L117.002 9h1.776zM124.937 9.15c2.751 0 4.852-2.176 4.852-4.903 0-2.289-1.801-3.727-4.102-3.727-2.752 0-4.853 2.164-4.853 4.89 0 2.29 1.789 3.74 4.103 3.74zm.1-1.576c-1.339 0-2.339-.875-2.339-2.276 0-1.789 1.263-3.202 2.876-3.202 1.339 0 2.352.875 2.352 2.276 0 1.789-1.276 3.202-2.889 3.202zM137.464 9l1.839-8.342h-1.776l-1.188 5.315-2.677-5.315h-1.826L129.998 9h1.776l1.225-5.528L135.751 9h1.713zM146.889 9L145.513.658h-2.226L138.234 9h2.114l.825-1.413h3.577L144.963 9h1.926zm-2.277-2.977h-2.601l2.089-3.59.512 3.59zM152.9 9l.337-1.563h-3.527l1.501-6.78h-1.788L147.584 9h5.316z">
#      </path>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="virtual-tour">
#      <g fill="none" fill-rule="evenodd">
#       <g fill="#00A650">
#        <g>
#         <g>
#          <g>
#           <g>
#            <g>
#             <path d="M20.746.002l.034.01C22.253.624 23 1.369 23 2.226c0 .942-.894 1.744-2.658 2.384-1.515.549-3.64.947-5.984 1.122l-.04.002c-.015 0-.037 0-.037-.01l-.001-.109-.001-.888c4.796-.209 7.684-1.724 7.684-2.501 0-.392-.595-.873-1.59-1.286-.033-.014-.064-.03-.092-.05l.465-.888zM2.137.033l.493.866-.04.02c-.915.377-1.487.812-1.56 1.181l-.007.078c0 .41.732 1.096 2.797 1.677 1.626.457 4.025.754 6.272.846l-.467-1.048c-.224-.165-.68-.5-.51-.717.172-.217.752.467.977.632l1.537 1.258c.21.155.263.45.117.664-.031.046-.071.088-.117.122L9.425 7.233c-.092.069-.201.102-.31.102-.153 0-.306-.067-.406-.195-.172-.217-.128-.526.096-.692l1.038-.763c-2.377-.09-4.577-.395-6.31-.882C1.223 4.153 0 3.245 0 2.178 0 1.338.737.608 2.19.011l-.053.022z" fill-rule="nonzero" transform="translate(-100 -572) translate(84 259) translate(0 296) translate(16 17) translate(0 3.918)">
#             </path>
#             <path d="M8.401 3.615L12.307 3.565 12.292 4.742 8.386 4.792z" transform="translate(-100 -572) translate(84 259) translate(0 296) translate(16 17) translate(0 3.918) rotate(50 10.347 4.179)">
#             </path>
#            </g>
#            <path d="M8.195 5.617L12.152 5.627 12.155 6.813 8.197 6.804z" transform="translate(-100 -572) translate(84 259) translate(0 296) translate(16 17) translate(0 3.918) rotate(-40 10.175 6.215)">
#            </path>
#           </g>
#           <path d="M6.506 5.66c1.363 0 2.267-.666 2.267-1.627 0-.788-.707-1.24-1.29-1.298.65-.106 1.2-.591 1.2-1.232C8.682.6 7.902 0 6.505 0c-1.01 0-1.734.37-2.194.887l.682.887c.386-.345.863-.525 1.364-.525.526 0 .92.156.92.5 0 .288-.32.428-.887.428h-.296c-.185-.001-.377-.003-.444-.008v1.256c.083-.008.502-.008.74-.008.747 0 .977.148.977.46 0 .304-.312.534-.92.534-.476 0-1.1-.189-1.495-.575l-.714.961c.427.493 1.215.863 2.267.863zm5.249 0c1.273 0 2.185-.797 2.185-1.923 0-1.166-.912-1.798-1.898-1.798-.558 0-1.076.262-1.347.624v-.066c0-.764.616-1.248 1.281-1.248.452 0 .748.115 1.052.361l.616-1.084C13.234.206 12.625 0 11.976 0c-1.659 0-2.71 1.084-2.71 2.834 0 1.569.755 2.826 2.489 2.826zm-.09-1.249c-.666 0-.929-.46-.97-.903.238-.247.575-.37.92-.37.427 0 .895.189.895.649 0 .304-.32.624-.846.624zm5.018 1.249c1.602 0 2.35-1.389 2.35-2.834 0-1.446-.748-2.826-2.35-2.826s-2.35 1.38-2.35 2.826c0 1.445.748 2.834 2.35 2.834zm0-1.249c-.657 0-.92-.616-.92-1.585 0-.97.263-1.577.92-1.577s.92.607.92 1.577c0 .969-.263 1.585-.92 1.585z" fill-rule="nonzero" transform="translate(-100 -572) translate(84 259) translate(0 296) translate(16 17)">
#           </path>
#          </g>
#         </g>
#        </g>
#       </g>
#      </g>
#     </symbol>
#    </defs>
#    <defs>
#     <symbol id="supermarket">
#      <path clip-rule="evenodd" d="M72.9268 6.92808C71.9982 8.13533 70.6597 8.51721 69.6105 8.51721C67.3916 8.51721 65.655 7.07591 65.655 4.83388C65.655 1.92663 67.8378 0.0172119 70.334 0.0172119C72.2997 0.0172119 73.4333 1.10127 73.9036 2.34547L72.2635 2.91214C71.95 2.0375 71.1782 1.56939 70.2496 1.56939C68.7301 1.56939 67.4519 2.91214 67.4519 4.72301C67.4519 6.00417 68.3201 6.96504 69.707 6.96504C70.3943 6.96504 71.142 6.59547 71.6003 6.01649L72.9268 6.92808ZM6.81352 5.6962C6.81352 7.1991 5.63171 8.51721 3.64192 8.51721C2.06215 8.51721 0.675323 7.88895 0 6.97736L1.06122 5.68388C1.61595 6.44765 2.66511 6.96504 3.77457 6.96504C4.64284 6.96504 4.99256 6.45997 4.99256 6.04113C4.99256 5.56661 4.33442 5.32377 3.55753 5.03712C2.43857 4.62427 1.07328 4.12052 1.07328 2.70272C1.07328 1.34765 2.24304 0.0295308 4.22077 0.0295308C5.49905 0.0295308 6.70499 0.509966 7.42855 1.35997L6.35527 2.61649C5.7523 1.90199 4.7755 1.56939 3.95546 1.56939C3.34044 1.56939 2.88218 1.93895 2.88218 2.38243C2.88218 2.81295 3.51655 3.04866 4.27564 3.33071C5.40624 3.75081 6.81352 4.27372 6.81352 5.6962ZM15.5525 5.08026C15.1304 7.07591 14.1175 8.51721 11.7418 8.51721C9.43844 8.51721 8.24456 7.35924 8.24456 5.64692C8.24456 5.48678 8.28074 5.21576 8.30486 5.08026L9.36608 0.152719H11.1026L10.0535 5.0433C10.0293 5.11721 10.0052 5.27736 10.0052 5.44982C10.0173 6.27518 10.6082 6.97736 11.7418 6.97736C12.9718 6.97736 13.5748 6.18895 13.828 5.0433L14.8772 0.152719H16.6258L15.5525 5.08026ZM18.3583 8.36939L18.9975 5.4375H21.0114C23.5318 5.4375 24.3398 3.65127 24.3398 2.4317C24.3398 1.1875 23.3871 0.152719 22.0967 0.152719H18.4186L16.6459 8.36939H18.3583ZM19.3231 3.89765H21.1199C21.9761 3.89765 22.555 3.3433 22.555 2.61649C22.555 2.07446 22.145 1.69257 21.554 1.69257H19.8054L19.3231 3.89765ZM30.076 8.36939L30.4016 6.82953H26.4341L26.832 4.95707H30.7272L31.0528 3.41721H27.1697L27.5435 1.69257H31.511L31.8487 0.152719H26.1567L24.384 8.36939H30.076ZM33.9551 5.44982L33.328 8.36939H31.6155L33.3883 0.152719H36.8252C38.1276 0.152719 39.3094 1.03968 39.3094 2.46866C39.3094 3.94692 38.3205 5.08026 37.0181 5.32663L38.1396 8.36939H36.2343L35.2816 5.44982H33.9551ZM36.0896 3.90997H34.2927L34.7751 1.69257H36.4996C37.0302 1.69257 37.5246 2.08678 37.5246 2.64112C37.5246 3.38026 36.9819 3.90997 36.0896 3.90997ZM42.5614 2.44402L41.2831 8.36939H39.5707L41.3434 0.152719H43.6829L44.5271 5.28968L47.5901 0.152719H50.0623L48.2896 8.36939H46.5651L47.8434 2.44402L44.2979 8.36939H43.5503L42.5614 2.44402ZM55.7744 8.36939L56.1 6.82953H52.1325L52.5304 4.95707H56.4256L56.7512 3.41721H52.8681L53.242 1.69257H57.2095L57.5471 0.152719H51.8551L50.0824 8.36939H55.7744ZM59.6535 5.44982L59.0264 8.36939H57.314L59.0867 0.152719H62.5236C63.826 0.152719 65.0078 1.03968 65.0078 2.46866C65.0078 3.94692 64.019 5.08026 62.7166 5.32663L63.8381 8.36939H61.9327L60.98 5.44982H59.6535ZM61.788 3.90997H59.9912L60.4735 1.69257H62.198C62.7286 1.69257 63.2231 2.08678 63.2231 2.64112C63.2231 3.38026 62.6804 3.90997 61.788 3.90997ZM74.8643 8.36939L75.6602 6.97736H79.1092L79.3142 8.36939H81.1714L79.8448 0.152719H77.6983L72.8263 8.36939H74.8643ZM76.4682 5.4375H78.9766L78.4821 1.90199L76.4682 5.4375ZM85.2796 8.36939C89.0662 8.36939 90.4892 5.84402 90.4892 3.67591C90.4892 1.55707 88.7888 0.152719 87.0041 0.152719H83.8928L82.12 8.36939H85.2796ZM84.1701 6.82953H85.5931C87.5347 6.82953 88.7165 5.4375 88.7165 3.7991C88.7165 2.60417 87.8723 1.69257 86.6905 1.69257H85.2796L84.1701 6.82953ZM95.321 8.51721C97.974 8.51721 100 6.37373 100 3.68823C100 1.43388 98.2635 0.0172119 96.0445 0.0172119C93.3915 0.0172119 91.3655 2.14837 91.3655 4.83388C91.3655 7.08823 93.09 8.51721 95.321 8.51721ZM93.1624 4.72301C93.1624 6.10272 94.1271 6.96504 95.4175 6.96504C96.9731 6.96504 98.2032 5.57301 98.2032 3.81141C98.2032 2.4317 97.2264 1.56939 95.936 1.56939C94.3803 1.56939 93.1624 2.96142 93.1624 4.72301Z" fill="#C70F5A" fill-rule="evenodd">
#      </path>
#     </symbol>
#    </defs>
#   </svg>
#   <div class="ui-search-main ui-search-main--without-header ui-search-main--only-products">
#    <aside class="ui-search-sidebar">
#     <div class="ui-search-breadcrumb">
#      <h1 class="ui-search-breadcrumb__title">
#       Audifonos
#      </h1>
#     </div>
#     <div class="ui-search-search-result">
#      <span class="ui-search-search-result__quantity-results">
#       224.257 resultados
#      </span>
#     </div>
#     <form class="ui-search-filter-groups" method="GET">
#      <div class="ui-search-filter-dl">
#       <ul>
#        <li class="ui-search-filter-highlighted ui-search-filter-highlighted-shipping_highlighted_fulfillment">
#         <section class="ui-search-filter-highlighted__container" role="group">
#          <button class="ui-search-filter-highlighted__content ui-search-filter-highlighted__content-button" name="button" type="button">
#           <label class="ui-search-filter-highlighted__title ui-search-icon-label" for="shipping_highlighted_fulfillment">
#            <svg aria-label="full" class="ui-search-icon ui-search-icon--full" viewbox="0 0 100 32" xmlns="http://www.w3.org/2000/svg">
#             <use href="#full">
#             </use>
#            </svg>
#            te ahorra envíos
#           </label>
#           <label class="ui-search-filter-highlighted__subtitle ui-search-icon-label" for="shipping_highlighted_fulfillment">
#            Con tu carrito de compras
#           </label>
#          </button>
#          <div class="ui-search-filter-highlighted__switch-container">
#           <label class="andes-checkbox andes-switch ui-search-filter-highlighted__switch-icon andes-checkbox--default andes-checkbox--default">
#            <input autocomplete="off" class="andes-checkbox__input" id="shipping_highlighted_fulfillment" type="checkbox"/>
#            <span class="andes-checkbox__label">
#            </span>
#            <span class="andes-checkbox__mimic">
#            </span>
#           </label>
#          </div>
#         </section>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <ul>
#        <li class="ui-search-filter-highlighted ui-search-filter-highlighted-shipping_cost_highlighted">
#         <section class="ui-search-filter-highlighted__container" role="group">
#          <button class="ui-search-filter-highlighted__content ui-search-filter-highlighted__content-button" name="button" type="button">
#           <label class="ui-search-filter-highlighted__title ui-search-icon-label" for="shipping_cost_highlighted">
#            Envío gratis
#           </label>
#          </button>
#          <div class="ui-search-filter-highlighted__switch-container">
#           <label class="andes-checkbox andes-switch ui-search-filter-highlighted__switch-icon andes-checkbox--default andes-checkbox--default">
#            <input autocomplete="off" class="andes-checkbox__input" id="shipping_cost_highlighted" type="checkbox"/>
#            <span class="andes-checkbox__label">
#            </span>
#            <span class="andes-checkbox__mimic">
#            </span>
#           </label>
#          </div>
#         </section>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <ul>
#        <li class="ui-search-filter-highlighted ui-search-filter-highlighted-SHIPPING_ORIGIN_HIGHLIGHTED">
#         <section class="ui-search-filter-highlighted__container" role="group">
#          <button class="ui-search-filter-highlighted__content ui-search-filter-highlighted__content-button" name="button" type="button">
#           <label class="ui-search-filter-highlighted__title ui-search-icon-label" for="SHIPPING_ORIGIN_HIGHLIGHTED">
#            <svg class="ui-search-icon ui-search-icon--international-filter-cbt" fill="none" height="16" viewbox="0 0 156 16" width="156" xmlns="http://www.w3.org/2000/svg">
#             <circle cx="8.00019" cy="8.00019" r="7.1" stroke="#1F4E96" stroke-width="1.4">
#             </circle>
#             <path d="M2.38083 3.22679C2.58026 4.1877 3.79511 6.49183 4.71976 7.79722C5.15489 11.0063 6.78987 12.982 6.78987 12.982C7.77304 13.3164 8.75751 9.41797 8.7991 8.28674C8.85349 6.60061 6.42402 7.45274 5.15489 7.68844C4.88294 7.36209 4.90469 6.209 5.64441 5.51279C6.56906 4.64253 9.80241 1.53423 9.20411 0.827148" stroke="#1F4E96" stroke-linejoin="round" stroke-width="1.4">
#             </path>
#             <path d="M13.1512 2.57544C12.4622 3.22813 11.2692 4.91425 12.009 6.43721C12.7487 7.96017 14.4928 9.39247 15.2724 9.91825" stroke="#1F4E96" stroke-width="1.4">
#             </path>
#             <path d="M24.092 11.632C25.049 11.632 26.27 11.291 27.117 10.213L25.907 9.399C25.489 9.916 24.807 10.246 24.18 10.246C22.915 10.246 22.123 9.388 22.123 8.244C22.123 6.627 23.289 5.428 24.675 5.428C25.522 5.428 26.226 5.846 26.512 6.627L28.008 6.121C27.579 5.01 26.545 4.042 24.752 4.042C22.475 4.042 20.484 5.747 20.484 8.343C20.484 10.345 22.068 11.632 24.092 11.632ZM31.719 11.632C34.139 11.632 35.987 9.718 35.987 7.32C35.987 5.307 34.403 4.042 32.379 4.042C29.959 4.042 28.111 5.945 28.111 8.343C28.111 10.356 29.684 11.632 31.719 11.632ZM31.807 10.246C30.63 10.246 29.75 9.476 29.75 8.244C29.75 6.671 30.861 5.428 32.28 5.428C33.457 5.428 34.348 6.198 34.348 7.43C34.348 9.003 33.226 10.246 31.807 10.246ZM44.1231 11.5L45.7401 4.163H43.4851L40.6911 8.75L39.9211 4.163H37.7871L36.1701 11.5H37.7321L38.8981 6.209L39.8001 11.5H40.4821L43.7161 6.209L42.5501 11.5H44.1231ZM47.1422 11.5L47.7252 8.882H49.5622C51.8612 8.882 52.5982 7.287 52.5982 6.198C52.5982 5.087 51.7292 4.163 50.5522 4.163H47.1972L45.5802 11.5H47.1422ZM49.6502 7.507H48.0222L48.4622 5.538H50.0572C50.5962 5.538 50.9702 5.879 50.9702 6.363C50.9702 7.012 50.4422 7.507 49.6612 7.507H49.6502ZM58.4062 11.5L57.3832 8.783C58.5712 8.563 59.4732 7.551 59.4732 6.231C59.4732 4.955 58.3952 4.163 57.2072 4.163H54.0722L52.4552 11.5H54.0172L54.5892 8.893H55.7992L56.6682 11.5H58.4062ZM56.5252 7.518H54.8972L55.3372 5.538H56.9102C57.3942 5.538 57.8452 5.89 57.8452 6.385C57.8452 7.045 57.3502 7.518 56.5362 7.518H56.5252ZM66.3656 11.5L65.1556 4.163H63.1976L58.7536 11.5H60.6126L61.3386 10.257H64.4846L64.6716 11.5H66.3656ZM64.3636 8.882H62.0756L63.9126 5.725L64.3636 8.882ZM71.4303 11.5L73.0473 4.163H71.4853L69.8683 11.5H71.4303ZM79.4539 11.5L81.0709 4.163H79.5089L78.4639 8.838L76.1099 4.163H74.5039L72.8869 11.5H74.4489L75.5269 6.638L77.9469 11.5H79.4539ZM84.1676 11.5L85.4766 5.538H87.6216L87.9186 4.163H82.0666L81.7696 5.538H83.9146L82.5946 11.5H84.1676ZM92.4949 11.5L92.7919 10.125H89.1729L89.5359 8.453H93.0889L93.3859 7.078H89.8439L90.1849 5.538H93.8039L94.1119 4.163H88.9199L87.3029 11.5H92.4949ZM99.667 11.5L98.644 8.783C99.832 8.563 100.734 7.551 100.734 6.231C100.734 4.955 99.656 4.163 98.468 4.163H95.333L93.716 11.5H95.278L95.85 8.893H97.06L97.929 11.5H99.667ZM97.786 7.518H96.158L96.598 5.538H98.171C98.655 5.538 99.106 5.89 99.106 6.385C99.106 7.045 98.611 7.518 97.797 7.518H97.786ZM107.351 11.5L108.968 4.163H107.406L106.361 8.838L104.007 4.163H102.401L100.784 11.5H102.346L103.424 6.638L105.844 11.5H107.351ZM115.64 11.5L114.43 4.163H112.472L108.028 11.5H109.887L110.613 10.257H113.759L113.946 11.5H115.64ZM113.638 8.882H111.35L113.187 5.725L113.638 8.882ZM119.794 11.632C120.751 11.632 121.972 11.291 122.819 10.213L121.609 9.399C121.191 9.916 120.509 10.246 119.882 10.246C118.617 10.246 117.825 9.388 117.825 8.244C117.825 6.627 118.991 5.428 120.377 5.428C121.224 5.428 121.928 5.846 122.214 6.627L123.71 6.121C123.281 5.01 122.247 4.042 120.454 4.042C118.177 4.042 116.186 5.747 116.186 8.343C116.186 10.345 117.77 11.632 119.794 11.632ZM124.948 11.5L126.565 4.163H125.003L123.386 11.5H124.948ZM130.364 11.632C132.784 11.632 134.632 9.718 134.632 7.32C134.632 5.307 133.048 4.042 131.024 4.042C128.604 4.042 126.756 5.945 126.756 8.343C126.756 10.356 128.329 11.632 130.364 11.632ZM130.452 10.246C129.275 10.246 128.395 9.476 128.395 8.244C128.395 6.671 129.506 5.428 130.925 5.428C132.102 5.428 132.993 6.198 132.993 7.43C132.993 9.003 131.871 10.246 130.452 10.246ZM141.383 11.5L143 4.163H141.438L140.393 8.838L138.039 4.163H136.433L134.816 11.5H136.378L137.456 6.638L139.876 11.5H141.383ZM149.671 11.5L148.461 4.163H146.503L142.059 11.5H143.918L144.644 10.257H147.79L147.977 11.5H149.671ZM147.669 8.882H145.381L147.218 5.725L147.669 8.882ZM154.958 11.5L155.255 10.125H152.153L153.473 4.163H151.9L150.283 11.5H154.958Z" fill="#1F4E96">
#             </path>
#            </svg>
#           </label>
#           <label class="ui-search-filter-highlighted__subtitle ui-search-icon-label" for="SHIPPING_ORIGIN_HIGHLIGHTED">
#            Envío gratis desde el mundo a tu casa
#           </label>
#          </button>
#          <div class="ui-search-filter-highlighted__switch-container">
#           <label class="andes-checkbox andes-switch ui-search-filter-highlighted__switch-icon andes-checkbox--default andes-checkbox--default">
#            <input autocomplete="off" class="andes-checkbox__input" id="SHIPPING_ORIGIN_HIGHLIGHTED" type="checkbox"/>
#            <span class="andes-checkbox__label">
#            </span>
#            <span class="andes-checkbox__mimic">
#            </span>
#           </label>
#          </div>
#         </section>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Tiendas oficiales
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Solo tiendas oficiales" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_Tienda_all_NoIndex_True#applied_filter_id%3Dofficial_store%26applied_filter_name%3DTiendas+oficiales%26applied_filter_order%3D4%26applied_value_id%3Dall%26applied_value_name%3DSolo+tiendas+oficiales%26applied_value_order%3D1%26applied_value_results%3D892%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Solo tiendas oficiales
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (892)
#          </span>
#         </button>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Categorías
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Computación" class="ui-search-button-link" formaction="https://computacion.mercadolibre.com.co/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO1648%26applied_value_name%3DComputaci%C3%B3n%26applied_value_order%3D17%26applied_value_results%3D29179%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Computación
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (29.179)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Audio" class="ui-search-button-link" formaction="https://electronica.mercadolibre.com.co/audio/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO3835%26applied_value_name%3DAudio%26applied_value_order%3D11%26applied_value_results%3D121382%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Audio
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (121.382)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Accesorios para Celulares" class="ui-search-button-link" formaction="https://celulares.mercadolibre.com.co/accesorios/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO3813%26applied_value_name%3DAccesorios+para+Celulares%26applied_value_order%3D2%26applied_value_results%3D40378%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Accesorios para Celulares
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (40.378)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Consolas y Videojuegos" class="ui-search-button-link" formaction="https://videojuegos.mercadolibre.com.co/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO1144%26applied_value_name%3DConsolas+y+Videojuegos%26applied_value_order%3D18%26applied_value_results%3D21471%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Consolas y Videojuegos
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (21.471)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Accesorios Audio y Video" class="ui-search-button-link" formaction="https://electronica.mercadolibre.com.co/accesorios-audio-video/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO3690%26applied_value_name%3DAccesorios+Audio+y+Video%26applied_value_order%3D1%26applied_value_results%3D5529%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Accesorios Audio y Video
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (5.529)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Instrumentos Musicales" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/instrumentos-musicales/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO1182%26applied_value_name%3DInstrumentos+Musicales%26applied_value_order%3D29%26applied_value_results%3D3975%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Instrumentos Musicales
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (3.975)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Telefonía Fija e Inalámbrica" class="ui-search-button-link" formaction="https://telefonos.mercadolibre.com.co/telefonia-fija-e-inalambrica/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO1053%26applied_value_name%3DTelefon%C3%ADa+Fija+e+Inal%C3%A1mbrica%26applied_value_order%3D44%26applied_value_results%3D3423%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Telefonía Fija e Inalámbrica
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (3.423)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Deportes y Fitness" class="ui-search-button-link" formaction="https://deportes.mercadolibre.com.co/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO1276%26applied_value_name%3DDeportes+y+Fitness%26applied_value_order%3D22%26applied_value_results%3D2430%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Deportes y Fitness
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (2.430)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Cables" class="ui-search-button-link" formaction="https://electronica.mercadolibre.com.co/cables/audifonos_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D5%26applied_value_id%3DMCO5054%26applied_value_name%3DCables%26applied_value_order%3D14%26applied_value_results%3D2313%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Cables
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (2.313)
#          </span>
#         </button>
#        </li>
#        <li>
#         <a class="ui-search-modal__link ui-search-modal--default ui-search-link" href="https://listado.mercadolibre.com.co/audifonos_FiltersAvailableSidebar?filter=category">
#          Ver todos
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Pago
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Cuotas sin interés" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_Installments_NoInterest_NoIndex_True#applied_filter_id%3Dinstallments%26applied_filter_name%3DPago%26applied_filter_order%3D6%26applied_value_id%3Dno_interest%26applied_value_name%3DCuotas+sin+inter%C3%A9s%26applied_value_order%3D1%26applied_value_results%3D84033%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Cuotas sin interés
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (84.033)
#          </span>
#         </button>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Costo de envío
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Gratis" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_CostoEnvio_Gratis_NoIndex_True#applied_filter_id%3Dshipping_cost%26applied_filter_name%3DCosto+de+env%C3%ADo%26applied_filter_order%3D7%26applied_value_id%3Dfree%26applied_value_name%3DGratis%26applied_value_order%3D1%26applied_value_results%3D198377%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Gratis
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (198.377)
#          </span>
#         </button>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Envío
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Mercado Envíos" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_Envio_MercadoEnvios_NoIndex_True#applied_filter_id%3Dshipping%26applied_filter_name%3DEnv%C3%ADo%26applied_filter_order%3D8%26applied_value_id%3Dmercadoenvios%26applied_value_name%3DMercado+Env%C3%ADos%26applied_value_order%3D2%26applied_value_results%3D222049%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Mercado Envíos
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (222.049)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <a aria-label="Full" class="ui-search-filter-icon ui-search-link" href="https://listado.mercadolibre.com.co/audifonos_Envio_Full_NoIndex_True#applied_filter_id%3Dshipping%26applied_filter_name%3DEnv%C3%ADo%26applied_filter_order%3D8%26applied_value_id%3Dfulfillment%26applied_value_name%3DFull%26applied_value_order%3D1%26applied_value_results%3D937%26is_custom%3Dfalse" rel="nofollow">
#          <svg aria-label="full" class="ui-search-icon ui-search-icon--full ui-search-filter-icon--full" viewbox="0 0 100 32" xmlns="http://www.w3.org/2000/svg">
#           <use href="#full">
#           </use>
#          </svg>
#          <span class="ui-search-filter-results-qty">
#           (937)
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Condición
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Nuevo" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_ITEM*CONDITION_2230284_NoIndex_True#applied_filter_id%3DITEM_CONDITION%26applied_filter_name%3DCondici%C3%B3n%26applied_filter_order%3D9%26applied_value_id%3D2230284%26applied_value_name%3DNuevo%26applied_value_order%3D1%26applied_value_results%3D146084%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Nuevo
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (146.084)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Usado" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_ITEM*CONDITION_2230581_NoIndex_True#applied_filter_id%3DITEM_CONDITION%26applied_filter_name%3DCondici%C3%B3n%26applied_filter_order%3D9%26applied_value_id%3D2230581%26applied_value_name%3DUsado%26applied_value_order%3D3%26applied_value_results%3D3390%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Usado
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (3.390)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Reacondicionado" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_ITEM*CONDITION_2230582_NoIndex_True#applied_filter_id%3DITEM_CONDITION%26applied_filter_name%3DCondici%C3%B3n%26applied_filter_order%3D9%26applied_value_id%3D2230582%26applied_value_name%3DReacondicionado%26applied_value_order%3D2%26applied_value_results%3D132%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Reacondicionado
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (132)
#          </span>
#         </button>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Ubicación
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Bogotá D.C." class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/bogota-dc/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-DC%26applied_value_name%3DBogot%C3%A1+D.C.%26applied_value_order%3D4%26applied_value_results%3D108018%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Bogotá D.C.
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (108.018)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Cesar" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/cesar/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-CES%26applied_value_name%3DCesar%26applied_value_order%3D11%26applied_value_results%3D42072%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Cesar
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (42.072)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Antioquia" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/antioquia/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-ANT%26applied_value_name%3DAntioquia%26applied_value_order%3D1%26applied_value_results%3D15649%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Antioquia
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (15.649)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Santander" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/santander/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-SAN%26applied_value_name%3DSantander%26applied_value_order%3D26%26applied_value_results%3D9220%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Santander
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (9.220)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Cundinamarca" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/cundinamarca/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-CUN%26applied_value_name%3DCundinamarca%26applied_value_order%3D13%26applied_value_results%3D8054%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Cundinamarca
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (8.054)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Atlantico" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/atlantico/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-ATL%26applied_value_name%3DAtlantico%26applied_value_order%3D3%26applied_value_results%3D5253%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Atlantico
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (5.253)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Valle Del Cauca" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/valle-del-cauca/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-VAC%26applied_value_name%3DValle+Del+Cauca%26applied_value_order%3D29%26applied_value_results%3D3470%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Valle Del Cauca
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (3.470)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Bolivar" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/bolivar/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-BOL%26applied_value_name%3DBolivar%26applied_value_order%3D5%26applied_value_results%3D1977%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Bolivar
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (1.977)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Risaralda" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/risaralda/audifonos_NoIndex_True#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D10%26applied_value_id%3DCO-RIS%26applied_value_name%3DRisaralda%26applied_value_order%3D24%26applied_value_results%3D577%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Risaralda
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (577)
#          </span>
#         </button>
#        </li>
#        <li>
#         <a class="ui-search-modal__link ui-search-modal--default ui-search-link" href="https://listado.mercadolibre.com.co/audifonos_FiltersAvailableSidebar?filter=state">
#          Ver todos
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="ui-search-filter-dl">
#       <div aria-level="3" class="ui-search-filter-dt-title" role="heading">
#        Precio
#       </div>
#       <ul>
#        <li class="ui-search-filter-container">
#         <button aria-label="Hasta $100.000" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_PriceRange_0-100000_NoIndex_True#applied_filter_id%3Dprice%26applied_filter_name%3DPrecio%26applied_filter_order%3D11%26applied_value_id%3D*-100000.0%26applied_value_name%3DHasta+%24100.000%26applied_value_order%3D1%26applied_value_results%3D53683%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Hasta $100.000
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (53.683)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="$100.000 a $200.000" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_PriceRange_100000-200000_NoIndex_True#applied_filter_id%3Dprice%26applied_filter_name%3DPrecio%26applied_filter_order%3D11%26applied_value_id%3D100000.0-200000.0%26applied_value_name%3D%24100.000+a+%24200.000%26applied_value_order%3D2%26applied_value_results%3D83341%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           $100.000 a $200.000
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (83.341)
#          </span>
#         </button>
#        </li>
#        <li class="ui-search-filter-container">
#         <button aria-label="Más de $200.000" class="ui-search-button-link" formaction="https://listado.mercadolibre.com.co/audifonos_PriceRange_200000-0_NoIndex_True#applied_filter_id%3Dprice%26applied_filter_name%3DPrecio%26applied_filter_order%3D11%26applied_value_id%3D200000.0-*%26applied_value_name%3DM%C3%A1s+de+%24200.000%26applied_value_order%3D3%26applied_value_results%3D87233%26is_custom%3Dfalse" role="link" type="submit">
#          <span class="ui-search-filter-name">
#           Más de $200.000
#          </span>
#          <span class="ui-search-filter-results-qty">
#           (87.233)
#          </span>
#         </button>
#        </li>
#        <li>
#         <section class="ui-search-price-filter ui-search-filter-range--price">
#          <div class="ui-search-price-filter-container">
#           <label class="andes-form-control andes-form-control--textfield andes-form-control--textbox">
#            <div class="andes-form-control__control">
# ...
#           <div class="ui-search-result__content-column ui-search-result__content-column--left">
#            <div class="ui-search-item__group ui-search-item__group--price">
#             <div class="ui-search-item__group__element">
#              <div class="ui-search-price ui-search-price--size-medium">
#               <s class="price-tag ui-search-price__part ui-search-price__original-value price-tag__disabled">
#                <span class="price-tag-text-sr-only">
#                 Antes: 147380 pesos
#                </span>
#                <span aria-hidden="true" class="price-tag-amount">
#                 <span class="price-tag-symbol">
#                  $
#                 </span>
#                 <span class="price-tag-fraction">
#                  147.380
#                 </span>
#                </span>
#               </s>
#               <div class="ui-search-price__second-line">
#                <span class="price-tag ui-search-price__part">
#                 <span class="price-tag-text-sr-only">
#                  128220 pesos
#                 </span>
#                 <span aria-hidden="true" class="price-tag-amount">
#                  <span class="price-tag-symbol">
#                   $
#                  </span>
#                  <span class="price-tag-fraction">
#                   128.220
#                  </span>
#                 </span>
#                </span>
#                <span class="ui-search-price__second-line__label">
#                 <span class="ui-search-price__discount">
#                  13% OFF
#                 </span>
#                </span>
#               </div>
#              </div>
#             </div>
#             <span class="ui-search-item__group__element ui-search-installments ui-search-color--BLACK">
#              <div class="ui-search-installments-prefix">
#               <span>
#                en
#               </span>
#              </div>
#              36x
#              <div class="ui-search-price ui-search-price--size-x-tiny ui-search-color--BLACK">
#               <div class="ui-search-price__second-line">
#                <span class="price-tag ui-search-price__part">
#                 <span class="price-tag-text-sr-only">
#                  3562 pesos
#                 </span>
#                 <span aria-hidden="true" class="price-tag-amount">
#                  <span class="price-tag-symbol">
#                   $
#                  </span>
#                  <span class="price-tag-fraction">
#                   3.562
#                  </span>
#                 </span>
#                </span>
#               </div>
#              </div>
#             </span>
#            </div>
#            <div class="ui-search-item__group ui-search-item__group--shipping">
#             <div class="ui-search-item__group__element ui-search-item__group__element--shipping">
#              <p class="ui-search-item__shipping ui-search-item__shipping--free">
#               Envío gratis
#              </p>
#             </div>
#            </div>
#           </div>
#           <div class="ui-search-result__content-column ui-search-result__content-column--right ui-search-result__content-column--extra-padding">
#            <div class="ui-search-item__group ui-search-item__group--reviews">
#             <div class="ui-search-reviews ui-search-item__group__element">
#              <span class="ui-search-reviews__ratings">
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-half" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-half">
#                </use>
#               </svg>
#              </span>
#              <span class="ui-search-reviews__amount">
#               151
#              </span>
#             </div>
#            </div>
#            <div class="ui-search-item__group ui-search-item__group--variations-text">
#             <span class="ui-search-item__group__element ui-search-item__variations-text">
#              Disponible en 4 colores
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="ui-search-result__bookmark">
#          <form action="/search/bookmarks/MCO652325407" class="ui-search-bookmark" method="POST">
#           <button aria-checked="false" aria-label="Favorito" class="ui-search-bookmark__btn" role="switch" type="submit">
#            <svg class="ui-search-icon ui-search-icon--bookmark ui-search-bookmark__icon-bookmark" viewbox="0 0 22 20" xmlns="http://www.w3.org/2000/svg">
#             <use href="#bookmark">
#             </use>
#            </svg>
#            <svg class="ui-search-icon ui-search-icon--bookmark ui-search-bookmark__icon-bookmark-fill" viewbox="0 0 22 20" xmlns="http://www.w3.org/2000/svg">
#             <use href="#bookmark">
#             </use>
#            </svg>
#           </button>
#           <input name="logginUrl" type="hidden" value="https://www.mercadolibre.com/jms/mco/lgz/login?platform_id=ML&amp;go=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos&amp;loginType=explicit"/>
#           <input name="_csrf" type="hidden" value="i4HkEUZT-81T1quIFPHPgmLoqjF-jbJLQHfQ"/>
#           <input name="method" type="hidden" value="add"/>
#           <input name="itemId" type="hidden" value="MCO652325407"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </li>
#      <li class="ui-search-layout__item">
#       <div class="ui-search-result__wrapper">
#        <div class="andes-card andes-card--flat andes-card--default ui-search-result ui-search-result--core andes-card--padding-default">
#         <div class="ui-search-result__image">
#          <a class="ui-search-link" href="https://www.mercadolibre.com.co/audifonos-in-ear-inalambricos-bose-quietcomfort-earbuds-triple-black/p/MCO16999221#searchVariation=MCO16999221&amp;position=50&amp;search_layout=stack&amp;type=product&amp;tracking_id=17140da4-5d1e-49bf-b7e3-28c4b070a37d" title="Audífonos in-ear inalámbricos Bose QuietComfort Earbuds triple black">
#           <div class="carousel-container arrow-visible">
#            <div class="slick-initialized slick-slider">
#             <div class="slick-list" role="presentation">
#              <div class="slick-track">
#               <div class="slick-slide slick-active" data-index="0" style="outline:none" tabindex="-1">
#                <img alt="Audífonos in-ear inalámbricos Bose QuietComfort Earbuds triple black" class="ui-search-result-image__element lazy-loadable" data-src="https://http2.mlstatic.com/D_NQ_NP_697090-MLA45668238356_042021-V.jpg" height="160" src="..." width="160"/>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </a>
#         </div>
#         <div class="ui-search-result__content-wrapper">
#          <div class="ui-search-item__highlight-label ui-search-item__highlight-label--MCO4203" style="background:#3483FA">
#           <div class="ui-search-item__highlight-label__container">
#            <label class="ui-search-styled-label ui-search-item__highlight-label__text" for="" style="color:#FFFFFF">
#             EXENTO DE IVA
#            </label>
#           </div>
#          </div>
#          <div class="ui-search-item__group ui-search-item__group--title">
#           <a class="ui-search-item__group__element ui-search-link" href="https://www.mercadolibre.com.co/audifonos-in-ear-inalambricos-bose-quietcomfort-earbuds-triple-black/p/MCO16999221#searchVariation=MCO16999221&amp;position=50&amp;search_layout=stack&amp;type=product&amp;tracking_id=17140da4-5d1e-49bf-b7e3-28c4b070a37d" title="Audífonos in-ear inalámbricos Bose QuietComfort Earbuds triple black">
#            <h2 class="ui-search-item__title">
#             Audífonos in-ear inalámbricos Bose QuietComfort Earbuds triple black
#            </h2>
#           </a>
#          </div>
#          <div class="ui-search-result__content-columns">
#           <div class="ui-search-result__content-column ui-search-result__content-column--left">
#            <div class="ui-search-item__group ui-search-item__group--price">
#             <div class="ui-search-item__group__element">
#              <div class="ui-search-price ui-search-price--size-medium">
#               <div class="ui-search-price__second-line">
#                <span class="price-tag ui-search-price__part">
#                 <span class="price-tag-text-sr-only">
#                  1092350 pesos
#                 </span>
#                 <span aria-hidden="true" class="price-tag-amount">
#                  <span class="price-tag-symbol">
#                   $
#                  </span>
#                  <span class="price-tag-fraction">
#                   1.092.350
#                  </span>
#                 </span>
#                </span>
#                <span class="ui-search-price__second-line__label">
#                </span>
#               </div>
#              </div>
#             </div>
#             <span class="ui-search-item__group__element ui-search-installments ui-search-color--BLACK">
#              <div class="ui-search-installments-prefix">
#               <span>
#                en
#               </span>
#              </div>
#              36x
#              <div class="ui-search-price ui-search-price--size-x-tiny ui-search-color--BLACK">
#               <div class="ui-search-price__second-line">
#                <span class="price-tag ui-search-price__part">
#                 <span class="price-tag-text-sr-only">
#                  30343 pesos
#                 </span>
#                 <span aria-hidden="true" class="price-tag-amount">
#                  <span class="price-tag-symbol">
#                   $
#                  </span>
#                  <span class="price-tag-fraction">
#                   30.343
#                  </span>
#                 </span>
#                </span>
#               </div>
#              </div>
#             </span>
#            </div>
#            <div class="ui-search-item__group ui-search-item__group--shipping">
#             <div class="ui-search-item__group__element ui-search-item__group__element--shipping">
#              <p class="ui-search-item__shipping ui-search-item__shipping--free">
#               Envío gratis
#              </p>
#             </div>
#            </div>
#           </div>
#           <div class="ui-search-result__content-column ui-search-result__content-column--right">
#            <div class="ui-search-item__group ui-search-item__group--reviews">
#             <div class="ui-search-reviews ui-search-item__group__element">
#              <span class="ui-search-reviews__ratings">
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" fill="#3483fa" height="100%" viewbox="0 0 10 10" width="100%">
#                <use href="#start-full">
#                </use>
#               </svg>
#               <svg class="ui-search-icon ui-search-icon--star ui-search-icon--star-full" height="100%" viewbox="0 0 11 10" width="100%">
#                <use href="#start-empty">
#                </use>
#               </svg>
#              </span>
#              <span class="ui-search-reviews__amount">
#               5
#              </span>
#             </div>
#            </div>
#            <div class="ui-search-item__group ui-search-item__group--variations-text">
#             <span class="ui-search-item__group__element ui-search-item__variations-text">
#              Disponible en 2 colores
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="ui-search-result__bookmark">
#          <form action="/search/bookmarks/MCO621342714" class="ui-search-bookmark" method="POST">
#           <button aria-checked="false" aria-label="Favorito" class="ui-search-bookmark__btn" role="switch" type="submit">
#            <svg class="ui-search-icon ui-search-icon--bookmark ui-search-bookmark__icon-bookmark" viewbox="0 0 22 20" xmlns="http://www.w3.org/2000/svg">
#             <use href="#bookmark">
#             </use>
#            </svg>
#            <svg class="ui-search-icon ui-search-icon--bookmark ui-search-bookmark__icon-bookmark-fill" viewbox="0 0 22 20" xmlns="http://www.w3.org/2000/svg">
#             <use href="#bookmark">
#             </use>
#            </svg>
#           </button>
#           <input name="logginUrl" type="hidden" value="https://www.mercadolibre.com/jms/mco/lgz/login?platform_id=ML&amp;go=https%3A%2F%2Flistado.mercadolibre.com.co%2Faudifonos&amp;loginType=explicit"/>
#           <input name="_csrf" type="hidden" value="i4HkEUZT-81T1quIFPHPgmLoqjF-jbJLQHfQ"/>
#           <input name="method" type="hidden" value="add"/>
#           <input name="itemId" type="hidden" value="MCO621342714"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </li>
#     </ol>
#     <div class="ui-search-listing-disclaimer ui-search-listing-disclaimer--stack">
#      <div class="ui-search-listing-disclaimer__card ui-search-listing-disclaimer__card--stack">
#       <div class="andes-badge andes-badge--notification andes-badge--neutral ui-search-listing-disclaimer__icon andes-badge--small" hierarchy="loud">
#        <svg class="andes-badge__icon" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#         <g fill="none" fill-rule="evenodd">
#          <g transform="matrix(1 0 0 -1 0 16)">
#           <path class="andes-badge__icon-inner" d="M7.03 3.879h1.94l-.243 5.333H7.273z">
#           </path>
#           <circle class="andes-badge__icon-inner" cx="8" cy="11.152" r="1" transform="matrix(1 0 0 -1 0 22.303)">
#           </circle>
#          </g>
#         </g>
#        </svg>
#       </div>
#       <p class="ui-search-listing-disclaimer__text">
#        El envío gratis está sujeto al peso, precio y la distancia del envío.
#       </p>
#      </div>
#     </div>
#     <div class="ui-search-pagination">
#      <ul class="ui-search-pagination andes-pagination" role="navigation">
#       <li class="andes-pagination__button andes-pagination__button--current">
#        <span class="andes-pagination__link">
#         1
#        </span>
#       </li>
#       <li class="andes-pagination__page-count">
#        de
#        <!-- -->
#        40
#       </li>
#       <li class="andes-pagination__button andes-pagination__button--next">
#        <a class="andes-pagination__link ui-search-link" href="https://listado.mercadolibre.com.co/audifonos_Desde_51_NoIndex_True" rel="nofollow" role="button" title="Siguiente">
#         <span class="andes-pagination__arrow-title">
#          Siguiente
#         </span>
#         <span class="andes-pagination__arrow">
#         </span>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </section>
#   </div>
#  </div>
# </main>

# %%
productos = results.find_all("div", class_="ui-search-result__wrapper")

for producto in productos:
    nombre = producto.find("h2", class_="ui-search-item__title")
    #envio = producto.find("p", class_="ui-search-item__shipping ui-search-item__shipping--free")
    precio = producto.find("span", class_="price-tag-text-sr-only")
    print(nombre.text)
    #print(envio.text)
    print(precio.text)
    print()

# %% [markdown]
# ### Actividad
# Descarga los datos de audífonos del sitio web de Falabella

# %% [markdown]
# ### Descargando datos de Twitter
#
# Otra fuente de datos que puede ser relevante son las redes sociales. Para poder tomar datos desde redes sociales, necesitamos conectarnos a través de un servicio que cada red ofrece. Por ejemplo, en el caso de twitter solicitamos crear una aplicación a través de este enlace: https://developer.twitter.com/en/docs/twitter-api
#
# Para el ejercicio de hoy, yo ya solicité la creación, y abajo podemos ver los datos clave que necesitamos:
# my_api_key y my_api_secret . Con esto, le estamos dando como un "usuario" y "clave" a twitter para conectarnos.

# %%
# import tweepy
import tweepy as tw
# your Twitter API key and API secret
my_api_key = "wvXJ24P3YupUN9kNX8HnvDzp8"
my_api_secret = "33uUzfW8h1gUNMNtrsnMvF7Zt1ucJURBuYZGmNp3IWCevNxA8H"
# Esta instrucción nos permite autenticarnos antes Twitter
auth = tw.OAuthHandler(my_api_key, my_api_secret)
# Una vez autenticados, creamos una variable llamada **api** que será la que utilizaremos para consultar los tweets
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# Una vez nos conectamos, el siguiente paso es buscar la información que queremos. Una forma fácil de hacerlo es utilizando los hashtags, que son definidos con el símbolo #.
#
# En el siguiente bloque estamos consultando los tweets que han sido publicados desde el primero de marzo de este año sobre covid 19 en español. Nota que estamos filtrando para quitar los retweets, y así evitar duplicar información. Si quieres conocer cómo funcionan estos filtros y otras funciones de Tweepy ingresa a https://medium.com/@robguilarr/making-queries-to-twitter-api-on-tweepy-66afeb7184a4
#
# Para más información sobre Tweepy
# https://docs.tweepy.org/en/stable/

# %%
search_query = "#covid19 -filter:retweets"
# Obtener tweets
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="es",
              since="2022-03-01").items(50)

# Almacenar los tweets en una lista e imprimirlos
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    print(tweet)
    
print("Número total de tweets:", len(tweets_copy))

# %% [markdown]
# ### Actividad
# Ahora descarga los datos que se hayan publicado durante esta semana sobre las elecciones en Colombia. ¿Qué hashtag quieres usar?
