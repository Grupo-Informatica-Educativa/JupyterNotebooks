# %%
# !pip install SoundFile
# !pip install PsychoPy
# Out:
# ...
#   Using cached SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
# ...
#   Using cached google_auth-2.6.2-py2.py3-none-any.whl (156 kB)
# ...
#   Using cached google_api_core-2.7.1-py3-none-any.whl (114 kB)
# ...
#      -------------------------------------- 488.2/488.2 KB 3.4 MB/s eta 0:00:00
# ...
#   Using cached google_cloud_speech-2.13.1-py2.py3-none-any.whl (131 kB)
# ...
#   Using cached python_vlc-3.0.11115-py3-none-any.whl (80 kB)
# ...
#      ---------------------------------------- 8.4/8.4 MB 5.7 MB/s eta 0:00:00
# ...
#   Using cached google_cloud-0.34.0-py2.py3-none-any.whl (1.8 kB)
# ...
#      ---------------------------------------- 8.2/8.2 MB 1.7 MB/s eta 0:00:00
# ...
#   Using cached pyglet-1.4.11-py2.py3-none-any.whl (1.0 MB)
# ...
#   Using cached pocketsphinx-0.1.15.tar.gz (29.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# ...
#   Using cached markdown_it_py-2.0.1-py3-none-any.whl (84 kB)
# ...

# %%
# !python "Cargas cognitivas niños_lastrun.py"
# Out:
# 1.1983 	WARNING 	The 'psychtoolbox' library cannot be loaded but is required for audio capture (use `pip install psychtoolbox` to get it). Microphone recording will be unavailable this session. Note that opening a microphone stream will raise an error.
# C:\Users\cvieira\Anaconda3\envs\psycoenv\lib\site-packages\pyglet\media\codecs\wmf.py:838: UserWarning: [WinError -2147417850] No se puede cambiar el modo de subproceso después de establecerlo
#   warnings.warn(str(err))
# C:\Users\cvieira\Anaconda3\envs\psycoenv\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] No se puede cambiar el modo de subproceso después de establecerlo
#   warnings.warn(str(err))
# 1.3988 	WARNING 	Speech-to-text recognition module for PocketSphinx is not available (use command `pip install SpeechRecognition` to get it). Transcription will be unavailable using that service this session.
# ...
